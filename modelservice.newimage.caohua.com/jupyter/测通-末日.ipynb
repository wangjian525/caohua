# %% [markdown]
# # 本地测试

# %%
import os
os.getcwd()
# Out:
# '/home/caohua/image_new/jupyter'

# %%
os.chdir(os.path.dirname(os.getcwd()))

# %%
os.getcwd()
# Out:
# '/home/caohua/image_new'

# %% [markdown]
# ## 初步评分

# %%
from media_toutiao.image_score_pre_new import *

# %%
# new_image_score = NewImageScore()

# %%
# df = new_image_score()
# df.head()

# %%
# new_image_score.load_to_hive()

# %% [markdown]
# ## 计划创建

# %%
from media_toutiao.create_plan_with_train import *

# %%
plan_creator = NewCreatePlan()
# Out:
# [INFO]: 实时数据提取完毕！

# %%
rsp = plan_creator()
# Out:
# no score new num: 7
# back new num: 6
# [INFO]：新素材提取成功！
# Processing!:   0%|          | 0/17160 [00:00<?, ?it/s]
# [INFO]: 实时计划训练完毕！
# [INFO]: 候选计划组合完毕！
# [INFO]: 新建计划创建完毕！

# %%
rsp
# Out:
#     ad_account_id  image_id  game_id       gender delivery_range  \
# 0            7852     35812  1001703         NONE        DEFAULT
# 1            7853     35812  1001703  GENDER_MALE        DEFAULT
# 2            7852     35930  1001703  GENDER_MALE        DEFAULT
# 3            7853     35568  1001703         NONE        DEFAULT
# 4            7854     35304  1001703  GENDER_MALE        DEFAULT
# ..            ...       ...      ...          ...            ...
# 95           7794     36009  1001703  GENDER_MALE        DEFAULT
# 96           7794     35208  1001703  GENDER_MALE        DEFAULT
# 97           7852     35208  1001703  GENDER_MALE        DEFAULT
# 98           7852     35476  1001703         NONE        DEFAULT
# 99           7855     35885  1001703         NONE        DEFAULT
#
#    hide_if_converted  hide_if_exists  auto_extend_enabled  \
# 0                 AD               0                    1
# 1                 AD               0                    0
# 2                APP               0                    0
# 3                APP               0                    0
# 4                APP               0                    1
# ..               ...             ...                  ...
# 95                AD               0                    0
# 96               APP               0                    0
# 97               APP               0                    0
# 98               APP               0                    0
# 99                AD               0                    0
#
#          flow_control_mode location_type  \
# 0   FLOW_CONTROL_MODE_FAST       CURRENT
# 1   FLOW_CONTROL_MODE_FAST       CURRENT
# 2   FLOW_CONTROL_MODE_FAST       CURRENT
# 3   FLOW_CONTROL_MODE_FAST       CURRENT
# 4   FLOW_CONTROL_MODE_FAST       CURRENT
# ..                     ...           ...
# 95  FLOW_CONTROL_MODE_FAST       CURRENT
# 96  FLOW_CONTROL_MODE_FAST       CURRENT
# 97  FLOW_CONTROL_MODE_FAST       CURRENT
# 98  FLOW_CONTROL_MODE_FAST       CURRENT
# 99  FLOW_CONTROL_MODE_FAST       CURRENT
#
#                                        inventory_type  \
# 0   [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 1   [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 2   [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 3                              [INVENTORY_UNION_SLOT]
# 4                              [INVENTORY_UNION_SLOT]
# ..                                                ...
# 95  [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 96  [INVENTORY_AWEME_FEED, INVENTORY_FEED, INVENTO...
# 97  [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 98  [INVENTORY_UNION_SLOT, INVENTORY_FEED, INVENTO...
# 99                             [INVENTORY_UNION_SLOT]
#
#                                         schedule_time          ac  budget  \
# 0   1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 1   1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 2   1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 3   1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 4   1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# ..                                                ...         ...     ...
# 95  1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 96  1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 97  1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 98  1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
# 99  1111111111111111111111111111111111111111111111...  [WIFI, 4G]  3300.0
#
#     cpa_bid   platform  retargeting_type retargeting_tags_include  \
# 0    635.00  [ANDROID]               NaN                       []
# 1    606.00  [ANDROID]               NaN                       []
# 2    618.00  [ANDROID]               NaN                       []
# 3    627.47  [ANDROID]               NaN                       []
# 4    627.09  [ANDROID]               NaN                       []
# ..      ...        ...               ...                      ...
# 95   648.00  [ANDROID]               NaN                       []
# 96   638.00  [ANDROID]               NaN                       []
# 97   630.00  [ANDROID]               NaN                       []
# 98   618.00  [ANDROID]               NaN                       []
# 99   608.38  [ANDROID]               NaN                       []
#
#    retargeting_tags_exclude  action_days action_categories action_scene  \
# 0    [324104932, 325120861]          NaN                []           []
# 1    [324104932, 325120861]          NaN                []           []
# 2                        []          NaN                []           []
# 3                        []          NaN                []           []
# 4                        []          NaN                []           []
# ..                      ...          ...               ...          ...
# 95                       []          NaN                []           []
# 96                       []          NaN                []           []
# 97                       []          NaN                []           []
# 98                       []          NaN                []           []
# 99                       []          NaN                []           []
#
#    interest_categories interest_action_mode  adjust_cpa    smart_bid_type  \
# 0                   []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 1                   []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 2                   []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 3                   []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 4                   []            UNLIMITED         0.0  SMART_BID_CUSTOM
# ..                 ...                  ...         ...               ...
# 95                  []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 96                  []            RECOMMEND         0.0  SMART_BID_CUSTOM
# 97                  []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 98                  []            UNLIMITED         0.0  SMART_BID_CUSTOM
# 99                  []            UNLIMITED         0.0  SMART_BID_CUSTOM
#
#      deep_bid_type  roi_goal  \
# 0   BID_PER_ACTION       NaN
# 1   BID_PER_ACTION       NaN
# 2   BID_PER_ACTION       NaN
# 3   BID_PER_ACTION       NaN
# 4   BID_PER_ACTION       NaN
# ..             ...       ...
# 95  BID_PER_ACTION       NaN
# 96  BID_PER_ACTION       NaN
# 97  BID_PER_ACTION       NaN
# 98  BID_PER_ACTION       NaN
# 99  BID_PER_ACTION       NaN
#
#                                           ad_keywords  \
# 0   [生存挑战, 全城危急, 末世军团, 生存危机, 末日, 丧尸, 末世, 生化危机, 小姐姐...
# 1   [卡牌, 手游, 游戏, 抽卡, 十连抽, 氪金, 主播, 妹子, 陪玩, 基金, 定投, ...
# 2   [丧尸, 美女, 僵尸, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, ...
# 3   [末日, 末世, 丧尸, 行尸走肉, 生化危机, 丧尸国度, 小姐姐, 美女, 小姨子, 大...
# 4                           [丧尸, 末日, 氪金, 法拉利, 手表, 跑车]
# ..                                                ...
# 95                          [丧尸, 末日, 氪金, 法拉利, 手表, 跑车]
# 96  [丧尸, 美女, 僵尸, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, ...
# 97  [末日, 末世, 丧尸, 幸存, 美女, 长腿, 小姨子, 女忧, 豪车, 科技, 5G, ...
# 98                          [丧尸, 末日, 氪金, 法拉利, 手表, 跑车]
# 99                           [手游, 策略游戏, 卡牌游戏, 好玩, 丧尸]
#
#                                            title_list third_industry_id city  \
# 0   [{'title': '3分钟上手，5分钟上头，来试试你能过多少关？'}, {'title'...          19130103   []
# 1   [{'title': '嫂子上厕所都在玩的游戏，原来这么好玩！'}, {'title': '...          19131501   []
# 2   [{'title': '解谜逃生，策略生存，太烧脑了，能否通过，全靠智商！', 'creat...          19131501   []
# 3   [{'title': '移动机关，灭杀怪物，逃出升天，闯关成功！', 'creative_w...          19130103   []
# 4   [{'title': '不烧钱只烧脑，智商135挂在49关，一起来试试吧', 'creati...          19130101   []
# ..                                                ...               ...  ...
# 95  [{'title': '嫂子上厕所都在玩的游戏，没想到竟然这么好玩！', 'creative...          19130101   []
# 96  [{'title': '3分钟上手，5分钟上头，来试试你能过多少关？', 'creative...          19131201   []
# 97  [{'title': '智商149卡在了39关，这款游戏太烧脑，你能过几关？', 'crea...          19131201   []
# 98  [{'title': '移动机关，灭杀怪物，逃出升天，闯关成功！'}, {'title': ...          19130101   []
# 99  [{'title': '这款游戏不肝不氪，休闲又解压，玩了一天都不腻！', 'creativ...          19130103   []
#
#     android_osv  op_id   flag operation   launch_price  convertIndex  \
# 0           NaN  13678  CESHI   disable  [1000, 11000]            13
# 1           NaN  13678  CESHI   disable  [1000, 11000]            13
# 2           NaN  13678  CESHI   disable  [1000, 11000]            13
# 3           NaN  13678  CESHI   disable  [1000, 11000]            13
# 4           NaN  13678  CESHI   disable  [1000, 11000]            13
# ..          ...    ...    ...       ...            ...           ...
# 95          NaN  13678  CESHI   disable  [1000, 11000]            13
# 96          NaN  13678  CESHI   disable  [1000, 11000]            13
# 97          NaN  13678  CESHI   disable  [1000, 11000]            13
# 98          NaN  13678  CESHI   disable  [1000, 11000]            13
# 99          NaN  13678  CESHI   disable  [1000, 11000]            13
#
#                                                   age  \
# 0   [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 1   [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 2   [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 3   [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 4   [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# ..                                                ...
# 95  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 96  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 97  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 98  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 99  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
#
#                                               web_url
# 0   https://www.chengzijianzhan.com/tetris/page/69...
# 1   https://www.chengzijianzhan.com/tetris/page/69...
# 2   https://www.chengzijianzhan.com/tetris/page/69...
# 3   https://www.chengzijianzhan.com/tetris/page/69...
# 4   https://www.chengzijianzhan.com/tetris/page/69...
# ..                                                ...
# 95  https://www.chengzijianzhan.com/tetris/page/69...
# 96  https://www.chengzijianzhan.com/tetris/page/69...
# 97  https://www.chengzijianzhan.com/tetris/page/69...
# 98  https://www.chengzijianzhan.com/tetris/page/69...
# 99  https://www.chengzijianzhan.com/tetris/page/69...
#
# [100 rows x 40 columns]
