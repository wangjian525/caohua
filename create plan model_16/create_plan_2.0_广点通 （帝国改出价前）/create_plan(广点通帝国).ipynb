# %%
import pandas as pd
import numpy as np
import json
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import warnings
import random

warnings.filterwarnings('ignore')
import lightgbm as lgb
from impala.dbapi import connect
from impala.util import as_pandas
import pymysql
import ast
import re
import requests
from itertools import combinations
from tqdm import tqdm_notebook

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
def get_game_id():
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL 
    '''
    cur.execute(sql)
    result_df = cur.fetchall()
    cur.close()
    conn.close()
    return result_df

# %%
# 获取近期所有计划()
def get_plan_info():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = pymysql.connect(host='db-slave-modeltoufang-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
                p.*,
                b.image_id
            FROM
                db_ptom.ptom_third_plan p
            left join
                db_ptom.ptom_plan b
            on p.plan_id=b.plan_id
            WHERE
                p.game_id IN ({})
                AND p.media_id = 16
                AND p.platform = 1
                AND p.create_time>= date( NOW() - INTERVAL 1440 HOUR )
                AND p.create_time<= date(NOW())
                            AND p.plan_id >= (
                                select plan_id from db_ptom.ptom_plan
                                where create_time >= date( NOW() - INTERVAL 1440 HOUR )
                                and create_time <= date( NOW() - INTERVAL 1416 HOUR )
                                limit 1
                            )
    '''
    finalSql = sql.format(game_id)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
# 获取image_id,label_ids
def get_image_info():
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id,
            a.image_id,
            b.label_ids
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN
            db_data_ptom.ptom_image_info b
        on a.image_id = b.image_id
        WHERE
            a.game_id IN ( SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL ) 
            AND a.media_id = 16 
            AND a.create_time >= date( NOW() - INTERVAL 1440 HOUR ) 
        GROUP BY
            a.chl_user_id,
            a.source_id,
            a.image_id
    '''
    cur.execute(sql)
    result_df = pd.read_sql(sql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
def get_launch_report():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id AS source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount as roi,
            b.pay_role_user_num / b.create_role_num as pay_rate
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN db_stdata.st_lauch_report b ON a.chl_user_id = b.channel_id 
            AND a.source_id = b.source_id 
        WHERE
            a.create_time >= date( NOW() - INTERVAL 1440 HOUR ) 
            AND b.tdate >= date( NOW() - INTERVAL 1440 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 16
            AND b.game_id IN ({})
            AND b.amount >= 500
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')

    return result_df

# %%
# 解析json
def get_plan_json(plan_info):
    plan_info.drop(['inventory_type', 'budget', 'bid_mode'], axis=1, inplace=True)
    plan_info.dropna(how='all', inplace=True, axis=1)
    plan_info.dropna(subset=['ad_info'], inplace=True)

    plan_info['ad_info'] = plan_info['ad_info'].apply(json.loads)
    temp = plan_info['ad_info'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('ad_info', axis=1, inplace=True)

    temp = plan_info['targeting'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('targeting', axis=1, inplace=True)

    temp = plan_info['deep_conversion_spec'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('deep_conversion_spec', axis=1, inplace=True)

    temp = plan_info['behavior_or_interest'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('behavior_or_interest', axis=1, inplace=True)
    plan_info.drop(0, axis=1, inplace=True)

    temp = plan_info['intention'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('intention', axis=1, inplace=True)
    plan_info = plan_info.rename(columns={'targeting_tags': 'intention_targeting_tags'})
    plan_info.drop(0, axis=1, inplace=True)

    temp = plan_info['interest'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('interest', axis=1, inplace=True)
    plan_info = plan_info.rename(
        columns={'category_id_list': 'interest_category_id_list', 'keyword_list': 'interest_keyword_list',
                 'targeting_tags': 'interest_targeting_tags'})
    plan_info.drop(0, axis=1, inplace=True)

    temp = plan_info['behavior'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('behavior', axis=1, inplace=True)
    temp = plan_info[0].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop(0, axis=1, inplace=True)
    plan_info = plan_info.rename(columns={'category_id_list': 'behavior_category_id_list',
                                          'intensity': 'behavior_intensity',
                                          'keyword_list': 'behavior_keyword_list',
                                          'scene': 'behavior_scene',
                                          'targeting_tags': 'behavior_targeting_tags',
                                          'time_window': 'behavior_time_window'})

    temp = plan_info['excluded_converted_audience'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('excluded_converted_audience', axis=1, inplace=True)
    plan_info.drop(0, axis=1, inplace=True)

    temp = plan_info['geo_location'].apply(pd.Series)
    plan_info = pd.concat([plan_info, temp], axis=1)
    plan_info.drop('geo_location', axis=1, inplace=True)
    plan_info.drop(0, axis=1, inplace=True)

    # 过滤一对多计划
    plan_info['ad_id_count'] = plan_info.groupby('plan_id')['ad_id'].transform('count')
    plan_info = plan_info[plan_info['ad_id_count'] == 1]

    # 删除纯买激活的计划
    plan_info = plan_info[~((plan_info['deep_conversion_type'].isna()) & (
            plan_info['optimization_goal'] == 'OPTIMIZATIONGOAL_APP_ACTIVATE'))]
    # 删除auto_audience=True 的记录，并且删除auto_audience字段
    plan_info[plan_info['auto_audience'] == False]
    plan_info = plan_info[['ad_account_id', 'game_id', 'channel_id', 'source_id', 'budget_mode',
                           'create_time', 'image_id', 'optimization_goal', 'time_series',
                           'bid_strategy', 'bid_amount', 'daily_budget', 'expand_enabled',
                           'expand_targeting', 'device_price', 'app_install_status',
                           'gender', 'game_consumption_level', 'age', 'network_type',
                           'deep_conversion_type', 'deep_conversion_behavior_spec',
                           'deep_conversion_worth_spec', 'intention_targeting_tags',
                           'interest_category_id_list', 'interest_keyword_list',
                           'behavior_category_id_list',
                           'behavior_intensity', 'behavior_keyword_list', 'behavior_scene',
                           'behavior_time_window',
                           'conversion_behavior_list', 'excluded_dimension', 'location_types',
                           'regions']]
    return plan_info

# %%
# 获取近期30天优化计划的创意数据
def get_creative():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modeltoufang-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/ 
       SELECT
            b.chl_user_id AS channel_id,
            b.source_id,
            b.image_id,
            a.creative_param
        FROM
            db_ptom.ptom_batch_ad_task a
            LEFT JOIN db_ptom.ptom_plan b ON a.plan_name = b.plan_name 
        WHERE
            a.media_id = 16 
            AND b.create_time >= date( NOW() - INTERVAL 1440 HOUR )    
            AND a.game_id IN ({})
            AND b.image_id is not null

    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result

# %%
# 获取score_image (分数大于550的image_id)
def get_score_image():
    conn = connect(host='192.168.0.97', port=10000, auth_mechanism='PLAIN', user='hadoop',
                   password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql_engine = 'set hive.execution.engine=tez'
    sql = 'select image_id,label_ids from dws.dws_image_score_d where media_id=16 and score>=500 and dt=CURRENT_DATE group by image_id,label_ids'
    cursor.execute(sql_engine)
    cursor.execute(sql)
    result = as_pandas(cursor)
    result['label_ids'] = result['label_ids'].astype(str)
    result['label_ids'] = result['label_ids'].apply(lambda x: x.strip('-1;') if '-1' in x else x)
    result['label_ids'] = pd.to_numeric(result['label_ids'], errors='coerce')

    # 关闭链接
    cursor.close()
    conn.close()

    return result['image_id'].values

# %%
# 获取近期计划的运营数据
def get_now_plan_roi():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.ad_account_id,
            b.channel_id,
            b.source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount AS roi,
            b.pay_role_user_num / b.create_role_num AS pay_rate 
        FROM
            db_data_ptom.ptom_plan a 
        left join
            db_stdata.st_lauch_report b
        on a.chl_user_id=b.channel_id and a.source_id=b.source_id
        WHERE
            b.tdate >= date( NOW() - INTERVAL 240 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 16 
            AND b.game_id IN ({}) 
            AND b.amount > 0  
            AND b.pay_role_user_num >= 1 
            AND b.new_role_money >= 6
            AND (b.new_role_money / b.amount)>=0.001
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')
#     result_df = result_df[result_df['roi'] >= 0.03]
    return result_df

# %%
def create_plan(df, score_image):
    # 选ad_account_id、image_id每个账号+素材8条
    game_id = 1001832
    # df = df[df['game_id'] == game_id]
    df = df[df['game_id'].isin([1001545, 1001465, 1001832])]
    ad_account_id_group = np.array([8499, 8500, 8501, 8502, 8503, 8504, 8505, 8506, 8507, 8508,
                                    8518, 8517, 8516, 8515, 8514, 8513, 8512, 8511, 8510, 8509])

    image_id_group = np.intersect1d(df['image_id'].unique(), score_image)

    print(image_id_group)
    df = df[df['image_id'].isin(image_id_group)]
    #     df = df[df['site_set'].notna()]

    plan = pd.DataFrame()
    for ad_account in ad_account_id_group:
        for image in image_id_group:
            #         print(image)
            temp = pd.DataFrame({'ad_account_id': [ad_account], 'image_id': [image]})
            plan = plan.append(temp)
    #         print(temp)
    plan = pd.DataFrame(np.repeat(plan.values, 10, axis=0), columns=plan.columns)

    plan['game_id'] = game_id

    # 选择预算，不限制预算
    plan['budget_mode'] = 0
    plan['daily_budget'] = 0

    # 选扩量方式expand_enabled、expand_targeting
    sample_df = df[['expand_enabled', 'expand_targeting']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选定向targeting
    sample_df = df[['device_price', 'app_install_status', 'gender', 'game_consumption_level', 'age', 'network_type',
                    'conversion_behavior_list', 'excluded_dimension', 'location_types', 'regions',
                    'intention_targeting_tags', 'interest_category_id_list', 'interest_keyword_list',
                    'behavior_category_id_list', 'behavior_intensity',
                    'behavior_keyword_list', 'behavior_scene', 'behavior_time_window']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选创意\出价方式、出价
    create_df = df[
        ['image_id', 'site_set', 'deep_link_url', 'adcreative_template_id', 'page_spec', 'page_type', 'link_page_spec',
         'link_name_type', 'link_page_type', 'promoted_object_id', 'profile_id', 'promoted_object_type',
         'automatic_site_enabled', 'label', 'adcreative_elements',
         'optimization_goal', 'bid_strategy', 'bid_amount', 'deep_conversion_type', 'deep_conversion_behavior_spec',
         'deep_conversion_worth_spec']]

    plan_ = pd.DataFrame()
    for image_id in image_id_group:
        plan_1 = plan[plan['image_id'] == image_id]
        create_df_1 = create_df[create_df['image_id'] == image_id]
        create_df_1['site_set'] = create_df_1['site_set'].map(str)
        create_df_1['weight'] = create_df_1.groupby(['site_set'])['image_id'].transform('count')

        sample_df_1 = create_df_1.sample(n=plan_1.shape[0], replace=True, weights=create_df_1['weight']).reset_index(
            drop=True)
        sample_df_1.drop(['image_id', 'weight'], axis=1, inplace=True)

        plan_1 = plan_1.reset_index(drop=True)
        sample_df_1 = sample_df_1.reset_index(drop=True)
        plan_1 = pd.concat([plan_1, sample_df_1], axis=1)
        plan_ = plan_.append(plan_1)

    plan = plan_
    plan['site_set'] = plan['site_set'].apply(ast.literal_eval)

    # 选time_series
    cols = ['time_series']
    for col in cols:
        count_df = pd.DataFrame(data=df[col].value_counts()).reset_index()
        count_df.columns = ['col', 'counts']
        count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
        plan[col] = plan.apply(lambda x: np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0],
                               axis=1)

    plan['promoted_object_id'] = '2000001805'
    plan['create_time'] = pd.to_datetime(pd.datetime.now())
    plan['create_date'] = pd.to_datetime(pd.datetime.now().date())
    plan = plan.reset_index(drop=True)
    return plan

# %%
# 对列表内容进行编码
def get_mutil_feature(data):
    cols = ['behavior_category_id_list', 'behavior_intensity', 'behavior_keyword_list',
            'intention_targeting_tags', 'interest_category_id_list', 'interest_keyword_list']
    for col in cols:
        data[col] = data[col].apply(lambda x: x if x == x else [])
        data = data.join(data[col].str.join('|').str.get_dummies().add_prefix(col + '_').reset_index(drop=True))
        data.drop(col, axis=1, inplace=True)
    return data

# %%
plan_info = get_plan_info()
plan_info = get_plan_json(plan_info)
creative_info = get_creative()
image_info = get_image_info()
launch_report = get_launch_report()
creative_info['creative_param'] = creative_info['creative_param'].apply(json.loads)
temp = creative_info['creative_param'].apply(pd.Series)
if 'image_id' in temp.columns:
    temp = temp.drop('image_id', axis=1)
creative_info = pd.concat([creative_info, temp], axis=1)
creative_info.drop('creative_param', axis=1, inplace=True)
creative_info.drop(['title', 'adcreative_template_parent', 'idea_type', 'adcreative_name', 'ideaName', '_creative'],
                   axis=1, inplace=True)
creative_info['adcreative_elements_array'] = creative_info['adcreative_elements_array'].apply(lambda x: x[0])
creative_info['adcreative_elements'] = creative_info['adcreative_elements_array'].apply(
    lambda x: x['adcreative_elements'])
creative_info.drop('adcreative_elements_array', axis=1, inplace=True)
creative_info = creative_info[['channel_id', 'source_id', 'image_id', 'deep_link_url',
                               'adcreative_template_id', 'page_spec', 'page_type', 'site_set', 'label',
                               'promoted_object_id', 'promoted_object_type', 'automatic_site_enabled',
                               'link_name_type', 'link_page_type', 'profile_id', 'link_page_spec',
                               'adcreative_elements']]
plan_info = pd.merge(plan_info.drop(['image_id'], axis=1), creative_info, on=['channel_id', 'source_id'],
                     how='inner')
plan_info.dropna(subset=['image_id'], inplace=True)
plan_info['image_id'] = plan_info['image_id'].astype(int)
plan_info['adcreative_template_id'] = plan_info['adcreative_template_id'].astype(int)
plan_info['profile_id'] = plan_info['profile_id'].apply(lambda x: x if x != x else str(int(x)))
plan_info['create_time'] = pd.to_datetime(plan_info['create_time'])
plan_info_current = plan_info[plan_info['create_time'] >= pd.datetime.now() - pd.DateOffset(30)]
now_plan_roi = get_now_plan_roi()
score_image = get_score_image()
image_info = image_info[image_info['image_id'].notna()]
image_info['image_id'] = image_info['image_id'].astype(int)
df_create = pd.merge(plan_info_current, image_info, on=['channel_id', 'source_id', 'image_id'], how='left')
df_create = pd.merge(df_create, now_plan_roi.drop(['ad_account_id'], axis=1), on=['channel_id', 'source_id'],
                     how='inner')
df_create = df_create[df_create['site_set'].notna()]

# %%
def doSubStr(x):
    if '罗马争端' in x:
        res = re.sub('罗马争端', '亚洲王朝', x)
    elif '伐木时代' in x:
        res = re.sub('伐木时代', '亚洲王朝', x)
    elif '罗马单机版' in x:
        res = re.sub('罗马单机版', '亚洲王朝', x)
    elif '罗马：单机版' in x:
        res = re.sub('罗马：单机版', '亚洲王朝', x)
    elif '帝国：单机加强版' in x:
        res = re.sub('帝国：单机加强版', '亚洲王朝', x)  
    elif '帝国纪元：单机版' in x:
        res = re.sub('帝国纪元：单机版', '亚洲王朝', x)
    elif '帝国纪元' in x:
        res = re.sub('帝国纪元', '亚洲王朝', x)
    elif '帝国' in x:
        res = re.sub('帝国', '帝王', x)
    else:
        res = x
    return res

# %%
df_create['adcreative_elements'] = df_create['adcreative_elements'].map(str)
df_create['adcreative_elements'] = df_create['adcreative_elements'].apply(doSubStr)
df_create['adcreative_elements'] = df_create['adcreative_elements'].apply(ast.literal_eval)

# %%
df_create['adcreative_elements'].value_counts()
# Out:
# {'short_video_struct': {'short_video1': 91443}, 'title': '沦落荒岛，你该如何扩充人口，是发展成部落还是走向强国！'}                                                                                                                                                                                                     14
# {'image': 100158, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 100158, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                      11
# {'image': 112200, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 112200, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       7
# {'image': 111065, 'description': '开局5个农民，发展生产，升级建筑，带你重回20年前的罗马时代！', 'video': 111065, 'button_text': '立即下载', 'title': '开局荒岛，3天建立你的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                  7
# {'short_video_struct': {'short_video1': 74665}, 'title': '帝王高清复刻版，1：1还原端游，开局5农民，多久建立帝王？'}                                                                                                                                                                                                    6
# {'short_video_struct': {'short_video1': 114748}, 'title': '开局一座岛，种田造房，白手起家，几天你能称霸全服？'}                                                                                                                                                                                                       4
# {'image': 111548, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 111548, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       4
# {'image': 111564, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 111564, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       4
# {'image': 109517, 'description': '开局5个农民，发展生产，升级建筑，带你重回20年前的罗马时代！', 'video': 109517, 'button_text': '立即下载', 'title': '开局荒岛，3天建立你的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                  4
# {'short_video_struct': {'short_video1': 75543}, 'title': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！'}                                                                                                                                                                                                       4
# {'image': 117385, 'description': '还原经典，开局5个农民，伐木采矿，造兵攻城，建造王国！', 'video': 117385, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                          3
# {'image': 115319, 'description': '开局5农民，伐木种田，采矿贸易，3天打造属于自己的文明强国！', 'video': 115319, 'button_text': '立即下载', 'title': '开局5农民，3天建立文明强国！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                  3
# {'image': 97395, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 97395, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                        2
# {'image': 115838, 'description': '荒岛开局，伐木种植，狩猎捕鱼，发展人口，罗马时代等你建造！', 'video': 115838, 'button_text': '立即下载', 'title': 'SLG大作打造属于自己的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                   2
# {'image': 117020, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 117020, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        2
# {'image': 113796, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 113796, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       2
# {'image': 115916, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 115916, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                              2
# {'corporate': {'corporate_img': 74721, 'corporate_name': '亚洲王朝'}, 'video': 94076, 'title': '开局5农民，建立你的帝王'}                                                                                                                                                                                   2
# {'image': 114947, 'bottom_text': '福利礼包：ch666', 'description': '开局5农民，种田造房，伐木狩猎，武将招募，三天打造罗马文明！', 'video': 114947, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                      2
# {'short_video_struct': {'short_video1': 114899}, 'title': '沦落荒岛，你该如何扩充人口，是发展成部落还是走向强国！'}                                                                                                                                                                                                     2
# {'image': 111441, 'description': '苦等20年，终于出手游了！满满的儿时回忆，老玩家已感动哭！', 'video': 111441, 'button_text': '立即下载', 'title': '一起征战世界文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                          2
# {'image': 113262, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 113262, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        2
# {'image': 97081, 'description': '2021年度策略大作，资源全靠打，一键造兵，一天秒升帝王时代！', 'video': 115455, 'button_text': '立即下载', 'label': [{'content': '战争策略'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                   2
# {'image': 116647, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116647, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                                      2
# {'image': 100919, 'description': '帝王出手游了！1:1还原端游，开局5农民，打造你的专属帝王！', 'video': 100919, 'button_text': '立即下载', 'label': [{'content': '战争策略'}, {'content': '高策略手游'}, {'content': '经典巨作'}], 'title': '帝王策略单机版，等你来战', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                          2
# {'corporate': {'corporate_img': 74721, 'corporate_name': '亚洲王朝'}, 'video': 98212, 'title': '从荒岛到帝王，你需要多久'}                                                                                                                                                                                   2
# {'image': 95764, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸帝王！', 'video': 95764, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                         2
# {'image': 115388, 'description': '开局一块地，修水建房，自由建造，伐木建造，发展属于你的文明！', 'video': 115388, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       2
# {'image': 114798, 'description': '沦落荒岛，你该如何扩充人口，是发展成部落还是走向强国！', 'video': 114798, 'button_text': '立即下载', 'title': '苦等20年，手游终于出了！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                       2
# {'image': 115413, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 115413, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       1
# {'image': 111779, 'description': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！', 'video': 111779, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                            1
# {'image': 106432, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 106432, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 116422, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 116422, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                              1
# {'image': 116647, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116647, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 102543, 'description': '开局2个农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 102543, 'button_text': '立即下载', 'title': '开局5农民，三天打造罗马文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                       1
# {'image': 111966, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 111966, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        1
# {'image': 108919, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 108919, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                               1
# {'image': 117118, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 117118, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 115685, 'description': '开局5农民，伐木种田，采矿贸易，3天打造帝王文明！', 'video': 115685, 'button_text': '立即下载', 'title': '开局5农民，3天打造帝王文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                       1
# {'image': 114947, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 114947, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        1
# {'image': 115859, 'description': '经典回归，采集物资、填海造陆、发展科技、打造专属王国！', 'video': 115859, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                        1
# {'image': 117020, 'bottom_text': '福利礼包：ch666', 'description': '开局5农民，种田造房，伐木狩猎，武将招募，三天打造罗马文明！', 'video': 117020, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                      1
# {'image': 114883, 'description': '下班无聊？就来玩亚洲王朝单机版，采集伐木，一天秒升帝王时代', 'video': 114883, 'button_text': '立即下载', 'label': [{'content': '高策略手游'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                  1
# {'image': 116465, 'description': '小时候玩的游戏终于出手游了！开局5个农民，建立你的文明！', 'video': 116465, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                         1
# {'image': 114947, 'description': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！', 'video': 114947, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                            1
# {'image': 95534, 'description': '开局流落荒岛，伐木采集，自由建造，你如何打造最强文明？', 'video': 95534, 'button_text': '立即下载', 'title': '开局荒岛，3天建立强大王国', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                        1
# {'image': 108919, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 108919, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                              1
# {'image': 112931, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 112931, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        1
# {'image': 116695, 'description': '开局农民采集伐木，建造军队，你能建造属于你的强大帝王吗？', 'video': 116695, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 116465, 'description': '开局一块地，修水建房，自由建造，伐木建造，发展属于你的文明！', 'video': 116465, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       1
# {'image': 111494, 'description': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！', 'video': 111494, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                            1
# {'end_page': {'end_page_desc': '2021年热门战争策略手游！', 'end_page_type': 'END_PAGE_AVATAR_NICKNAME_HIGHLIGHT'}, 'corporate': {'corporate_img': 74721, 'corporate_name': '亚洲王朝'}, 'description': '苦等20年，终于等到这良心策略手游', 'caption': '开局荒岛，多久能建立属于你的文明', 'video': 106609, 'title': '2021年热门战争策略手游！'}     1
# {'image': 116647, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 116647, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        1
# {'image': 116459, 'description': '下班无聊？就来玩亚洲王朝单机版，采集伐木，一天秒升帝王时代', 'video': 116459, 'button_text': '立即下载', 'label': [{'content': '高策略手游'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                  1
# {'image': 116731, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116731, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 111779, 'bottom_text': '福利礼包：ch666', 'description': '开局5农民，种田造房，伐木狩猎，武将招募，7天打造罗马文明！', 'video': 111779, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                      1
# {'image': 117447, 'description': '开局农民采集伐木，建造军队，你能建造属于你的强大帝王吗？', 'video': 117447, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 105953, 'bottom_text': '大家都在玩！', 'description': '“老男孩”们的坚守！被“后浪”掩埋的RTS游戏，帝王出手游了！', 'video': 105953, 'button_text': '立即下载', 'label': [{'content': '战争策略'}], 'title': '帝王单机策略手游，等你来战', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                          1
# {'image': 116866, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116866, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 111310, 'bottom_text': '福利礼包：ch666', 'description': '开局5农民，种田造房，伐木狩猎，武将招募，7天打造罗马文明！', 'video': 111310, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                      1
# {'image': 115183, 'description': '占个小岛当岛主，刷钱刷资源，升级主城，发展人口，重新打造文明', 'video': 115183, 'button_text': '立即下载', 'label': [{'content': '高策略手游'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                  1
# {'image': 116177, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116177, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 117385, 'description': '小时候玩的游戏终于出手游了！开局5个农民，建立你的文明！', 'video': 117385, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                         1
# {'image': 112774, 'description': '2021年度策略大作，开局3农民，资源全靠打，一天秒升帝王时代！', 'video': 112774, 'button_text': '立即下载', 'label': [{'content': '战争策略'}, {'content': '高策略手游'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                          1
# {'image': 110066, 'description': '荒岛求生，伐木、挖矿、狩猎，快来建立你的王国！', 'video': 110066, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                               1
# {'image': 111310, 'description': '荒岛求生，伐木、挖矿、狩猎，快来建立你的王国！', 'video': 111310, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                               1
# {'image': 115858, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 115858, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 113928, 'description': '荒岛开局，伐木种植，狩猎捕鱼，发展人口，罗马时代等你建造！', 'video': 113928, 'button_text': '立即下载', 'title': 'SLG大作打造属于自己的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                   1
# {'image': 111310, 'description': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！', 'video': 111310, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                            1
# {'image': 79576, 'description': '开局5农民开启你的王国王朝！', 'video': 79576, 'button_text': '立即下载', 'title': '征战文明，约战兄弟再创王朝！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                                    1
# {'image': 115320, 'description': '2021年度策略大作，资源全靠打，一键造兵，一天秒升帝王时代！', 'video': 115320, 'button_text': '立即下载', 'label': [{'content': '战争策略'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                  1
# {'image': 113262, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 113262, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 107288, 'description': '小时候玩的帝王终于出手游了！', 'video': 107288, 'button_text': '立即下载', 'title': '正版授权，策略手游！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                                      1
# {'image': 117277, 'description': '开局只是个小农民，种田造房，伐木狩猎，三天打造文明时代！', 'video': 117277, 'button_text': '立即下载', 'title': '开局荒岛，3天建立强大王国', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                      1
# {'image': 116180, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 116180, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 117432, 'description': '升级主城发展人口，打造新文明', 'video': 117432, 'button_text': '立即下载', 'title': '探索世界建立起自己的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                                   1
# {'image': 117385, 'description': '探索世界建立起自己的文明！', 'video': 117385, 'button_text': '立即下载', 'title': '升级主城发展人口，打造新文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                                   1
# {'image': 116186, 'description': '荒岛求生，伐木、挖矿、狩猎，快来建立你的王国！', 'video': 116186, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                               1
# {'image': 116099, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116099, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                                      1
# {'image': 117444, 'description': '经典回归，采集物资、填海造陆、发展科技、打造专属王国！', 'video': 117444, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                        1
# {'image': 106600, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 106600, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 115182, 'description': '开局5农民，伐木种田，采矿贸易，3天打造帝王文明！', 'video': 115182, 'button_text': '立即下载', 'title': '开局5农民，3天打造帝王文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                                                                                       1
# {'image': 115319, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 115319, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                       1
# {'image': 117268, 'description': '荒岛开局，伐木种植，狩猎捕鱼，发展人口，罗马时代等你建造！', 'video': 117268, 'button_text': '立即下载', 'title': 'SLG大作打造属于自己的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                   1
# {'image': 116187, 'description': '荒岛开局，伐木种植，狩猎捕鱼，发展人口，罗马时代等你建造！', 'video': 116187, 'button_text': '立即下载', 'title': 'SLG大作打造属于自己的文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                   1
# {'image': 116465, 'description': '2021年度策略大作，开局3农民，资源全靠打，一天秒升帝王时代！', 'video': 116465, 'button_text': '立即下载', 'label': [{'content': '战争策略'}, {'content': '高策略手游'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                          1
# {'image': 101800, 'description': '开局搭桥通路，自由探索，采集资源，扩张领土，建立你的王国！', 'video': 101800, 'button_text': '立即下载', 'title': '经典战争策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                          1
# {'image': 116900, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116900, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 100860, 'description': '小时候玩的帝王终于出手游了，开局5个农民，建立你的帝王!', 'button_text': '立即下载', 'title': '亚洲王朝，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                                          1
# {'image': 116905, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 116905, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                      1
# {'image': 114947, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 114947, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'short_video_struct': {'short_video1': 109552}, 'title': '开局一座岛，种田造房，白手起家，几天你能称霸全服？'}                                                                                                                                                                                                       1
# {'image': 112708, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 112708, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                                      1
# {'image': 117131, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 117131, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 97090, 'description': '小时候玩的帝王终于出手游了，开局5个农民，建立你的帝王!', 'button_text': '立即下载', 'title': '亚洲王朝，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                                           1
# {'image': 111310, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 111310, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                                      1
# {'image': 113120, 'description': '还原经典单机游戏，开局2个农民，采集资源，建造帝王时代！', 'video': 113120, 'button_text': '立即下载', 'title': '经典还原，3天升级王国', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                        1
# {'image': 111749, 'bottom_text': '福利礼包：ch666', 'description': '开局只是个小农民，种田狩猎，伐木造房，三天打造罗马文明！', 'video': 111749, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                        1
# {'image': 116842, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 116842, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 114032, 'description': '荒岛求生，伐木、挖矿、狩猎，快来建立你的王国！', 'video': 114032, 'button_text': '立即下载', 'title': '2021年热门战争策略手游！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                                                                          1
# {'image': 111063, 'description': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！', 'video': 111063, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                            1
# {'image': 111779, 'description': '荒岛求生，伐木、挖矿、狩猎，快来建立你的王国！', 'video': 111779, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                               1
# {'image': 112931, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 112931, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                                      1
# {'image': 117385, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 117385, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 116844}}                                                                                                              1
# {'image': 113375, 'description': '2021年度SLG大作！采集挖矿，伐木建造，打造属于自己的文明王国', 'video': 113375, 'button_text': '立即下载', 'title': '经典还原，3天打造王国', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 77446}}                                                                                                   1
# {'image': 117103, 'description': '伐木采集，捕鱼挖矿，建立你的王国', 'video': 117103, 'button_text': '立即下载', 'title': 'SLG文明策略手游', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                                                                      1
# {'image': 113262, 'bottom_text': '福利礼包：ch666', 'description': '开局5农民，种田造房，伐木狩猎，武将招募，三天打造罗马文明！', 'video': 113262, 'button_text': '立即下载', 'title': '不肝不氪，高度还原中世纪战争', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 79601}}                                                                      1
# Name: adcreative_elements, dtype: int64

# %%
# 先只跑首次付费，ROI没有权限  ## TODO:ROI
df_create = df_create[(df_create['optimization_goal'] == 'OPTIMIZATIONGOAL_APP_ACTIVATE') | (
            df_create['optimization_goal'] == 'OPTIMIZATIONGOAL_APP_PURCHASE')]

df_create.to_csv('./df_create.csv', index=0)
plan_create = create_plan(df_create, score_image)
# 过滤掉版本不是微信朋友圈，但是每次付费的计划

image_info.dropna(subset=['image_id'], inplace=True)
image_info['image_id'] = image_info['image_id'].astype(int)
plan_create = pd.merge(plan_create, image_info[['image_id', 'label_ids']].drop_duplicates(), on='image_id',
                       how='left')

df = pd.merge(plan_info, image_info, on=['channel_id', 'source_id', 'image_id'], how='left')
df.dropna(subset=['image_id'], inplace=True)
df = pd.merge(df, launch_report, on=['channel_id', 'source_id'], how='left')
df.drop(df[df['tdate'].isna()].index, inplace=True)
df = df[df['amount'] >= 500]

df['plan_label'] = df.apply(lambda x: 1 if x.new_role_money / x.amount >= 0.015 else 0, axis=1)
df['ad_account_id'] = df['ad_account_id'].astype('int')
df['image_id'] = df['image_id'].astype('int')
df.rename(columns={'tdate': 'create_date'}, inplace=True)
df['create_date'] = pd.to_datetime(df['create_date'])
df['create_time'] = pd.to_datetime(df['create_time'])

df.drop(['channel_id', 'source_id', 'budget_mode', 'bid_amount', 'daily_budget', 'deep_conversion_behavior_spec',
         'deep_conversion_worth_spec',
         'deep_link_url', 'page_spec', 'promoted_object_id', 'promoted_object_type', 'automatic_site_enabled',
         'link_page_type',
         'profile_id', 'link_page_spec', 'adcreative_elements', 'amount', 'roi', 'pay_rate',
         'new_role_money'], axis=1, inplace=True)

plan_create_train = plan_create.drop(['adcreative_elements', 'automatic_site_enabled', 'bid_amount',
                                      'budget_mode', 'daily_budget', 'deep_conversion_behavior_spec',
                                      'deep_conversion_worth_spec', 'deep_link_url', 'link_page_spec',
                                      'link_page_type', 'page_spec', 'profile_id', 'promoted_object_id',
                                      'promoted_object_type'], axis=1)
df['train_label'] = 1
plan_create_train['train_label'] = 0
plan_create_train['plan_label'] = -1

df = df.append(plan_create_train)

df['create_date'] = pd.to_datetime(df['create_date'])
df['ad_im_sort_id'] = df.groupby(['ad_account_id', 'image_id'])['create_time'].rank()
df['ad_game_sort_id'] = df.groupby(['ad_account_id', 'game_id'])['create_time'].rank()
df['im_ad_sort_id'] = df.groupby(['image_id', 'ad_account_id'])['create_time'].rank()

df = get_mutil_feature(df)

cat_cols = ['ad_account_id', 'game_id', 'optimization_goal', 'time_series', 'bid_strategy', 'expand_enabled',
            'expand_targeting',
            'device_price', 'app_install_status', 'gender', 'game_consumption_level', 'age', 'network_type',
            'deep_conversion_type',
            'behavior_scene', 'behavior_time_window', 'conversion_behavior_list', 'excluded_dimension',
            'location_types', 'regions',
            'image_id', 'adcreative_template_id', 'page_type', 'site_set', 'label', 'link_name_type', 'label_ids']

cat_cross = []
for col in tqdm_notebook(combinations(cat_cols, 2)):
    df[str(col[0]) + '_' + str(col[1])] = df[col[0]].map(str) + '_' + df[col[1]].map(str)
    cat_cross.append(str(col[0]) + '_' + str(col[1]))

for col in cat_cols + cat_cross:
    df[col] = df[col].astype(str)
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
# Out:
# [29785 29925 33634 35562 37131 37701 38837 38977 38987 38996 39088 39210
#  39415 39429 39436]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
train_data = df[df['train_label'] == 1]
test_data = df[df['train_label'] == 0]
train_data.drop(['train_label', 'create_time', 'create_date'], axis=1, inplace=True)
test_data.drop(['train_label', 'create_time', 'create_date'], axis=1, inplace=True)

target = train_data['plan_label']
features = train_data.drop(['plan_label'], axis=1)
features.columns = ['c' + str(i) for i in range(features.shape[1])]
X_val, x_test, Y_val, y_test = train_test_split(features, target, test_size=0.3)

params = {
    "objective": "binary",
    "boosting_type": "gbdt",
    "learning_rate": 0.01,
    "max_depth": 8,
    "num_leaves": 55,
    "max_bin": 255,
    "min_data_in_leaf": 101,
    "min_child_samples": 15,
    "feature_fraction": 0.5,
    "bagging_fraction": 0.6,
    "bagging_freq": 20,
    "lambda_l1": 1e-05,
    "lambda_l2": 0,
    "min_split_gain": 0.0,
    "metric": "auc",
    'is_unbalance': True
}

train_data = lgb.Dataset(X_val, label=Y_val)
val_data = lgb.Dataset(x_test, label=y_test, reference=train_data)
model = lgb.train(params, train_data, num_boost_round=8000, early_stopping_rounds=100,
                  valid_sets=[train_data, val_data])

features_test = test_data.drop(['label'], axis=1)
y_predict = model.predict(features_test)

plan_create['prob'] = y_predict
threshold = pd.Series(y_predict).sort_values(ascending=False).reset_index(drop=True)[int(y_predict.shape[0] * 0.4)]

plan_result = plan_create[plan_create['prob'] >= threshold]
plan_result['rank_ad_im'] = plan_result.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False,
                                                                                            method='first')
plan_result = plan_result[plan_result['rank_ad_im'] <= 1]

plan_create['rank_ad_im'] = plan_create.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False,
                                                                                            method='first')
plan_result_pr = plan_create[plan_create['rank_ad_im'] <= 1]

ad_num = plan_result['ad_account_id'].value_counts()
for ad in np.setdiff1d(plan_create['ad_account_id'].values, ad_num[ad_num > 2].index):
    add_plan = plan_result_pr[plan_result_pr['ad_account_id'] == ad].sort_values('prob', ascending=False)[0:3]
    plan_result = plan_result.append(add_plan)

ad_num = plan_result['image_id'].value_counts()
for ad in np.setdiff1d(plan_create['image_id'].values, ad_num[ad_num >= 2].index):
    add_plan = plan_result_pr[plan_result_pr['image_id'] == ad].sort_values('prob', ascending=False)[0:3]
    plan_result = plan_result.append(add_plan)

plan_result['weight'] = plan_result.groupby(['ad_account_id'])['game_id'].transform('count')
plan_result['site_set'] = plan_result['site_set'].map(str)

if plan_result.shape[0] > 80:
    plan_result = plan_result.sample(80, weights=plan_result['weight'])

ad_num = plan_result['image_id'].value_counts()
for ad in np.setdiff1d(plan_create['image_id'].values, ad_num[ad_num >= 2].index):
    add_plan = plan_result_pr[plan_result_pr['image_id'] == ad].sort_values('prob', ascending=False)[0:2]
    add_plan['site_set'] = add_plan['site_set'].map(str)
    plan_result = plan_result.append(add_plan)

plan_result['rank_ad_im'] = plan_result.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False,
                                                                                            method='first')
plan_result = plan_result[plan_result['rank_ad_im'] <= 1]

plan_result = plan_result.drop(['create_time', 'create_date', 'prob', 'rank_ad_im', 'label_ids', 'weight'], axis=1)

# [SITE_SET_WECHAT] 公众号和小程序adcreative_template_id只跑1480、560、720、721、1064五种
plan_result['site_set'] = plan_result['site_set'].map(str)
plan_result = plan_result[~((plan_result['site_set'] == "['SITE_SET_WECHAT']") & (
    ~plan_result['adcreative_template_id'].isin([1480, 560, 720, 721, 1064])))]

# 屏蔽武汉
plan_result['regions'] = plan_result['regions'].apply(
    lambda x: x if x == x else [710000, 540000, 630000, 510000, 450000, 320000, 220000, 370000, 340000, 150000,
                                140000, 420700,
                                422800, 421100, 420200, 420800, 421000, 429005, 429021, 420300, 421300, 429006,
                                429004, 421200,
                                420600, 420900, 420500, 130000, 360000, 310000, 330000, 820000, 650000, 350000,
                                120000, 110000,
                                640000, 530000, 210000, 610000, 520000, 810000, 230000, 460000, 440000, 500000,
                                410000, 620000, 430000])
plan_result['location_types'] = plan_result['location_types'].apply(lambda x: ['LIVE_IN'])
# 修改落地页ID
plan_result['page_spec'] = plan_result.apply(
    lambda x: {'override_canvas_head_option': 'OPTION_CREATIVE_OVERRIDE_CANVAS',
               'page_id': '2268166449'} if x.site_set == "['SITE_SET_MOMENTS']"
    else ({'override_canvas_head_option': 'OPTION_CREATIVE_OVERRIDE_CANVAS',
           'page_id': '2268167873'} if x.site_set == "['SITE_SET_WECHAT']" else np.nan), axis=1)
plan_result['link_page_spec'] = plan_result.apply(
    lambda x: {'page_id': '2268166449'} if x.site_set == "['SITE_SET_MOMENTS']"
    else ({'page_id': '2268167873'} if x.site_set == "['SITE_SET_WECHAT']" else np.nan), axis=1)

# 朋友圈头像ID
plan_result['ad_account_id'] = plan_result['ad_account_id'].map(str)
plan_result_1 = plan_result[plan_result['site_set'] == "['SITE_SET_MOMENTS']"]
plan_result_2 = plan_result[plan_result['site_set'] != "['SITE_SET_MOMENTS']"]
# profile_id_dict = {'8499': '464718', '8500': '464737', '8501': '464749', '8502': '464757', '8503': '464767',
#                    '8504': '464773', '8505': '464779', '8506': '464788', '8507': '464796', '8508': '464803',
#                    '8518': '520038', '8517': '520048', '8516': '520069', '8515': '520082', '8514': '520101',
#                    '8513': '520116', '8512': '520120', '8511': '520133', '8510': '520147', '8509': '520154'}
profile_id_dict = {'8499': '549404', '8500': '549423', '8501': '549434', '8502': '549448', '8503': '549452',
                   '8504': '549459', '8505': '549465', '8506': '549474', '8507': '549479', '8508': '549487',
                   '8518': '549495', '8517': '549514', '8516': '549522', '8515': '549534', '8514': '549545',
                   '8513': '549564', '8512': '549571', '8511': '549578', '8510': '549586', '8509': '549590'}
plan_result_1['profile_id'] = plan_result_1['ad_account_id'].map(profile_id_dict)

plan_result = plan_result_1.append(plan_result_2)
plan_result = plan_result.reset_index(drop=True)
# Out:
# [1]	training's auc: 0.664938	valid_1's auc: 0.583145
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.671758	valid_1's auc: 0.580195
# [3]	training's auc: 0.693728	valid_1's auc: 0.574542
# [4]	training's auc: 0.693664	valid_1's auc: 0.574671
# [5]	training's auc: 0.692466	valid_1's auc: 0.570321
# [6]	training's auc: 0.701458	valid_1's auc: 0.572744
# [7]	training's auc: 0.702894	valid_1's auc: 0.576092
# [8]	training's auc: 0.704303	valid_1's auc: 0.568781
# [9]	training's auc: 0.707609	valid_1's auc: 0.57746
# [10]	training's auc: 0.703588	valid_1's auc: 0.577524
# [11]	training's auc: 0.703572	valid_1's auc: 0.579183
# [12]	training's auc: 0.705103	valid_1's auc: 0.57746
# [13]	training's auc: 0.707347	valid_1's auc: 0.578547
# [14]	training's auc: 0.714031	valid_1's auc: 0.582682
# [15]	training's auc: 0.713668	valid_1's auc: 0.584232
# [16]	training's auc: 0.71437	valid_1's auc: 0.58406
# [17]	training's auc: 0.714157	valid_1's auc: 0.582176
# [18]	training's auc: 0.715058	valid_1's auc: 0.588539
# [19]	training's auc: 0.716756	valid_1's auc: 0.588669
# [20]	training's auc: 0.72032	valid_1's auc: 0.589584
# [21]	training's auc: 0.726325	valid_1's auc: 0.589347
# [22]	training's auc: 0.729365	valid_1's auc: 0.588722
# [23]	training's auc: 0.732505	valid_1's auc: 0.590639
# [24]	training's auc: 0.734324	valid_1's auc: 0.593158
# [25]	training's auc: 0.739016	valid_1's auc: 0.59458
# [26]	training's auc: 0.742031	valid_1's auc: 0.598047
# [27]	training's auc: 0.744978	valid_1's auc: 0.601062
# [28]	training's auc: 0.748766	valid_1's auc: 0.602967
# [29]	training's auc: 0.753223	valid_1's auc: 0.606112
# [30]	training's auc: 0.756353	valid_1's auc: 0.606155
# [31]	training's auc: 0.757977	valid_1's auc: 0.607576
# [32]	training's auc: 0.759863	valid_1's auc: 0.608502
# [33]	training's auc: 0.76007	valid_1's auc: 0.609212
# [34]	training's auc: 0.762476	valid_1's auc: 0.610117
# [35]	training's auc: 0.764795	valid_1's auc: 0.610806
# [36]	training's auc: 0.764155	valid_1's auc: 0.611474
# [37]	training's auc: 0.765771	valid_1's auc: 0.612787
# [38]	training's auc: 0.767543	valid_1's auc: 0.615673
# [39]	training's auc: 0.767095	valid_1's auc: 0.615888
# [40]	training's auc: 0.766598	valid_1's auc: 0.616556
# [41]	training's auc: 0.766965	valid_1's auc: 0.616997
# [42]	training's auc: 0.766662	valid_1's auc: 0.617536
# [43]	training's auc: 0.766631	valid_1's auc: 0.619205
# [44]	training's auc: 0.767025	valid_1's auc: 0.619355
# [45]	training's auc: 0.768113	valid_1's auc: 0.61844
# [46]	training's auc: 0.76941	valid_1's auc: 0.620357
# [47]	training's auc: 0.769207	valid_1's auc: 0.622015
# [48]	training's auc: 0.769408	valid_1's auc: 0.622209
# [49]	training's auc: 0.769889	valid_1's auc: 0.621003
# [50]	training's auc: 0.770396	valid_1's auc: 0.620227
# [51]	training's auc: 0.770608	valid_1's auc: 0.62069
# [52]	training's auc: 0.770334	valid_1's auc: 0.620518
# [53]	training's auc: 0.770682	valid_1's auc: 0.618752
# [54]	training's auc: 0.772162	valid_1's auc: 0.619506
# [55]	training's auc: 0.771292	valid_1's auc: 0.620281
# [56]	training's auc: 0.771582	valid_1's auc: 0.620023
# [57]	training's auc: 0.772668	valid_1's auc: 0.619226
# [58]	training's auc: 0.772359	valid_1's auc: 0.618968
# [59]	training's auc: 0.77238	valid_1's auc: 0.620647
# [60]	training's auc: 0.772402	valid_1's auc: 0.620454
# [61]	training's auc: 0.774893	valid_1's auc: 0.621056
# [62]	training's auc: 0.776737	valid_1's auc: 0.62054
# [63]	training's auc: 0.778596	valid_1's auc: 0.62153
# [64]	training's auc: 0.780735	valid_1's auc: 0.620949
# [65]	training's auc: 0.782878	valid_1's auc: 0.621207
# [66]	training's auc: 0.784515	valid_1's auc: 0.621573
# [67]	training's auc: 0.785634	valid_1's auc: 0.623167
# [68]	training's auc: 0.786848	valid_1's auc: 0.622941
# [69]	training's auc: 0.788348	valid_1's auc: 0.623716
# [70]	training's auc: 0.78897	valid_1's auc: 0.623231
# [71]	training's auc: 0.790694	valid_1's auc: 0.623231
# [72]	training's auc: 0.791853	valid_1's auc: 0.622349
# [73]	training's auc: 0.792321	valid_1's auc: 0.622995
# [74]	training's auc: 0.793701	valid_1's auc: 0.623167
# [75]	training's auc: 0.795458	valid_1's auc: 0.622908
# [76]	training's auc: 0.795558	valid_1's auc: 0.623447
# [77]	training's auc: 0.796544	valid_1's auc: 0.623081
# [78]	training's auc: 0.797311	valid_1's auc: 0.623705
# [79]	training's auc: 0.798161	valid_1's auc: 0.624017
# [80]	training's auc: 0.798977	valid_1's auc: 0.622725
# [81]	training's auc: 0.799491	valid_1's auc: 0.622618
# [82]	training's auc: 0.799789	valid_1's auc: 0.622532
# [83]	training's auc: 0.800981	valid_1's auc: 0.621756
# [84]	training's auc: 0.801487	valid_1's auc: 0.621035
# [85]	training's auc: 0.802407	valid_1's auc: 0.620755
# [86]	training's auc: 0.803426	valid_1's auc: 0.620303
# [87]	training's auc: 0.80341	valid_1's auc: 0.621078
# [88]	training's auc: 0.803675	valid_1's auc: 0.6211
# [89]	training's auc: 0.804272	valid_1's auc: 0.620669
# [90]	training's auc: 0.804902	valid_1's auc: 0.621595
# [91]	training's auc: 0.805809	valid_1's auc: 0.620647
# [92]	training's auc: 0.806421	valid_1's auc: 0.62097
# [93]	training's auc: 0.806719	valid_1's auc: 0.621315
# [94]	training's auc: 0.807117	valid_1's auc: 0.621315
# [95]	training's auc: 0.807536	valid_1's auc: 0.620669
# [96]	training's auc: 0.808021	valid_1's auc: 0.621509
# [97]	training's auc: 0.807735	valid_1's auc: 0.621024
# [98]	training's auc: 0.808381	valid_1's auc: 0.621196
# [99]	training's auc: 0.809082	valid_1's auc: 0.620077
# [100]	training's auc: 0.809247	valid_1's auc: 0.619904
# [101]	training's auc: 0.80977	valid_1's auc: 0.619904
# [102]	training's auc: 0.810304	valid_1's auc: 0.619452
# [103]	training's auc: 0.810814	valid_1's auc: 0.61984
# [104]	training's auc: 0.811102	valid_1's auc: 0.620475
# [105]	training's auc: 0.811749	valid_1's auc: 0.620798
# [106]	training's auc: 0.812159	valid_1's auc: 0.620949
# [107]	training's auc: 0.813125	valid_1's auc: 0.620981
# [108]	training's auc: 0.813949	valid_1's auc: 0.621089
# [109]	training's auc: 0.813995	valid_1's auc: 0.62167
# [110]	training's auc: 0.814505	valid_1's auc: 0.622144
# [111]	training's auc: 0.814455	valid_1's auc: 0.621929
# [112]	training's auc: 0.814592	valid_1's auc: 0.62251
# [113]	training's auc: 0.815197	valid_1's auc: 0.62223
# [114]	training's auc: 0.815806	valid_1's auc: 0.622941
# [115]	training's auc: 0.815794	valid_1's auc: 0.624082
# [116]	training's auc: 0.815887	valid_1's auc: 0.623748
# [117]	training's auc: 0.81541	valid_1's auc: 0.62377
# [118]	training's auc: 0.815667	valid_1's auc: 0.623253
# [119]	training's auc: 0.815622	valid_1's auc: 0.623145
# [120]	training's auc: 0.815796	valid_1's auc: 0.623511
# [121]	training's auc: 0.815719	valid_1's auc: 0.622542
# [122]	training's auc: 0.815744	valid_1's auc: 0.622715
# [123]	training's auc: 0.815773	valid_1's auc: 0.622607
# [124]	training's auc: 0.815893	valid_1's auc: 0.622542
# [125]	training's auc: 0.816063	valid_1's auc: 0.621444
# [126]	training's auc: 0.815823	valid_1's auc: 0.622908
# [127]	training's auc: 0.81557	valid_1's auc: 0.622047
# [128]	training's auc: 0.815769	valid_1's auc: 0.621746
# [129]	training's auc: 0.815727	valid_1's auc: 0.621703
# [130]	training's auc: 0.815607	valid_1's auc: 0.622219
# [131]	training's auc: 0.815375	valid_1's auc: 0.621918
# [132]	training's auc: 0.815528	valid_1's auc: 0.621035
# [133]	training's auc: 0.815118	valid_1's auc: 0.62041
# [134]	training's auc: 0.815027	valid_1's auc: 0.621336
# [135]	training's auc: 0.814828	valid_1's auc: 0.62069
# [136]	training's auc: 0.814658	valid_1's auc: 0.620777
# [137]	training's auc: 0.813945	valid_1's auc: 0.620001
# [138]	training's auc: 0.81346	valid_1's auc: 0.619161
# [139]	training's auc: 0.812901	valid_1's auc: 0.619355
# [140]	training's auc: 0.812863	valid_1's auc: 0.618494
# [141]	training's auc: 0.813527	valid_1's auc: 0.619807
# [142]	training's auc: 0.814828	valid_1's auc: 0.620389
# [143]	training's auc: 0.81586	valid_1's auc: 0.620777
# [144]	training's auc: 0.816486	valid_1's auc: 0.621272
# [145]	training's auc: 0.81719	valid_1's auc: 0.621703
# [146]	training's auc: 0.817576	valid_1's auc: 0.622284
# [147]	training's auc: 0.818135	valid_1's auc: 0.622801
# [148]	training's auc: 0.818421	valid_1's auc: 0.622112
# [149]	training's auc: 0.818997	valid_1's auc: 0.62237
# [150]	training's auc: 0.819627	valid_1's auc: 0.62237
# [151]	training's auc: 0.820042	valid_1's auc: 0.622435
# [152]	training's auc: 0.820241	valid_1's auc: 0.622779
# [153]	training's auc: 0.820862	valid_1's auc: 0.622176
# [154]	training's auc: 0.821409	valid_1's auc: 0.622585
# [155]	training's auc: 0.821766	valid_1's auc: 0.622349
# [156]	training's auc: 0.821998	valid_1's auc: 0.621961
# [157]	training's auc: 0.822056	valid_1's auc: 0.621961
# [158]	training's auc: 0.822118	valid_1's auc: 0.621939
# [159]	training's auc: 0.822587	valid_1's auc: 0.621724
# [160]	training's auc: 0.822707	valid_1's auc: 0.62125
# [161]	training's auc: 0.823279	valid_1's auc: 0.621595
# [162]	training's auc: 0.82405	valid_1's auc: 0.621595
# [163]	training's auc: 0.8248	valid_1's auc: 0.621121
# [164]	training's auc: 0.825426	valid_1's auc: 0.621013
# [165]	training's auc: 0.825927	valid_1's auc: 0.621164
# [166]	training's auc: 0.826424	valid_1's auc: 0.620992
# [167]	training's auc: 0.826947	valid_1's auc: 0.620647
# [168]	training's auc: 0.82734	valid_1's auc: 0.620109
# [169]	training's auc: 0.827788	valid_1's auc: 0.620281
# [170]	training's auc: 0.828045	valid_1's auc: 0.620303
# [171]	training's auc: 0.828588	valid_1's auc: 0.619226
# [172]	training's auc: 0.82888	valid_1's auc: 0.618817
# [173]	training's auc: 0.829203	valid_1's auc: 0.619205
# [174]	training's auc: 0.829775	valid_1's auc: 0.619226
# [175]	training's auc: 0.829692	valid_1's auc: 0.619291
# [176]	training's auc: 0.829779	valid_1's auc: 0.619054
# [177]	training's auc: 0.829974	valid_1's auc: 0.619183
# [178]	training's auc: 0.830177	valid_1's auc: 0.619398
# [179]	training's auc: 0.830244	valid_1's auc: 0.619248
# [180]	training's auc: 0.830509	valid_1's auc: 0.619463
# [181]	training's auc: 0.831479	valid_1's auc: 0.619377
# [182]	training's auc: 0.832092	valid_1's auc: 0.618989
# [183]	training's auc: 0.832714	valid_1's auc: 0.618666
# [184]	training's auc: 0.83348	valid_1's auc: 0.618774
# [185]	training's auc: 0.834498	valid_1's auc: 0.618925
# [186]	training's auc: 0.834701	valid_1's auc: 0.619528
# [187]	training's auc: 0.835275	valid_1's auc: 0.619075
# [188]	training's auc: 0.835787	valid_1's auc: 0.618257
# [189]	training's auc: 0.836396	valid_1's auc: 0.618171
# [190]	training's auc: 0.836997	valid_1's auc: 0.618042
# [191]	training's auc: 0.837179	valid_1's auc: 0.617482
# [192]	training's auc: 0.83759	valid_1's auc: 0.618279
# [193]	training's auc: 0.838058	valid_1's auc: 0.618365
# [194]	training's auc: 0.83868	valid_1's auc: 0.618171
# [195]	training's auc: 0.839223	valid_1's auc: 0.617417
# [196]	training's auc: 0.839513	valid_1's auc: 0.616922
# [197]	training's auc: 0.83977	valid_1's auc: 0.616685
# [198]	training's auc: 0.839857	valid_1's auc: 0.616642
# [199]	training's auc: 0.840421	valid_1's auc: 0.616836
# [200]	training's auc: 0.840553	valid_1's auc: 0.616491
# [201]	training's auc: 0.841129	valid_1's auc: 0.616707
# [202]	training's auc: 0.841892	valid_1's auc: 0.61675
# [203]	training's auc: 0.842053	valid_1's auc: 0.616233
# [204]	training's auc: 0.842215	valid_1's auc: 0.615781
# [205]	training's auc: 0.84241	valid_1's auc: 0.616793
# [206]	training's auc: 0.842683	valid_1's auc: 0.616233
# [207]	training's auc: 0.842853	valid_1's auc: 0.616663
# [208]	training's auc: 0.843117	valid_1's auc: 0.61662
# [209]	training's auc: 0.843531	valid_1's auc: 0.61634
# [210]	training's auc: 0.843585	valid_1's auc: 0.616599
# [211]	training's auc: 0.843958	valid_1's auc: 0.616513
# [212]	training's auc: 0.844256	valid_1's auc: 0.616362
# [213]	training's auc: 0.844509	valid_1's auc: 0.616836
# [214]	training's auc: 0.844741	valid_1's auc: 0.61662
# [215]	training's auc: 0.845089	valid_1's auc: 0.616599
# Early stopping, best iteration is:
# [115]	training's auc: 0.815794	valid_1's auc: 0.624082

# %%
plan_result['adcreative_elements'].value_counts()
# Out:
# {'image': 115388, 'description': '开局一块地，修水建房，自由建造，伐木建造，发展属于你的文明！', 'video': 115388, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                        9
# {'image': 117277, 'description': '开局只是个小农民，种田造房，伐木狩猎，三天打造文明时代！', 'video': 117277, 'button_text': '立即下载', 'title': '开局荒岛，3天建立强大王国', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                       7
# {'image': 108919, 'description': '古巴比伦、欧洲、亚洲三选一，挖矿造兵，开启你的王国王朝！', 'video': 108919, 'button_text': '立即下载', 'title': '亚洲王朝', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                                7
# {'image': 115319, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 115319, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                        7
# {'image': 97081, 'description': '2021年度策略大作，资源全靠打，一键造兵，一天秒升帝王时代！', 'video': 115455, 'button_text': '立即下载', 'label': [{'content': '战争策略'}], 'title': '占个小岛当岛主，打造你的文明', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}    6
# {'image': 115859, 'description': '经典回归，采集物资、填海造陆、发展科技、打造专属王国！', 'video': 115859, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                         6
# {'short_video_struct': {'short_video1': 91443}, 'title': '沦落荒岛，你该如何扩充人口，是发展成部落还是走向强国！'}                                                                                                                                       6
# {'image': 100158, 'description': '种田、捕猎、挖矿、盖房子、造兵，扩领土，看农民如何制霸王国！', 'video': 100158, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                        4
# {'image': 117444, 'description': '经典回归，采集物资、填海造陆、发展科技、打造专属王国！', 'video': 117444, 'button_text': '立即下载', 'title': '建城造兵，打造最强文明！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                         4
# {'image': 117385, 'description': '还原经典，开局5个农民，伐木采矿，造兵攻城，建造王国！', 'video': 117385, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                           4
# {'short_video_struct': {'short_video1': 74665}, 'title': '帝王高清复刻版，1：1还原端游，开局5农民，多久建立帝王？'}                                                                                                                                     3
# {'image': 116465, 'description': '小时候玩的游戏终于出手游了！开局5个农民，建立你的文明！', 'video': 116465, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                          3
# {'image': 116465, 'description': '开局一块地，修水建房，自由建造，伐木建造，发展属于你的文明！', 'video': 116465, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 74721}}                                        3
# {'short_video_struct': {'short_video1': 114748}, 'title': '开局一座岛，种田造房，白手起家，几天你能称霸全服？'}                                                                                                                                        2
# {'short_video_struct': {'short_video1': 75543}, 'title': '开局给你一座荒岛，伐木建房，采集，打造属于你的王国！'}                                                                                                                                        2
# {'image': 117385, 'description': '小时候玩的游戏终于出手游了！开局5个农民，建立你的文明！', 'video': 117385, 'button_text': '立即下载', 'title': '帝王回归，等你来战！', 'brand': {'brand_name': '亚洲王朝', 'brand_img': 72822}}                                          1
# Name: adcreative_elements, dtype: int64

# %%
plan_result['adcreative_elements'] = plan_result['adcreative_elements'].map(str)

# %%
plan_result['adcreative_elements'] = plan_result['adcreative_elements'].apply(doSubStr)

# %%
plan_result[plan_result['adcreative_elements'].str.contains('帝国')]['adcreative_elements'].value_counts()
# Out:
# Series([], Name: adcreative_elements, dtype: int64)

# %%
plan_result['adcreative_elements'] = plan_result['adcreative_elements'].apply(ast.literal_eval)

# %%
# 定义组合json
plan_result['intention'] = plan_result['intention_targeting_tags'].apply(lambda x: {'targeting_tags': x})
plan_result.drop(['intention_targeting_tags'], axis=1, inplace=True)

ad_info = []
for i in range(plan_result.shape[0]):
    ad_info.append(
        json.loads(plan_result.loc[i, ['interest_category_id_list', 'interest_keyword_list']].rename(index={
            'interest_category_id_list': 'category_id_list',
            'interest_keyword_list': 'keyword_list'}).to_json()))
plan_result['interest'] = ad_info
plan_result.drop(['interest_category_id_list', 'interest_keyword_list'], axis=1, inplace=True)

ad_info = []
for i in range(plan_result.shape[0]):
    ad_info.append(json.loads(plan_result.loc[i, 'behavior_category_id_list':'behavior_time_window'].rename(index={
        'behavior_category_id_list': 'category_id_list',
        'behavior_intensity': 'intensity',
        'behavior_keyword_list': 'keyword_list',
        'behavior_scene': 'scene',
        'behavior_time_window': 'time_window'}).to_json()))
plan_result['behavior'] = ad_info
plan_result.drop(['behavior_category_id_list', 'behavior_intensity', 'behavior_keyword_list', 'behavior_scene',
                  'behavior_time_window'], axis=1, inplace=True)

plan_result['behavior'] = plan_result['behavior'].apply(lambda x: [x])

ad_info = []
for i in range(plan_result.shape[0]):
    ad_info.append(json.loads(plan_result.loc[i, ['conversion_behavior_list', 'excluded_dimension']].to_json()))
plan_result['excluded_converted_audience'] = ad_info
plan_result.drop(['conversion_behavior_list', 'excluded_dimension'], axis=1, inplace=True)

ad_info = []
for i in range(plan_result.shape[0]):
    ad_info.append(json.loads(plan_result.loc[i, ['regions', 'location_types']].to_json()))
plan_result['geo_location'] = ad_info
plan_result.drop(['regions', 'location_types'], axis=1, inplace=True)

ad_info = []
for i in range(plan_result.shape[0]):
    ad_info.append(json.loads(plan_result.loc[
                                  i, ["device_price", "app_install_status", "gender", "game_consumption_level",
                                      "age", "network_type",
                                      "excluded_converted_audience", "geo_location",
                                      "intention", "interest", "behavior"]].to_json()))
plan_result['targeting'] = ad_info
plan_result.drop(["device_price", "app_install_status", "gender", "game_consumption_level", "age", "network_type",
                  "excluded_converted_audience", "geo_location",
                  "intention", "interest", "behavior"], axis=1, inplace=True)

# plan_result['operation'] = 'disable'
plan_result['op_id'] = 13268
plan_result['flag'] = 'GDT'
plan_result['game_name'] = '亚洲王朝'
plan_result['platform'] = 1
plan_result['ad_account_id'] = plan_result['ad_account_id'].astype(int)
plan_result['site_set'] = plan_result['site_set'].apply(ast.literal_eval)

# 过滤‘优量汇’广告位
def is_in_list(n):
    return n != 'SITE_SET_MOBILE_UNION'

plan_result['site_set'] = plan_result['site_set'].apply(lambda x: list(filter(is_in_list, x)))
plan_result.drop('page_type', axis=1, inplace=True)
plan_result.to_csv('./plan_result.csv', index=0)  # 保存创建日志
print(plan_result.shape[0])
# Out:
# 74

# %%
plan_result_seg = pd.DataFrame()
for i in range(plan_result.shape[0]):
    plan_result_seg = plan_result_seg.append(plan_result.iloc[i:i + 1])
    if (i > 0 and i % 40 == 0) or i == (plan_result.shape[0] - 1):
        plan_result_seg = plan_result_seg.reset_index(drop=True)
        print(plan_result_seg.shape[0])
        rsp_data = get_ad_create(plan_result_seg)
        print(rsp_data)
        time.sleep(200)
        plan_result_seg = pd.DataFrame()
