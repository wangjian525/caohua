# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from tensorflow.keras import layers,datasets
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from tensorflow import keras
import gc
import warnings
warnings.filterwarnings('ignore')
import lightgbm as lgb
import category_encoders as ce
from sklearn.metrics import f1_score,classification_report,roc_auc_score
from impala.dbapi import connect
from impala.util import as_pandas
import pymysql
import ast
import requests
import random

# %%
def get_game_id():
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL 
    '''
    cur.execute(sql)
    result_df = cur.fetchall()
    cur.close()
    conn.close()
    return result_df

# %%
# 获取近期所有计划
def get_plan_info():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = pymysql.connect(host='db-slave-modeltoufang-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
                * 
            FROM
                db_ptom.ptom_third_plan p
            WHERE
                game_id IN ({})
                AND media_id = 45
                AND opt_status = 1
                AND create_time>=date( NOW() - INTERVAL 1440 HOUR )
                AND create_time<= date(NOW())
                            AND plan_id >= (
                                select plan_id from db_ptom.ptom_plan
                                where create_time >= date( NOW() - INTERVAL 1440 HOUR )
                                and create_time <= date( NOW() - INTERVAL 1416 HOUR )
                                limit 1
                            )
    '''
    finalSql = sql.format(game_id)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
# 获取image_id,label_ids
def get_image_info():
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id,
            a.image_id,
            b.label_ids
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN
            db_data_ptom.ptom_image_info b
        on a.image_id = b.image_id
        WHERE
            a.game_id IN ( SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL ) 
            AND a.create_time >= date( NOW() - INTERVAL 2880 HOUR ) 
        GROUP BY
            a.chl_user_id,
            a.source_id,
            a.image_id
    '''
    cur.execute(sql)
    result_df = pd.read_sql(sql, conn)
    result_df = result_df.dropna(axis=0, how='any')
    result_df['channel_id'] = result_df['channel_id'].map(int)
    result_df['source_id'] = result_df['source_id'].map(int)
    result_df['image_id'] = result_df['image_id'].map(int)
    cur.close()
    conn.close()
    return result_df

# %%
def get_launch_report():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id AS source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount as roi,
            b.pay_role_user_num / b.create_role_num as pay_rate
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN db_stdata.st_lauch_report b ON a.chl_user_id = b.channel_id 
            AND a.source_id = b.source_id 
        WHERE
            a.create_time >= date( NOW() - INTERVAL 1440 HOUR ) 
            AND b.tdate >= date( NOW() - INTERVAL 1440 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 45
            AND b.game_id IN ({})
            AND b.amount >= 500
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')

    return result_df

# %%
# 获取近期优化计划的创意数据
def get_creative():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modeltoufang-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/ 
        SELECT
            a.chl_user_id 'channel_id',
            a.source_id,
            a.image_id,
            b.creative_info 
        FROM
            (
            SELECT
                a.chl_user_id,
                a.source_id,
                a.image_id,
                b.ad_id,
                b.ad_account_id 
            FROM
                db_ptom.ptom_plan a
                LEFT JOIN db_ptom.ptom_third_plan b ON a.plan_id = b.plan_id 
            WHERE
                a.media_id = 45 
                AND a.create_time >= date( NOW() - INTERVAL 1440 HOUR ) 
                AND a.game_id IN ({}) 
                AND b.ad_id IS NOT NULL 
            ) a
            INNER JOIN db_ptom.ptom_third_ad_creative b ON a.ad_id = b.ad_id 
            AND a.ad_account_id = b.ad_account_id 
        WHERE
            b.create_time >= date( NOW() - INTERVAL 1440 HOUR ) 
            AND b.media_id = 45 
            AND a.image_id IS NOT NULL
            

    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result

# %%
def get_plan_json(plan_info):
    plan_info['ad_info'] = plan_info['ad_info'].apply(json.loads)
    temp = plan_info['ad_info'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('ad_info', axis=1, inplace=True)

    temp = plan_info['audience'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('audience', axis=1, inplace=True)

    temp = plan_info['ocpc'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('ocpc', axis=1, inplace=True)

    plan_info = plan_info[['ad_account_id', 'game_id', 'channel_id', 'source_id', 'create_time',
           'bidtype', 'producttypes', 'ftypes', 'pause', 'autoExpansion',
           'education', 'customAge', 'keywords', 'keywordsExtend', 'newInterests',
           'sex', 'iosVersion', 'androidVersion', 'excludeTrans', 'region',
           'device', 'age', 'transType', 'ocpcLevel', 'isSkipStageOne', 'payMode',
           'optimizeDeepTrans', 'transFrom', 'ocpcBid', 'deepOcpcBid',
           'deepTransType', 'roiRatio', 'useRoi']]
    
    # plan_info 去重
    plan_info = plan_info.sort_values(by='create_time')
    plan_info = plan_info.drop_duplicates(subset=['channel_id','source_id'], keep='last')
    return plan_info

# %%
# 获取近期计划的运营数据
def get_now_plan_roi():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
            a.ad_account_id,
            b.channel_id,
            b.source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount AS roi,
            b.pay_role_user_num / b.create_role_num AS pay_rate 
        FROM
            db_data_ptom.ptom_plan a 
        left join
            db_stdata.st_lauch_report b
        on a.chl_user_id=b.channel_id and a.source_id=b.source_id
        WHERE
            b.tdate >= date( NOW() - INTERVAL 240 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 45 
            AND b.game_id IN ({}) 
            AND b.amount >= 200 
            AND b.platform = 1
            AND b.pay_role_user_num >= 1 
            AND b.new_role_money >= 6
            AND (b.new_role_money / b.amount)>=0.001
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')
#     result_df = result_df[result_df['roi'] >= 0.03]
    return result_df

# %%
# 获取score_image (分数大于550的image_id)
def get_score_image():
    conn = connect(host='192.168.0.97', port=10000, auth_mechanism='PLAIN', user='hadoop',
                    password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql_engine = 'set hive.execution.engine=tez'
    sql_queue = 'set tez.queue.name=offline'
    sql = '''
        SELECT
            image_id,
            label_ids 
        FROM
            dws.dws_image_score_d 
        WHERE
            dt = CURRENT_DATE 
            AND media_id = 45 
            AND image_create_role_roi >= 0.005 
            AND ( image_create_role_retain_1d >= 0.16 OR image_create_role_retain_1d IS NULL ) 
            AND score >= 500 
        GROUP BY
            image_id,
            label_ids
    
    '''
    
    cursor.execute(sql_engine)
    cursor.execute(sql_queue)
    cursor.execute(sql)
    result = as_pandas(cursor)
    result['label_ids'] = result['label_ids'].astype(str)
    result['label_ids'] = result['label_ids'].apply(lambda x: x.strip('-1;') if '-1' in x else x)
    result['label_ids'] = pd.to_numeric(result['label_ids'],errors='coerce')
#     result = result[result['label_ids'].isin([27])]
#     print(result)
    # 关闭链接
    cursor.close()
    conn.close()
    
    return result['image_id'].values

# %%
def get_score_image_other():
    conn = connect(host='192.168.0.97', port=10000, auth_mechanism='PLAIN', user='hadoop',
                    password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql_engine = 'set hive.execution.engine=tez'
    sql_queue = 'set tez.queue.name=offline'
    sql = '''
        SELECT
            image_id,
            label_ids 
        FROM
            dws.dws_image_score_d 
        WHERE
            dt = CURRENT_DATE 
            AND media_id in (10,16,32) 
            AND image_create_role_roi >= 0.008 
            AND ( image_create_role_retain_1d >= 0.16 OR image_create_role_retain_1d IS NULL ) 
            AND score >= 520 
        GROUP BY
            image_id,
            label_ids
    '''
    cursor.execute(sql_engine)
    cursor.execute(sql_queue)
    cursor.execute(sql)
    result = as_pandas(cursor)
    result['label_ids'] = result['label_ids'].astype(str)
    result['label_ids'] = result['label_ids'].apply(lambda x: x.strip('-1;') if '-1' in x else x)
    result['label_ids'] = pd.to_numeric(result['label_ids'],errors='coerce')
#     result = result[result['label_ids'].isin([27])]
#     print(result)
    # 关闭链接
    cursor.close()
    conn.close()
    
    return result['image_id'].values

# %%
def filter_violation_image(image_ids):
    image_ids = [str(i) for i in image_ids]
    image_ids = ','.join(image_ids)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            image_id,
            image_name
        FROM
            db_data_ptom.ptom_image_info
        WHERE
            image_id IN ({})
            AND NOT FIND_IN_SET(1001706, game_ids)
    '''
    cur.execute(sql.format(image_ids))
    result = pd.read_sql(sql.format(image_ids), conn)
    # result = result[result['image_name'].apply(lambda x:True if len(re.findall(r"QMZZ(.*?)-", x))>0 and int(re.findall(r"QMZZ(.*?)-", x)[0]) not in tt_ban else False)]
    # 关闭链接
    cur.close()
    conn.close()

    return result['image_id'].values

# %%
def filter_exclude_image(image_ids, media_id):
    image_ids = [str(i) for i in image_ids]
    image_ids = ','.join(image_ids)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            image_id,
            image_name
        FROM
            db_data_ptom.ptom_image_info
        WHERE
            image_id IN ({})
            AND NOT FIND_IN_SET({}, exclude_media_ids)
    '''
    result = pd.read_sql(sql.format(image_ids, media_id), conn)
    # result = result[result['image_name'].apply(lambda x:True if len(re.findall(r"QMZZ(.*?)-", x))>0 and int(re.findall(r"QMZZ(.*?)-", x)[0]) not in tt_ban else False)]
    # 关闭链接
    cur.close()
    conn.close()

    return result['image_id'].values

# %%
def filter_game_image(image_ids, game_id):
    image_ids = [str(i) for i in image_ids]
    image_ids = ','.join(image_ids)

    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            image_id,
            image_name
        FROM
            db_data_ptom.ptom_image_info
        WHERE
            image_id IN ({})
            AND FIND_IN_SET({}, game_ids)
    '''
    cur.execute(sql.format(image_ids, game_id))
    result = pd.read_sql(sql.format(image_ids, game_id), conn)
    # result = result[result['image_name'].apply(lambda x:True if len(re.findall(r"QMZZ(.*?)-", x))>0 and int(re.findall(r"QMZZ(.*?)-", x)[0]) not in tt_ban else False)]
    # 关闭链接
    cur.close()
    conn.close()

    return result['image_id'].values

# %%
# 对长期累积roi不达标的素材进行过滤
# 获取数据-1-6天
def get_data_1_6():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = connect(host='192.168.0.97', port=10000, auth_mechanism='PLAIN', user='hadoop',
                   password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql = '''
            SELECT
                user_id,
                game_id,
                channel_id,
                source_id,
                role_id,
                platform,
                media_id,
                pay_num,
                pay_sum,
                create_role_time,
                created_role_day,
                pay_7_pred,
                dt 
            FROM
                tmp_data.tmp_roles_portrait_info_predict 
            WHERE
                dt = CURRENT_DATE
                AND channel_id = 21206
                AND game_id IN ({})
    
    '''
    finalSql = sql.format(game_id)
    cursor.execute(finalSql)
    result = as_pandas(cursor)

    # 关闭链接
    cursor.close()
    conn.close()

    return result

def get_data_7():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = connect(host='192.168.0.97', port=10000, auth_mechanism='PLAIN', user='hadoop',
                   password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql = '''
        SELECT
            user_id,
            game_id,
            channel_id,
            source_id,
            role_id,
            platform,
            media_id,
            pay_num,
            pay_sum,
            create_role_time,
            created_role_day,
            pay_sum AS pay_7_pred,
            dt 
        FROM
            tmp_data.tmp_roles_portrait_info_train2 
        WHERE
            dt = CURRENT_DATE 
            AND created_role_day = 7
            AND channel_id = 21206
            AND game_id IN ({})
    '''
    finalSql = sql.format(game_id)
    cursor.execute(finalSql)
    result = as_pandas(cursor)

    # 关闭链接
    cursor.close()
    conn.close()

    return result

# 获取近期所有计划的消耗情况
def get_amount_info():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
            SELECT
                tdate,
                channel_id,
                source_id,
                game_id,
                media_id,
                platform,
                amount 
            FROM
                db_stdata.st_lauch_report 
            WHERE
                game_id IN ({}) 
                AND tdate_type = 'day' 
                AND channel_id = 21206
                AND tdate >= date( NOW() - INTERVAL 7 DAY )
                AND tdate <= date( NOW() - INTERVAL 1 DAY )
    '''
    finalSql = sql.format(game_id)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    
    return result_df

def calculate_roi(groupby_list=['media_id','platform','image_id']):
    # 获取预测数据
    df_1 = get_data_7()
    df_2 = get_data_1_6()
    df = df_1.append(df_2)
    df['create_role_time'] = pd.to_datetime(df['create_role_time']).dt.date
    # 聚合生成计划维度的回款预测数据
    source_df = pd.DataFrame({'7_pay_sum':df.groupby(['game_id','channel_id','source_id','create_role_time','media_id','platform'])['pay_7_pred'].sum()}).reset_index()
    source_df['media_id'] = source_df['media_id'].map(int)
    source_df = source_df[source_df['media_id'].isin([10,16,32,45])]
    # 获取计划消耗数据，只取4个主流媒体
    amount_info = get_amount_info()
    amount_info = amount_info[amount_info['media_id'].isin([10,16,32,45])]
    image_info = get_image_info()
    # 拼接数据
    source_df.rename(columns={'create_role_time':'tdate'}, inplace=True)
    source_df['tdate'] = pd.to_datetime(source_df['tdate'])
    source_df = pd.merge(source_df,amount_info,on=['channel_id','source_id','tdate','media_id','platform','game_id'],how='outer')
    source_df['amount'] = source_df['amount'].fillna(0)
    source_df['7_pay_sum'] = source_df['7_pay_sum'].fillna(0)
    data = pd.merge(source_df,image_info,on=['channel_id','source_id'],how='left')
    
    df_pay_sum = pd.DataFrame({'7_pay_sum': data.groupby(groupby_list)['7_pay_sum'].sum()}).reset_index()
    df_amount = pd.DataFrame({'7_amount': data.groupby(groupby_list)['amount'].sum()}).reset_index()
    df = pd.merge(df_amount,df_pay_sum,on=groupby_list,how='left')
    df['7_pay_sum'] = df['7_pay_sum'].apply(lambda x: round(x,2))
    df['7_amount'] = df['7_amount'].apply(lambda x: round(x,2))
    df = df[df['7_amount']>0]
    df['7_roi'] = round(df['7_pay_sum'] / df['7_amount'],4)
    
    df = df[(df['media_id']==45)&(df['platform']==1)&(df['7_amount']>=15000)&(df['7_roi']<0.04)]
    df['image_id'] = df['image_id'].astype(int)
    return df['image_id'].values

# %%
def create_plan(df_create,score_image):
    # 选ad_account_id、image_id每个账号+素材8条
    game_id = 1001794  ## 选择包：
#     df_create = df_create[df_create['game_id'].isin([1001794, 1001862, 1001783, 1001863, 1001961, 1001935])]
#     image_id_group = np.intersect1d(df_create['image_id'].unique(), score_image)
    image_id_group = filter_violation_image(score_image)
    image_id_group = filter_exclude_image(image_id_group, 45)
    image_id_group = np.setdiff1d(image_id_group,calculate_roi())
    print('匹配的素材ID', image_id_group)
#     df_create = df_create[df_create['image_id'].isin(image_id_group)]
    
    # 选择预算，不限制预算
    plan = pd.DataFrame({'image_id': image_id_group})
    
    sample_df = df_create[['producttypes', 'ftypes','education', 'customAge', 'keywords', 'keywordsExtend', 'newInterests',
                       'sex', 'iosVersion', 'androidVersion', 'excludeTrans', 'region',
                       'device', 'age','transType', 'ocpcLevel', 'isSkipStageOne', 'payMode',
                   'optimizeDeepTrans', 'transFrom', 'ocpcBid', 'deepOcpcBid',
                   'deepTransType', 'roiRatio', 'useRoi', 'materialstyle',
                   'brand', 'userPortrait', 'titles', 'subtitle']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    plan = plan.reset_index(drop=True)
    plan['game_id'] = game_id
    return plan

# %%
def get_train_df():
    plan_info = get_plan_info()
    plan_info = get_plan_json(plan_info)
    creative_info = get_creative()
    creative_info = creative_info.drop_duplicates(subset=['channel_id','source_id'], keep='last')
    creative_info['creative_info'] = creative_info['creative_info'].apply(json.loads)
    temp = creative_info['creative_info'].apply(pd.Series)
    if 'image_id' in temp.columns:
        temp = temp.drop('image_id', axis=1)
    temp = temp[['materialstyle','material']]
    temp['material'] = temp['material'].apply(json.loads)
    creative_info = pd.concat([creative_info,temp], axis=1)
    creative_info.drop('creative_info', axis=1, inplace=True)
    temp = creative_info['material'].apply(pd.Series)
    temp = temp[['brand','userPortrait','elements','title','subtitle']]
    creative_info = pd.concat([creative_info,temp], axis=1)
    creative_info.drop('material', axis=1, inplace=True)
    creative_info_1 = creative_info[creative_info['elements'].isna()]
    creative_info_2 = creative_info[creative_info['elements'].notna()]
    if creative_info_1.shape[0] != 0:
        creative_info_1['titles'] = creative_info_1['title'].apply(lambda x: [x])
    creative_info_2['titles'] = creative_info_2['elements'].apply(lambda x: x['titles'])
    creative_info = pd.concat([creative_info_1,creative_info_2],axis=0)
    creative_info.drop(['elements','title'],axis=1,inplace=True)
    creative_info['subtitle'] = creative_info['subtitle'].fillna(creative_info['subtitle'].mode()[0])
    plan_info = pd.merge(plan_info, creative_info, on=['channel_id','source_id'], how='inner')
    image_info = get_image_info()
    launch_report = get_launch_report()
    
    plan_info['create_time'] = pd.to_datetime(plan_info['create_time'])
    plan_info_current = plan_info[plan_info['create_time']>=pd.datetime.now() - pd.DateOffset(30)]
    image_info = image_info[image_info['image_id'].notna()]
    image_info['image_id'] = image_info['image_id'].astype(int)
    
    score_image_1 = get_score_image_other()
    score_image_2 = get_score_image()
    score_image = np.union1d(score_image_1,score_image_2)
    score_image = filter_game_image(score_image, 1001794)
    
    now_plan_roi = get_now_plan_roi()
    df_create = pd.merge(plan_info_current,image_info,on=['channel_id','source_id','image_id'],how='left')
    df_create = pd.merge(df_create,now_plan_roi.drop(['ad_account_id'], axis=1),on=['channel_id','source_id'],how='inner')
    # df_create['platform'] = df_create['platform'].astype(str)
    # df_create['platform'] = df_create['platform'].map({"['ANDROID']":1,"['IOS']":2})
    # df_create['platform'] = df_create['platform'].astype(int)
    df_create.to_csv('./df_create.csv',index=0)
    
    # 只跑付费ROI，不跑激活付费
#     df_create = df_create[df_create['optimizeDeepTrans']==False]
    
    plan_create = create_plan(df_create,score_image)
    
    return plan_create

# %%
def get_image_label():
    conn = pymysql.connect(host='db-slave-modelfenxi-001.ch', port=3306, user='model_read',
                           passwd='aZftlm6PcFjN{DxIKOPr)BcutuJd<uYOC0P<8')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
            a.image_id,
            a.label_ids
        FROM
            db_data_ptom.ptom_image_info a
        WHERE
          a.create_time >= '2021-01-01'
    '''
    cur.execute(sql)
    result_df = pd.read_sql(sql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
def get_plan(plan_num, ad_account_id_group):
    plan_create = get_train_df()
    
    # 每个账号跑固定的素材标签
    label_map = {10507:['220', '199,220', '220,239', '117', '132,136', '119', ',220','220,315', '140', '114,156', 
                        '121,199,220','119,239','220,278','121','220,320','278,220','220,307','220,363,278,314','340,220,359','360,358','220,278,360'],
                10508:['220', '199,220', '148', '115,148', ',220', '201', '117', '159',
                   '132,170', '128,140,197', '220,115', '117,115', '117,128', '135,197',
                   '121,159,194,195,201', '117,220,221', '117,239', '220,239', '140',
                   '121,199,220','148,239','220,278','121','255,239,148','220,315','220,320','278,220','220,363,278,314','340,220,359','360,358','220,278,360'],
                10509:['220', '199,220', '159', '132', '148', '133,132', '201', '132,136',
                   '117', '140', ',220', '220,239', '201,159,194,195', '121,122,159,195',
                   '135,136,132', '115', '131,135,136', '117,239', '202,220,199', '148,239','220,278','121','220,315','220,320','278,220','220,363,278,314','340,220,359','360,358','220,278,360'],
                11369:['220', '159', '199,220', '117', '220,239', '132', ',220', '117,239',
                   '201,159,194,195', '121,122,159,195', '133,132', '132,170',
                   '129,135,170', '117,220,221', '132,133', '199,220,236','220,278','220,315','220,320','278,220','220,313','220,363,278,314','340,220,359','360,358','220,278,360'],
                11370:['220', '135,132', '199,220', ',220', '117', '201', '220,239','220,315'
                   '128,140,197', '128,132,134', '133,132,197', '117,134,130','220,278','220,320','278,220','220,313','220,363,278,314','340,220,359','360,358','220,278,360'],
                 12228:['220', '199,220', '220,239', '117', '132,136', '119', ',220','220,315', '140', '114,156', 
                        '121,199,220','119,239','220,278','121','220,320','278,220','220,307','220,363,278,314','340,220,359','360,358','220,278,360'],
                12229:['220', '199,220', '148', '115,148', ',220', '201', '117', '159',
                   '132,170', '128,140,197', '220,115', '117,115', '117,128', '135,197',
                   '121,159,194,195,201', '117,220,221', '117,239', '220,239', '140',
                   '121,199,220','148,239','220,278','121','255,239,148','220,315','220,320','278,220','220,363,278,314','340,220,359','360,358','220,278,360'],
                12230:['220', '199,220', '159', '132', '148', '133,132', '201', '132,136',
                   '117', '140', ',220', '220,239', '201,159,194,195', '121,122,159,195',
                   '135,136,132', '115', '131,135,136', '117,239', '202,220,199', '148,239','220,278','121','220,315','220,320','278,220','220,363,278,314','340,220,359','360,358','220,278,360'],
                12231:['220', '159', '199,220', '117', '220,239', '132', ',220', '117,239',
                   '201,159,194,195', '121,122,159,195', '133,132', '132,170',
                   '129,135,170', '117,220,221', '132,133', '199,220,236','220,278','220,315','220,320','278,220','220,313','220,363,278,314','340,220,359','360,358','220,278,360'],
                12232:['220', '135,132', '199,220', ',220', '117', '201', '220,239','220,315'
                   '128,140,197', '128,132,134', '133,132,197', '117,134,130','220,278','220,320','278,220','220,313','220,363,278,314','340,220,359','360,358','220,278,360']
                }
    
    image_label = get_image_label()
    plan_create = pd.merge(plan_create, image_label, on=['image_id'])
    
    # 每个账号分配计划数量，并保障标签对应
    plan_result = pd.DataFrame()
    for ad_account_id in ad_account_id_group:
        plan_create_ad = plan_create[plan_create['label_ids'].isin(label_map[ad_account_id])]
#         print(plan_create_ad.shape)
        if plan_create_ad.shape[0] < plan_num:
            plan_num = plan_create_ad.shape[0]
        plan_result_ = plan_create_ad.sample(n=plan_num, replace=False).reset_index(drop=True)
    #     plan_create = plan_create.drop(plan_create[plan_create['image_id'].isin(plan_result_.image_id.values)].index, axis=0)
        plan_result_['ad_account_id'] = ad_account_id
        plan_result = plan_result.append(plan_result_)   
    plan_result['autoExpansion'] = 0
    plan_result['pause'] = False
    plan_result.drop('label_ids', axis=1, inplace=True)
    
    plan_result = plan_result.reset_index(drop=True)
    plan_result['deepTransTypes'] = plan_result.apply(lambda x: [26],axis=1)
    plan_result['brand'] = plan_result.apply(lambda x: '罗马：单机加强版' ,axis=1)
    # plan_result['plan_auto_task_id'] = "12545"
    plan_result['plan_auto_task_id'] = "12550,12549"       # 监控规则
    plan_result['op_id'] = 13268
    plan_result['flag'] = 'BD'
    plan_result['game_name'] = '帝国'
#     plan_result['ocpcBid'] = plan_result['ocpcBid'].apply(lambda x: random.randint(6800.00, 7000.00))     # 出价
#     plan_result['roiRatio'] = 0.025     # ROI系数
#     plan_result['useRoi'] = True     # ROI系数
    
    # 出价方式
    plan_result['transFrom'] = 1
    plan_result['payMode'] = 1
    plan_result['ocpcLevel'] = 2
    plan_result['isSkipStageOne'] = True

    plan_result['optimizeDeepTrans'] = plan_result['optimizeDeepTrans'].apply(lambda x:np.random.choice([False,True],p=[0.9,0.1]))
#     plan_result['optimizeDeepTrans'] = plan_result['optimizeDeepTrans'].apply(lambda x: False)
    plan_result['transType'] = plan_result['optimizeDeepTrans'].apply(lambda x:26 if x==False else 4)
    plan_result['ocpcBid'] = plan_result['optimizeDeepTrans'].apply(lambda x:random.randint(7000.00, 7200.00) if x==False else random.randint(150.00, 170.00))
    plan_result['deepOcpcBid'] = plan_result['optimizeDeepTrans'].apply(lambda x:random.randint(4500.00, 4700.00) if x==True else np.nan)
    plan_result['useRoi'] = plan_result['optimizeDeepTrans'].apply(lambda x:True if x==False else np.nan)
    plan_result['roiRatio'] = plan_result['optimizeDeepTrans'].apply(lambda x:0.03 if x==False else np.nan)
    plan_result['deepTransType'] = plan_result['optimizeDeepTrans'].apply(lambda x:np.nan if x==False else 26)
    plan_result['ftypes'] = plan_result.apply(lambda x:[1, 2] if x.optimizeDeepTrans==True else x.ftypes, axis=1)
    # 意向词
    df_kw = pd.read_excel('../百度周原生意图词0718-0731.xlsx')
    df_kw = df_kw.dropna(axis=0,subset=['SLG意图词'])
#     plan_result['keywords'] = plan_result['keywords'].apply(lambda x:",".join(map(str,np.random.choice(df_kw['SLG意图词'].values[:3000], 1900, replace=False))))
#     plan_result['keywords'] = plan_result['keywords'].apply(lambda x: "1.70版本传奇,1.76传奇复古,123天气预报查看15天,170复古传奇金币版,176金币复古版本,178魔兽世界,196黄金皓月传奇,2018新公测回合制手游,20万左右suv,20元红包,2345天气,2345游戏盒子,350手游烈火龙城下载,37游戏大全,3万元简装修效果图,4399小游戏生死狙击,4d坦克红警,53度茅台内供酒,58同城新房,66游戏,77捕鱼,850棋牌,9377手游,9377手游平台,95美女秀,99魔域,9块9包邮,app下载,app下载软件下载,app交友软件,baidu,bt传奇,bt游戏平台,cbg梦幻站,coach包包,dd373,dnf,dnf勇者归来,dnf地狱,dnf所有地下城,dnf手游,dnf狂战士,dnf鬼泣技能,eve,fc魂斗罗,gta5,gucci,gucci官网,gucci香水,huawei,h小说,iphone5c,jj千炮捕鱼刷金币教程,lol官方,lol英雄联盟,lol英雄联盟单机版,lpl英雄联盟,lv中国官网,lv围巾女,macan最新报价,mba,mu,mu觉醒,nba,nba范特西,oppo手机报价表,pubg,qq三国,q版三国手游,reno2游戏,rpg三国,rpg手游,soul,steam,taptap下载,txt全集小说,wg999传奇,wow,yy影院,yy直播美女主播,一,一刀烈火,一加手机,一念成瘾，陆太太嫁到,一念永恒,一美女,七界仙尊,万古天帝第一神,万古神皇,万古第一帝,万域之王,万炮捕鱼捕鱼,三剑,三国,三国 手游,三国11,三国三国三国游戏,三国之力震天下,三国之召唤猛将,三国之吕布天下,三国乱世手机版,三国人物,三国傲世无双,三国全面战争,三国全面战争手游,三国关云长,三国加强版,三国单机游戏下载,三国历史,三国名将传手游,三国塔防手游排行榜,三国塔防游戏,三国塔防类游戏,三国大时代5,三国威力加强版手游,三国小说,三国带兵打仗的游戏,三国志,三国志11,三国志11华夏风云最终,三国志11武将,三国志11补丁,三国志13,三国志15威力加强版,三国志2017攻略,三国志5,三国志9,三国志9手机版,三国志三国志,三国志下载,三国志单机,三国志吞食天地,三国志吧,三国志大全,三国志威力加强版,三国志孔明传,三国志左慈,三国志战略版,三国志战略版官方版,三国志手机游戏,三国志手游单机,三国志手游攻略,三国志手游破解版,三国志的,三国志的手游,三国志赵云传,三国快打游戏,三国战争,三国战争策略游戏,三国战纪官网,三国战纪游戏,三国战记网游,三国手机卡牌,三国手机游戏大全,三国手机网游,三国挂机游戏,三国攻城志手游,三国放置版,三国放置英雄武将搭配,三国新吕布,三国无双,三国无双7,三国杀的游戏规则,三国杀神赵云,三国游戏,三国游戏哪个最好玩,三国游戏手机版,三国演义,三国演义是哪三国,三国火烧赤壁,三国版游戏,三国的手游,三国神将,三国神将传,三国第一猛将并非吕布,三国策略,三国策略手游,三国策略手游单机版,三国策略手游排行榜,三国策略类,三国策略类手机游戏,三国类战争策略游戏,三国类手游,三国类游戏排行,三国类的游戏,三国系列单机游戏,三国群侠传下载,三国群殴传,三国群英,三国群英1,三国群英8,三国群英ol,三国群英传,三国群英传1手机版单机,三国群英传3加强版,三国群英传三,三国群英传三国鼎立,三国群英传军师,三国群英传官网,三国群英传手机,三国群英传手机版单机,三国群英传手游版攻略,三国群英传秘籍,三国群英传装备,三国群英变态版,三国群英游戏,三国群英纪,三国群英转,三国英雄无敌,三国街机,三国许攸,三国连环战手游,三国题材卡牌游戏,三维城市建造游戏,下游戏下载,下载,下载手机免费游戏,下载手机游戏安卓,下载棋牌,下载迷失尸境,下载麻将欢乐麻将,不嫁总裁,不是回合制手游,不灭帝尊,不花钱的三国手游,不限购楼盘,世界未末日,东风标致suv,丧尸之战,丧尸乐园,丧尸全部游戏,丧尸军团,丧尸出笼,丧尸危机,丧尸围城4,丧尸国度,丧尸国度第一季,丧尸游戏,丧尸电影,丧尸电影大全排行榜,丧尸系列游戏,个人急售二手房,中国,中年女交友,中年女人单身群,中式四合院别墅设计,丹武九重天,主宰三界,乒乓球教学,九州天空城,九游,九阳神功,九阴真经,九阴绝学,买房,买房产,买房价格,买房子,买苹果手机,买车,乱世三国志游戏,乱轰三国志武将,二战,二战游戏,二战风云,二手房价,二手房价格,二手房装修,二手车估价,云墨行,五粮液股票,亚洲,交友网免费,交友软件,交易平台,亦庄楼盘,人体艺术,人气手游,人道至尊,什么传奇游戏,仗剑江湖,仙侠传手游,仙侠剧,仙侠动漫,仙侠手游下载,仙侠游戏下载,仙侠游戏名字大全,仙侠网游,仙剑,仙境传说,仙武帝尊免费全文阅读,仙灵觉醒,仙路至尊 小说,休闲游戏排行,休闲经营游戏,休闲裤,休闲零食店加盟,传奇1.76,传奇999级,传奇一刀,传奇一刀999级,传奇上线10000级,传奇世界,传奇世界2吧,传奇世界之不死之身,传奇世界手游脚本,传奇世界新手怎么玩,传奇世界高爆版,传奇了,传奇兑换码,传奇内挂,传奇刀刀切割,传奇原版手游,传奇变态版本下载,传奇可以赚钱吗,传奇合击版,传奇哪里下,传奇官网,传奇战域,传奇手游,传奇手游推广,传奇手游游戏,传奇手游点卡版,传奇手游电脑版,传奇手游网,传奇挂机游戏,传奇暴击版,传奇暴服版,传奇来了,传奇来了满v无限元宝,传奇永恒什么时候公测,传奇游戏排行榜,传奇火龙,传奇火龙挂,传奇版,传奇王者,传奇盒子,传奇至尊,传奇蓝月手游,传奇超变版,传奇超变版本下载,传奇超级爆率版,传奇迷失版本,传奇送vip,传奇通用登陆器,传奇高爆,传奇高爆版,作文,使命召唤手游下载,俄罗斯,保卫萝卜3,修仙世界,修仙归来,修仙手游推荐,修真劫,假面骑士,健康管理师报考条件,僵尸感染,僵尸末日,僵尸突围,免下载游戏,免安装麻将机,免费下载游戏大全,免费修仙狂徒有声小说,免费全本小说言情,免费全本已完结小说,免费听书小说,免费完整小说,免费小说修仙狂徒,免费小说在线,免费小说推荐,免费小说新版,免费模拟人生,免费游戏大全,免费的直播,兑换的捕鱼,全屋整装,全本书免费阅读,全本免费小说都市修仙,全本小说免费阅读,全民奇迹mu下载,全民奇迹充值,全民奇迹大天使之杖,全民奇迹开服,全民斗地主下载,全民突击,全职魔法师,全自动麻将机,全面战争罗马2,公交,六复古传奇官网,关于三国游戏,关于三国的游戏,关于动漫,养成游戏,内裤男,冒泡棋牌游戏大厅,冒险家,冒险岛,冒险岛2官网国服,冒险岛手游修改版,冒险岛攻略,冒险游戏,军事手游,农村,冬虫夏草的功效与作用及食用方法,冰种翡翠手镯价格,决战龙城,减肥的最好方法,凡人修仙的小说,刀刀暴击传奇,刀刀群秒,刀塔传奇2,刀塔传奇变态版,刀塔传奇礼包,刀塔英雄礼包,刚开传奇,别墅室内设计,别墅怎样装修,刷金币,剑3,剑侠世界手游下载,剑侠奇缘手游,剑灵17173,剑灵召唤,剑灵官网,剑神,剑神诀,剑神诀手游,剑诀,剑魂之刃下载,动态图片,动漫头像男,动漫女生人物图片,动漫少女漫画大全,动画头像,劲舞团,劳力士男表,勇士队,勇者之心,勇者斗恶龙,北京房价,十大好玩手游破解版,十大手机游戏,千炮捕鱼破解版无限金币,午夜小说,华为 荣耀9,华为p40,华为p7价格,华为手机好不好,华为手机性价比,华为新款手机,华为笔记本电脑,单机三国群英传3,单机塔防手游,单机小游戏,单机游戏三国志2,单机游戏三国志手机版,单机游戏红警,单机游戏红警3,单机版三国志,单机版三国战记下载,单机版传奇下载,单机的末日生存游戏,单机红警,单机红警下载,单田芳,单职业倍攻传奇,单职业打金传奇,单身男女,单身群,单间租房,卡地亚手表,卡牌游戏,即将公测的手游,即将开盘的楼盘,历史策略游戏,原神,原神觉醒,原装瑞士手表,去皱面膜,反恐精英,发型,口袋兽人,口袋妖怪go,口袋妖怪中文版,口袋妖怪漆黑的魅影,口袋妖怪火红,口袋妖怪银魂,口袋怪兽下载,口袋精灵复刻,古代战争策略游戏,古风歌曲,古驰,可以挂机的回合制手游,可以挂机的网络游戏,可以爆装备的手游,可爱的情侣头像,史上第一祖师爷,叶空修仙狂徒,吃鸡手游,吃鸡游戏,各种壁纸手机版,合击传奇,吉祥捕鱼,同城,同城交友,名将,名表,后宫,吞食三国,命运冠位指定从者,和女生聊天找话题,和平精英怎么样,哔哩哔哩,哪个捕鱼游戏好玩,哪些游戏好玩,唐家三少,唱吧,啊女人,啪啪三国类似游戏,啪啪王者荣耀,嘉善新房,嘉善楼盘房价,回合制手游抽神兽,回合制游戏,回合制网游新游,回忆传奇1.76金币,固安房价,国外购房,国战攻略,国战无双,国战游戏,国战类三国手游,国服魔兽月卡,国王游戏,圣斗士冥界篇,圣斗士名字,圣斗士星矢重生,在线电视剧观看,在线直播,在线美女,在线美女直播,在线观看,地下城,地下城堡2双狼怎么打,地下城游戏,地球末日生存,坦克世界,坦克之战,坦克前线帝国ol,坦克大战,坦克大战游戏下载,坦克射击,坦克帝国,坦克游戏,城堡塔防,塔防三国志官网,塔防三国志战法在哪里,塔防三国志手游官网,塔防塔防,塔防守卫者游戏,塔防游戏单机版下载,塔防西游记,复古传奇1.80,复古传奇180,复古传奇版本,复古传奇网站,复古版传奇,夏侯惇,多米音乐,大三国志,大亚湾楼盘,大众途锐报价,大剑天使,大唐无双手游,大型三国手游,大型单机游戏排行榜,大型游戏单机游戏,大天使之剑剑士,大天使之剑开服,大天使之剑漏洞,大天使之剑突破幻晶,大富翁,大恐龙,大桥未久,大秀直播,大衣搭配,大闹天宫捕鱼,大陆奇迹,天使,天堂2,天天三国战,天天斗三国,天天玩棋牌,天天美剧,天梭,天气,天气之换天气预报,天气今天天气预报,天气天气预报下载,天气预报,天气预报中国天气,天涯明月刀端游,天龙八部2888卡免费领取,天龙八部充值礼包,天龙八部荣耀版体验服,失眠,失眠了,奇迹mu,奇迹mu吧,奇迹mu怎么挂机,奇迹mu战士加点,奇迹mu手机,奇迹mu手机版,奇迹mu挂机点,奇迹mu武器大全,奇迹mu王者归来,奇迹mu荧光属性,奇迹mu觉醒手游,奇迹mu论坛,奇迹mu还有人玩吗,奇迹mu重生,奇迹之剑,奇迹单机版,奇迹圣域,奇迹战士加点,奇迹战士怎么加点,奇迹手游,奇迹暖暖,奇迹最新版本,奇迹游戏,奇迹类手机游戏,奇迹觉醒什么时候公测,奇迹魔域手游,奉贤房价,奔驰c级优惠,奥特曼怪兽,奥迪a4l促销,奥迪报价,女人与,女人内裤,女人出轨后的表现,女人征婚,女人性,女人找男人,女子,女性女,好玩三国策略手游,好玩的三国卡牌游戏,好玩的单机手游,好玩的联机手机游戏,好玩网游,好看的女尊小说,好看的校园小说,好看视频,如何挣钱,婚恋网,媳翁小说,孙悟空捕鱼,孤岛惊魂5,孤岛求生游戏,宅男,安卓手机游戏下载,安卓游戏排行榜,安居客,安居客新房,完整小说免费阅读,完美手游,官方麻将,官网,官网手游,宝马3系报价,宠物小精灵之,客户管理系统,富聊,射雕英雄传3d手游,将夜纪,小小魔兽,小播放器视频,小米手机,小说,小说三国,小说全本免费,小说大全免费阅读完结,小说岳风,小说欲妻,小说网络小说,小说肉文,小说阎王妻免费阅读,少儿人寿保险,少年三国2,少年三国志攻略,少年三国游戏,屏幕,屠龙之怒,屠龙天下,山海经神兽手游,崩坏,崩坏三,崩坏学园2,巅峰战舰,川村真矢,布偶猫,帝国ol全面战争下载,帝国手游,帝国文明,帝国时代2怎么玩,帝国时代2战役,帝国时代2花屏补丁,帝国时代3,帝国时代3亚洲王朝下载,帝国时代3亚洲王朝中文版,帝国时代3亚洲王朝手机版,帝国时代3修改器,帝国时代4,帝国时代决定版,帝国时代单机手机版,帝国时代手游攻略,帝国时代统治世界,帝国王朝,帝王三国名将列表,帝王三国游戏,带英雄无敌,平台游戏,幸存者危城,幸存者危城无限钻石,幸存者危城无限钻石版下载,幻想西游手游,幽冥白虎,广州地铁,广州火舞游戏决战沙邑,开奖结果,开网店,异界,张大仙,张无忌,当乐,影视动漫,影视大全免费观看,征途变态版,征途吧,征途游戏官方网站,御魂,御龙在天手游下载,微信,微信红包秒抢,微微一笑很倾城小说2,忍者必须死3,快乐捕鱼,快播电影,怀孕多久可以做b超,怀旧版征途,怎么样,怎么样留住男人的心,怎么看美女直播,怎样和女生聊天,怎样挽回前男友,怒火传奇,性感美女主播,怪兽大作战,总裁小说排行榜,恋爱养成类游戏,悟饭游戏厅,悦动报价,情侣头像,情感挽回,情歌,情话,惠州楼盘,成人影院,成人用品无人售货机加盟,我想找个女人,我本沉默迷失传奇,我的世界,我的世界吧,我的坦克我的团,我的极品老婆,我要买车,我要找女人,我要看三国,战争游戏,战争片电影,战争电影,战争的手游,战争策略,战争策略单机游戏,战争策略游戏大全,战争策略类手机游戏,战地1,战地2,战地4,战斗暴龙兽,战殇奇迹,战略三国游戏,战舰世界nga,战舰少女r,战觞奇迹,房产信息,房价,房屋拆迁,房屋装修,手机,手机三国策略游戏,手机休闲手机游戏,手机休闲游戏,手机免费游戏,手机助手,手机华为,手机单机三国游戏,手机变态版游戏,手机大型游戏,手机小游戏游戏,手机性价比,手机武侠游戏,手机游戏,手机游戏app,手机游戏交易平台哪个好,手机游戏战争策略,手机游戏排行榜,手机游戏策略游戏,手机版dnf地下城与勇士,手机版奇迹mu,手机策略游戏,手机赚钱app,手游,手游三国英杰传,手游下载排行榜,手游下载网站,手游仙侠坐骑,手游全面战争,手游公测手游,手游助手,手游塔防三国志,手游大全,手游战争,手游新,手游新发布,手游格斗游戏排行榜,手游游戏下载,手游礼包,手表回收价格,扑鱼达人3,打boss,打僵尸,打斗游戏,打造帝国,打金传奇,打金游戏,打鱼捕鱼,打鱼机器,打鱼电玩游戏机,找单身女人聊天,找老公的女人,找附近寂寞的女人,抗日红警,护肤,招商加盟,拳皇2002,拳皇98终极之战ol新版全民礼包领取,拳皇三国,挂机传奇下载,挂机手游,指挥官,捕鱼,捕鱼之深海捕鱼,捕鱼千炮,捕鱼大亨,捕鱼大作战,捕鱼季游戏,捕鱼开发,捕鱼总动员,捕鱼机头,捕鱼游戏下载平台,捕鱼游戏充值,捕鱼游戏大厅,捕鱼炮,捕鱼赢奖品,捕鱼达人4,捕鱼达人波克城市,换装,探探下载,推荐游戏,收藏酒,攻城掠地,攻城掠地马超觉醒,攻城略地,放开那三国 游戏,放开那三国2充值,放开那三国2礼包,放开那三国下载,放开那三国二,放开那三国交易,放置,放置三国,放置奇兵英雄,放置类游戏,故事,散人传奇新服,散人传奇送vip,文字小说玄幻,斗三国张辽,斗三国最新区,斗三国礼包,斗地主游戏大厅免费下载,斗战西游,斗牛比赛,斗罗,斗罗同人小说,斗罗大陆1,斗罗大陆2小说,斗罗大陆2漫画,斗罗大陆2绝世唐门漫画全集免费阅读,斗罗大陆三,斗罗大陆之绝世唐门,斗罗大陆之龙王传说,斗罗大陆免费阅读全文,斗罗大陆游戏攻略,斗罗大陆漫画全本下载,斗罗大陆电视剧,斗罗大陆顶点小说,斗罗大陆颠峰斗罗,斗罗大陆龙王,新三国争霸游戏,新三国塔防,新出游戏,新出的丧尸片,新剑侠情缘,新塔防游戏,新开楼盘信息,新开楼盘房价,新房如何装修,新房子开盘,新房开盘,新房房产,新房新楼盘,新房楼盘,新手游,新斗罗,新楼盘,新楼盘价格,新款宝马x1报价,新款宝马x5价格,新款手机,新款轿车报价,新版坦克大战,新能源汽车,新能源汽车大全,新西游记,新诛仙,新诛仙手游攻略,旅游攻略,无充值传奇,无双三国手游官网,无尽争霸手游,无尽尸城官方,无限火力,无限金币的游戏,日剧,时之歌,时代传奇,昆山新楼盘,昆明买房,明日之后,明日方舟,星球大战,星际争霸,星际争霸3,星际争霸虫族之心,星际战甲,星际未来,春装新款女装外套,显卡,普通麻将机免安装,暗黑三,暗黑之魂2,暗黑传奇礼包,暗黑单机版游戏,暗黑圣斗士,暗黑地下城与勇士,暗黑奇迹,暗黑破坏神3好玩吗,暗黑破坏神ol,暗黑血统2攻略,暗黑遗迹,最三国,最后的战争,最女人,最好玩的三国,最好玩的三国手游,最好玩的塔防游戏,最好玩的手机游戏,最好玩的捕鱼游戏,最好的三国手游,最强狂兵免费阅读全文,最强王者,最强神医,最新1.76传奇,最新suv价格,最新suv车型,最新捕鱼棋牌游戏大厅,最新款汽车报价,最新版王者荣耀前瞻,最新的仙侠手游,最新的苹果手机,最新策略手游,最终幻想觉醒,最美天气,朋友圈,望远镜,未来10倍牛股,未来周全国天气预报,末世为王 小说,末世之战,末世之无限兑换,末世之王,末世危城,末世求生,末日之后,末日之战网游,末日决战,末日前线官方,末日危城虐心,末日围城,末日围城破解版,末日孤舰,末日求生游戏,末日求生游戏手机游戏,末日生存大师,末日血战,末日血战兑换码,末日血战官网,末日血战正版,末日血战阵容,末日规则 下载,末日逃生,本田雅阁,杀三国,李丽珍,极品翡翠手镯价格,极品驸马小说免费阅读,果宝三国游戏,枪战游戏,校花梦工厂,核桃手串,格斗游戏,梦仙侠,梦幻之,梦幻剧情,梦幻官方网站,梦幻手游梦幻手游,梦幻西游2职业选择,梦幻西游之雷怒危机,梦幻西游大,梦幻西游官网,梦幻西游宠物进阶,梦幻西游攻略,梦幻西游礼包大全,梦幻西游竖琴价格,梦幻西游网易版官网,梦幻诛仙吧,梦想三国全集,梦游江湖手游,梦醒三国,棋牌捕鱼牛牛娱乐,棋牌游戏,植物大战僵尸,植物大战僵尸无敌,植物大战僵尸无限内购版,植物大战僵尸破解版,楚汉传奇手游,楼盘,楼盘价格,楼盘信息,楼盘房价,模型制作,模拟人生3秘籍,模拟人生4,模拟人生游戏,模拟农场,模拟经营类手游,樱花,次元大作战回归,欢乐捕鱼,欣文学小说,欧米茄手表价格,欧米茄男士手表,欧美一级特黄大片视频,歌曲,歌曲mp3,正版传奇,正版传奇一刀999级,正版海贼王手办,正统三国,正规网络兼职赚钱平台,武侠小说排行榜完本,武帝,武易游戏,武极天下,武神空间,死神vs火影,毁灭,比亚迪优惠,比较好玩的三国游戏,水无濑优夏,水果忍者,永恒塔防,永恒魔法,求生世界,求生之路,江湖行手游,汽车,波克捕鱼官网,波克捕鱼游戏,泽尻绘里香,流量宝,浪琴手表官方旗舰店,海口房价,海岛奇兵破解无限钻石,海战,海战世界国服,海战游戏,海王捕鱼最新版,海贼王上古七大果实,海贼王剧场版,海贼王强者之路,海贼王游戏单机版,海贼王漫画,海贼王漫画下载,海阳天气预报,涨停,混沌剑神小说,混沌弑神诀,清朝穿越小说,清纯美女,游戏,游戏三国之英雄传说,游戏三国游戏,游戏下载平台,游戏充值中心,游戏充值平台,游戏助手,游戏单机游戏,游戏在线游戏,游戏塔防游戏,游戏大厅下载,游戏大厅捕鱼下载,游戏平台下载,游戏热门游戏,游戏牌,游戏王单机手游,游戏王卡牌,游戏王网络游戏,游戏玩游戏,游戏盒子,游戏超级战舰,漂亮美女,漫画,漫画版,火影忍者1,火影忍者什么,火影忍者小樱,火影忍者手游,火影忍者漫画同人,火影忍者真人版,火影忍者羁绊,火龙,火龙王奇迹,炉石传说隐藏任务,点券,烈火雷霆,烈焰战神,热血三国2,热血三国3,热血传奇2,热血冒险岛,热血征途,热血江湖,热血问战,热门手游游戏,烽火三国,烽火戏诸侯,爆笑三国,爆装备的手游,爱你,牛仔裤,特斯拉新款,特色餐饮加盟,狂三国,狂斩三国,狂暴幻想之迷失尸境,狙击精英4,独栋别墅出售,玄天邪尊,玄幻奇幻小说排行榜,玄幻小说族,玄幻小说的巅峰,率土之滨五星,率土之滨武将搭配,率土之滨的乱世,王城争霸,王庚,王王者荣耀前瞻版,王者传奇手游官网,王者军团,王者归来,王者联盟,王者荣耀,王者荣耀之,王者荣耀什么英雄厉害,王者荣耀充值,王者荣耀前瞻版皮肤,王者荣耀即将出的皮肤,王者荣耀哪吒视频,王者荣耀国服东皇,王者荣耀新英雄时间表,王者荣耀最强王者一星,王者荣耀版本,王者荣耀电竞俱乐部,王者荣耀的,玩大天使之剑,玩的游戏,现在手机,现场直播,现房,现棋牌游戏,珍藏茅台,理查德米勒手表,生化危机,生存战,生存游戏,生存游戏推荐,生存类游戏,用什么捕鱼,电焊工培训,电玩游戏下载,电玩游戏机捕鱼,电视剧排行榜,电视直播频道,男人,男发型,男性感内裤,男朋友,男生什么发型好看,男穿越小说全本阅读,疫情,疯狂原始人,疯狂塔防战,白酒茅台价格,百度三国杀,百战天下,皇室战争,皇室战争下载,皓月传奇,皓月传奇礼包,盛世三国,盛大1.76传奇,直播美女直播,看大片,看最新电影,看美女主播,看黄片,真三国,真三国快打,真三国无双,真人美女主播,真实3d捕鱼,真实美女,真放置三国,真无双三国游戏,真正末日,真正的复古传奇,短篇言情小说免费,石家庄房产,砍传奇,破解版手游,碧蓝航线,神兽,神原,神将三国关羽,神舟战神笔记本,神都夜行录,福州房价,福特新车,租房信息,租房车,空气能热泵,穿搭女,穿越,穿越小说免费阅读全文,穿越小说吧免费阅读,穿越火线网页游戏,穿越言情小说,笑傲江湖,第一季,策略型手游,策略手游,策略游戏三国群雄传,策略类三国,简单,类似三国游戏,类似三国策略游戏,类似三国群英传的手机游戏,类似三国群英传的游戏,类似帝王三国手游,类似魔兽rpg的手游,类似魔域的游戏,类地下城与勇士手游,精神分裂症,红包版,红手指,红烧肉的做法,红翡翠手镯,红色警戒,红色警戒1,红警2坦克,红警单机,红警坦克ol,红警坦克大战,红警坦克官网,红警坦克战,红警塔防,红警大战,红警大战之坦克风暴,红警大战吧,红警大战黄金坦克,红警如何空投坦克,红警手机版,红警攻略,红警破解版,红警红警,约会交友软件,约会附近的人,终极斗罗,经典三国志单机游戏,经典歌曲,经典的小说,经营游戏,经营策略游戏,结婚生子游戏,绝世剑神 小说,绝地求生怎么下载,统一三国,缅甸旅游,网店货源,网易三国手游,网游三国之无敌村庄,网游加速器,网站,网络捕鱼平台,网络游戏排行,网络策略游戏,网页捕鱼,美人三国志,美女,美女三国游戏,美女主播在线观看,美女人,美女啊,美女图片,美女图片可爱,美女来了,美女没穿内衣内裤,美女照片,美女秀场直播,美女秀直播,美女脱衣直播,美女诱惑,美眉直播,群英,群雄三国志手游,翡翠冰种,翡翠玉手镯,翡翠玉石手镯,翡翠的等级和价格,翻译,老子是阎王,老梁,老爷吉祥开服表,老版三国,老版三国游戏,老版三国游戏单机,耐玩的安卓手机游戏,聊天群,聊天记录删除了怎么恢复,股票大盘,胡,能赢钱的捕鱼,至尊蓝月激活码,航海王破解版,航海王限定版,航海策略游戏,良心传奇,艾尔之光,艾希,艾泽拉斯,花桥房价,花田,苍之纪元阵容组合,英雄三国,英雄三国杀,英雄三国游戏,英雄对决,英雄无敌,英雄无敌3攻略,英雄无敌3死亡阴影,英雄无敌3死亡阴影安卓,英雄无敌之土匪领主,英雄无敌之战争纪元,英雄无敌公测,英雄无敌变态,英雄无敌布阵,英雄无敌战争纪元新服攻略,英雄英雄联盟,英雄连2,苹果,苹果5s价格,苹果7plus,苹果六,苹果手机,苹果的手机,范冰冰,茅台不老酒,茅台国隆酒,茅台汉酱酒价格,茅台白酒,茅台酒,茅台酒回收价格,茅台醇,茅台镇五星珍藏酒,茅台镇原浆酱香酒价格,茅台镇品鉴酒,茅台镇白酒,茅台镇窖藏原浆酒兼香型,茅台镇窖藏酒,茅台镇系列酒,茅台镇酒,茅台镇酒厂,茅台高尔夫酒价格,荒岛求生,荒岛求生游戏,荒野,荣耀9x,荣耀9xpro,荣耀王者最强王者,菜谱,菜谱家常菜土豆做法,萌三国漫画,蒸馒头,蓝月至尊版下载,蓝月至尊版官方下载,蛊真人,血战,街头霸王,街机三国,街机三国网游,街机捕鱼,街机捕鱼大厅,街机捕鱼平台,街机摇钱树捕鱼,街机电玩城,街机金蟾捕鱼红包,街机金蟾捕鱼联网版,街霸,衣服搭配,衬衫,西方玄幻小说,西游变态版官网,西游手游,西游游戏,视频,视频播放器免费,言小说,言情|免费小说,言情小說,言情小说免费阅读全本,言情小说吧,言情小说在线阅读,詹姆斯夺冠,试玩游戏,诛魔,说电影,谁主三国,谈恋爱,豆丁免费小说,象棋,财税筹划,贪玩蓝月手机版,贪玩蓝月手游,贪玩蓝月至尊版官网,贵州旅游攻略自由行,赚钱手游,赤月传奇3,赵丽颖,赵庭洞穿越小说,赵文卓,超变传奇至尊版,超变攻速版传奇手游,超声波捕鱼,超级三国群英手游,超级红包,超能英雄手游,超高爆率的传奇游戏,足球,足球直播,足球经理,跑步鞋,轩辕传奇,辐射避难所,达人捕鱼2,还女人,这就是战争,进击吧!三国,连天气预报,连衣裙,迷你世界,迷你世界丧尸,迷失尸境,迷失尸境官网,迷失尸境攻略,迷失尸境游戏,迷失尸境激活码,逃生游戏,逆剑狂神,逆剑狂神最新章节免费阅读,逍遥诀,途观l,那些电影,那里有红包领,部落冲突9本部落战阵型,部落战魂,都市仙尊,都市至尊仙医,都市艳妇小说全文阅读,都市言情小说,酷睿笔记本,醉三国手游,重庆新房,重楼,野外生存,野钓钓鲫鱼调漂图解,金庸武侠电视剧,金蟾打鱼捕鱼游戏,钓鱼技巧,钟会三国杀,钻石奇迹,问道,问道塔防,问道外传,问道攻略,问道最新版,问道问道,阅文,阿拉德之怒,阿瓦隆之王,阿瓦隆之王龙之战役,附近人约,附近出租房,附近四十岁单身女人,附近寂寞单身女人,附近约,附近美女单身,降临诸天,随便玩王麻将,雷神怒击,雷霆传奇游戏下载,雷霆霸业,雷鸣三国游戏,霸三国名将,青云,青春校园小说,韩国第一性感美女,音乐,音响,页游,顺义房价,领土战争手游,飘渺西游,飞天茅台53度,飞天茅台53度价格,飞天茅台酒,飞天茅台酒53度价格,飞常准,飞机,飞禽走兽,高德地图,高清动漫图片,高清头像,鬼泣4安卓版,魄斗罗,魔兽rpg,魔兽三国,魔兽世界,魔兽世界任务,魔兽世界充值,魔兽世界冰封王座,魔兽世界国服英雄榜,魔兽世界官,魔兽世界客户端下载,魔兽世界快速升级,魔兽世界战场,魔兽世界战网登陆,魔兽世界鲁克玛,魔兽争霸3,魔兽充值,魔兽剧情,魔兽和魔兽世界,魔兽地图,魔兽塔防,魔兽对战,魔兽归来,魔兽战役,魔兽战网点卡,魔兽攻略,魔兽王座,魔兽的手游,魔兽类单机游戏,魔兽英雄榜,魔兽金币交易平台,魔剑士,魔力捕鱼,魔域,魔域世界,魔域官方下载,魔域官方网,魔域手游特殊怪,魔域攻略,魔域永恒吧,魔域版本,魔域觉醒一区,魔域魔域,魔女猎人,魔尊,魔幻rpg手游,魔法门之英雄无敌战争纪元,魔法门英雄无敌战争纪元官网,麻将和了,麻将必赢,麻将技巧,麻将机,麻将机麻将,麻将的技巧,麻将秘决,麻将过庄,黄埔新房,黄蓉,黑暗之魂3,黑暗传奇,黑暗小说,黑暗帝国,黑暗游戏,龙城,龙城游戏,龙城霸业,龙将三国,龙武剑神,龙湖楼盘,龙珠觉醒,龙珠超宇宙自由对战,龙穴塔防2" if (x!=x)|(x=='') else x)
    plan_result['keywords'] = "1.70版本传奇,1.76传奇复古,123天气预报查看15天,170复古传奇金币版,176金币复古版本,178魔兽世界,196黄金皓月传奇,2018新公测回合制手游,20万左右suv,20元红包,2345天气,2345游戏盒子,350手游烈火龙城下载,37游戏大全,3万元简装修效果图,4399小游戏生死狙击,4d坦克红警,53度茅台内供酒,58同城新房,66游戏,77捕鱼,850棋牌,9377手游,9377手游平台,95美女秀,99魔域,9块9包邮,app下载,app下载软件下载,app交友软件,baidu,bt传奇,bt游戏平台,cbg梦幻站,coach包包,dd373,dnf,dnf勇者归来,dnf地狱,dnf所有地下城,dnf手游,dnf狂战士,dnf鬼泣技能,eve,fc魂斗罗,gta5,gucci,gucci官网,gucci香水,huawei,h小说,iphone5c,jj千炮捕鱼刷金币教程,lol官方,lol英雄联盟,lol英雄联盟单机版,lpl英雄联盟,lv中国官网,lv围巾女,macan最新报价,mba,mu,mu觉醒,nba,nba范特西,oppo手机报价表,pubg,qq三国,q版三国手游,reno2游戏,rpg三国,rpg手游,soul,steam,taptap下载,txt全集小说,wg999传奇,wow,yy影院,yy直播美女主播,一,一刀烈火,一加手机,一念成瘾，陆太太嫁到,一念永恒,一美女,七界仙尊,万古天帝第一神,万古神皇,万古第一帝,万域之王,万炮捕鱼捕鱼,三剑,三国,三国 手游,三国11,三国三国三国游戏,三国之力震天下,三国之召唤猛将,三国之吕布天下,三国乱世手机版,三国人物,三国傲世无双,三国全面战争,三国全面战争手游,三国关云长,三国加强版,三国单机游戏下载,三国历史,三国名将传手游,三国塔防手游排行榜,三国塔防游戏,三国塔防类游戏,三国大时代5,三国威力加强版手游,三国小说,三国带兵打仗的游戏,三国志,三国志11,三国志11华夏风云最终,三国志11武将,三国志11补丁,三国志13,三国志15威力加强版,三国志2017攻略,三国志5,三国志9,三国志9手机版,三国志三国志,三国志下载,三国志单机,三国志吞食天地,三国志吧,三国志大全,三国志威力加强版,三国志孔明传,三国志左慈,三国志战略版,三国志战略版官方版,三国志手机游戏,三国志手游单机,三国志手游攻略,三国志手游破解版,三国志的,三国志的手游,三国志赵云传,三国快打游戏,三国战争,三国战争策略游戏,三国战纪官网,三国战纪游戏,三国战记网游,三国手机卡牌,三国手机游戏大全,三国手机网游,三国挂机游戏,三国攻城志手游,三国放置版,三国放置英雄武将搭配,三国新吕布,三国无双,三国无双7,三国杀的游戏规则,三国杀神赵云,三国游戏,三国游戏哪个最好玩,三国游戏手机版,三国演义,三国演义是哪三国,三国火烧赤壁,三国版游戏,三国的手游,三国神将,三国神将传,三国第一猛将并非吕布,三国策略,三国策略手游,三国策略手游单机版,三国策略手游排行榜,三国策略类,三国策略类手机游戏,三国类战争策略游戏,三国类手游,三国类游戏排行,三国类的游戏,三国系列单机游戏,三国群侠传下载,三国群殴传,三国群英,三国群英1,三国群英8,三国群英ol,三国群英传,三国群英传1手机版单机,三国群英传3加强版,三国群英传三,三国群英传三国鼎立,三国群英传军师,三国群英传官网,三国群英传手机,三国群英传手机版单机,三国群英传手游版攻略,三国群英传秘籍,三国群英传装备,三国群英变态版,三国群英游戏,三国群英纪,三国群英转,三国英雄无敌,三国街机,三国许攸,三国连环战手游,三国题材卡牌游戏,三维城市建造游戏,下游戏下载,下载,下载手机免费游戏,下载手机游戏安卓,下载棋牌,下载迷失尸境,下载麻将欢乐麻将,不嫁总裁,不是回合制手游,不灭帝尊,不花钱的三国手游,不限购楼盘,世界未末日,东风标致suv,丧尸之战,丧尸乐园,丧尸全部游戏,丧尸军团,丧尸出笼,丧尸危机,丧尸围城4,丧尸国度,丧尸国度第一季,丧尸游戏,丧尸电影,丧尸电影大全排行榜,丧尸系列游戏,个人急售二手房,中国,中年女交友,中年女人单身群,中式四合院别墅设计,丹武九重天,主宰三界,乒乓球教学,九州天空城,九游,九阳神功,九阴真经,九阴绝学,买房,买房产,买房价格,买房子,买苹果手机,买车,乱世三国志游戏,乱轰三国志武将,二战,二战游戏,二战风云,二手房价,二手房价格,二手房装修,二手车估价,云墨行,五粮液股票,亚洲,交友网免费,交友软件,交易平台,亦庄楼盘,人体艺术,人气手游,人道至尊,什么传奇游戏,仗剑江湖,仙侠传手游,仙侠剧,仙侠动漫,仙侠手游下载,仙侠游戏下载,仙侠游戏名字大全,仙侠网游,仙剑,仙境传说,仙武帝尊免费全文阅读,仙灵觉醒,仙路至尊 小说,休闲游戏排行,休闲经营游戏,休闲裤,休闲零食店加盟,传奇1.76,传奇999级,传奇一刀,传奇一刀999级,传奇上线10000级,传奇世界,传奇世界2吧,传奇世界之不死之身,传奇世界手游脚本,传奇世界新手怎么玩,传奇世界高爆版,传奇了,传奇兑换码,传奇内挂,传奇刀刀切割,传奇原版手游,传奇变态版本下载,传奇可以赚钱吗,传奇合击版,传奇哪里下,传奇官网,传奇战域,传奇手游,传奇手游推广,传奇手游游戏,传奇手游点卡版,传奇手游电脑版,传奇手游网,传奇挂机游戏,传奇暴击版,传奇暴服版,传奇来了,传奇来了满v无限元宝,传奇永恒什么时候公测,传奇游戏排行榜,传奇火龙,传奇火龙挂,传奇版,传奇王者,传奇盒子,传奇至尊,传奇蓝月手游,传奇超变版,传奇超变版本下载,传奇超级爆率版,传奇迷失版本,传奇送vip,传奇通用登陆器,传奇高爆,传奇高爆版,作文,使命召唤手游下载,俄罗斯,保卫萝卜3,修仙世界,修仙归来,修仙手游推荐,修真劫,假面骑士,健康管理师报考条件,僵尸感染,僵尸末日,僵尸突围,免下载游戏,免安装麻将机,免费下载游戏大全,免费修仙狂徒有声小说,免费全本小说言情,免费全本已完结小说,免费听书小说,免费完整小说,免费小说修仙狂徒,免费小说在线,免费小说推荐,免费小说新版,免费模拟人生,免费游戏大全,免费的直播,兑换的捕鱼,全屋整装,全本书免费阅读,全本免费小说都市修仙,全本小说免费阅读,全民奇迹mu下载,全民奇迹充值,全民奇迹大天使之杖,全民奇迹开服,全民斗地主下载,全民突击,全职魔法师,全自动麻将机,全面战争罗马2,公交,六复古传奇官网,关于三国游戏,关于三国的游戏,关于动漫,养成游戏,内裤男,冒泡棋牌游戏大厅,冒险家,冒险岛,冒险岛2官网国服,冒险岛手游修改版,冒险岛攻略,冒险游戏,军事手游,农村,冬虫夏草的功效与作用及食用方法,冰种翡翠手镯价格,决战龙城,减肥的最好方法,凡人修仙的小说,刀刀暴击传奇,刀刀群秒,刀塔传奇2,刀塔传奇变态版,刀塔传奇礼包,刀塔英雄礼包,刚开传奇,别墅室内设计,别墅怎样装修,刷金币,剑3,剑侠世界手游下载,剑侠奇缘手游,剑灵17173,剑灵召唤,剑灵官网,剑神,剑神诀,剑神诀手游,剑诀,剑魂之刃下载,动态图片,动漫头像男,动漫女生人物图片,动漫少女漫画大全,动画头像,劲舞团,劳力士男表,勇士队,勇者之心,勇者斗恶龙,北京房价,十大好玩手游破解版,十大手机游戏,千炮捕鱼破解版无限金币,午夜小说,华为 荣耀9,华为p40,华为p7价格,华为手机好不好,华为手机性价比,华为新款手机,华为笔记本电脑,单机三国群英传3,单机塔防手游,单机小游戏,单机游戏三国志2,单机游戏三国志手机版,单机游戏红警,单机游戏红警3,单机版三国志,单机版三国战记下载,单机版传奇下载,单机的末日生存游戏,单机红警,单机红警下载,单田芳,单职业倍攻传奇,单职业打金传奇,单身男女,单身群,单间租房,卡地亚手表,卡牌游戏,即将公测的手游,即将开盘的楼盘,历史策略游戏,原神,原神觉醒,原装瑞士手表,去皱面膜,反恐精英,发型,口袋兽人,口袋妖怪go,口袋妖怪中文版,口袋妖怪漆黑的魅影,口袋妖怪火红,口袋妖怪银魂,口袋怪兽下载,口袋精灵复刻,古代战争策略游戏,古风歌曲,古驰,可以挂机的回合制手游,可以挂机的网络游戏,可以爆装备的手游,可爱的情侣头像,史上第一祖师爷,叶空修仙狂徒,吃鸡手游,吃鸡游戏,各种壁纸手机版,合击传奇,吉祥捕鱼,同城,同城交友,名将,名表,后宫,吞食三国,命运冠位指定从者,和女生聊天找话题,和平精英怎么样,哔哩哔哩,哪个捕鱼游戏好玩,哪些游戏好玩,唐家三少,唱吧,啊女人,啪啪三国类似游戏,啪啪王者荣耀,嘉善新房,嘉善楼盘房价,回合制手游抽神兽,回合制游戏,回合制网游新游,回忆传奇1.76金币,固安房价,国外购房,国战攻略,国战无双,国战游戏,国战类三国手游,国服魔兽月卡,国王游戏,圣斗士冥界篇,圣斗士名字,圣斗士星矢重生,在线电视剧观看,在线直播,在线美女,在线美女直播,在线观看,地下城,地下城堡2双狼怎么打,地下城游戏,地球末日生存,坦克世界,坦克之战,坦克前线帝国ol,坦克大战,坦克大战游戏下载,坦克射击,坦克帝国,坦克游戏,城堡塔防,塔防三国志官网,塔防三国志战法在哪里,塔防三国志手游官网,塔防塔防,塔防守卫者游戏,塔防游戏单机版下载,塔防西游记,复古传奇1.80,复古传奇180,复古传奇版本,复古传奇网站,复古版传奇,夏侯惇,多米音乐,大三国志,大亚湾楼盘,大众途锐报价,大剑天使,大唐无双手游,大型三国手游,大型单机游戏排行榜,大型游戏单机游戏,大天使之剑剑士,大天使之剑开服,大天使之剑漏洞,大天使之剑突破幻晶,大富翁,大恐龙,大桥未久,大秀直播,大衣搭配,大闹天宫捕鱼,大陆奇迹,天使,天堂2,天天三国战,天天斗三国,天天玩棋牌,天天美剧,天梭,天气,天气之换天气预报,天气今天天气预报,天气天气预报下载,天气预报,天气预报中国天气,天涯明月刀端游,天龙八部2888卡免费领取,天龙八部充值礼包,天龙八部荣耀版体验服,失眠,失眠了,奇迹mu,奇迹mu吧,奇迹mu怎么挂机,奇迹mu战士加点,奇迹mu手机,奇迹mu手机版,奇迹mu挂机点,奇迹mu武器大全,奇迹mu王者归来,奇迹mu荧光属性,奇迹mu觉醒手游,奇迹mu论坛,奇迹mu还有人玩吗,奇迹mu重生,奇迹之剑,奇迹单机版,奇迹圣域,奇迹战士加点,奇迹战士怎么加点,奇迹手游,奇迹暖暖,奇迹最新版本,奇迹游戏,奇迹类手机游戏,奇迹觉醒什么时候公测,奇迹魔域手游,奉贤房价,奔驰c级优惠,奥特曼怪兽,奥迪a4l促销,奥迪报价,女人与,女人内裤,女人出轨后的表现,女人征婚,女人性,女人找男人,女子,女性女,好玩三国策略手游,好玩的三国卡牌游戏,好玩的单机手游,好玩的联机手机游戏,好玩网游,好看的女尊小说,好看的校园小说,好看视频,如何挣钱,婚恋网,媳翁小说,孙悟空捕鱼,孤岛惊魂5,孤岛求生游戏,宅男,安卓手机游戏下载,安卓游戏排行榜,安居客,安居客新房,完整小说免费阅读,完美手游,官方麻将,官网,官网手游,宝马3系报价,宠物小精灵之,客户管理系统,富聊,射雕英雄传3d手游,将夜纪,小小魔兽,小播放器视频,小米手机,小说,小说三国,小说全本免费,小说大全免费阅读完结,小说岳风,小说欲妻,小说网络小说,小说肉文,小说阎王妻免费阅读,少儿人寿保险,少年三国2,少年三国志攻略,少年三国游戏,屏幕,屠龙之怒,屠龙天下,山海经神兽手游,崩坏,崩坏三,崩坏学园2,巅峰战舰,川村真矢,布偶猫,帝国ol全面战争下载,帝国手游,帝国文明,帝国时代2怎么玩,帝国时代2战役,帝国时代2花屏补丁,帝国时代3,帝国时代3亚洲王朝下载,帝国时代3亚洲王朝中文版,帝国时代3亚洲王朝手机版,帝国时代3修改器,帝国时代4,帝国时代决定版,帝国时代单机手机版,帝国时代手游攻略,帝国时代统治世界,帝国王朝,帝王三国名将列表,帝王三国游戏,带英雄无敌,平台游戏,幸存者危城,幸存者危城无限钻石,幸存者危城无限钻石版下载,幻想西游手游,幽冥白虎,广州地铁,广州火舞游戏决战沙邑,开奖结果,开网店,异界,张大仙,张无忌,当乐,影视动漫,影视大全免费观看,征途变态版,征途吧,征途游戏官方网站,御魂,御龙在天手游下载,微信,微信红包秒抢,微微一笑很倾城小说2,忍者必须死3,快乐捕鱼,快播电影,怀孕多久可以做b超,怀旧版征途,怎么样,怎么样留住男人的心,怎么看美女直播,怎样和女生聊天,怎样挽回前男友,怒火传奇,性感美女主播,怪兽大作战,总裁小说排行榜,恋爱养成类游戏,悟饭游戏厅,悦动报价,情侣头像,情感挽回,情歌,情话,惠州楼盘,成人影院,成人用品无人售货机加盟,我想找个女人,我本沉默迷失传奇,我的世界,我的世界吧,我的坦克我的团,我的极品老婆,我要买车,我要找女人,我要看三国,战争游戏,战争片电影,战争电影,战争的手游,战争策略,战争策略单机游戏,战争策略游戏大全,战争策略类手机游戏,战地1,战地2,战地4,战斗暴龙兽,战殇奇迹,战略三国游戏,战舰世界nga,战舰少女r,战觞奇迹,房产信息,房价,房屋拆迁,房屋装修,手机,手机三国策略游戏,手机休闲手机游戏,手机休闲游戏,手机免费游戏,手机助手,手机华为,手机单机三国游戏,手机变态版游戏,手机大型游戏,手机小游戏游戏,手机性价比,手机武侠游戏,手机游戏,手机游戏app,手机游戏交易平台哪个好,手机游戏战争策略,手机游戏排行榜,手机游戏策略游戏,手机版dnf地下城与勇士,手机版奇迹mu,手机策略游戏,手机赚钱app,手游,手游三国英杰传,手游下载排行榜,手游下载网站,手游仙侠坐骑,手游全面战争,手游公测手游,手游助手,手游塔防三国志,手游大全,手游战争,手游新,手游新发布,手游格斗游戏排行榜,手游游戏下载,手游礼包,手表回收价格,扑鱼达人3,打boss,打僵尸,打斗游戏,打造帝国,打金传奇,打金游戏,打鱼捕鱼,打鱼机器,打鱼电玩游戏机,找单身女人聊天,找老公的女人,找附近寂寞的女人,抗日红警,护肤,招商加盟,拳皇2002,拳皇98终极之战ol新版全民礼包领取,拳皇三国,挂机传奇下载,挂机手游,指挥官,捕鱼,捕鱼之深海捕鱼,捕鱼千炮,捕鱼大亨,捕鱼大作战,捕鱼季游戏,捕鱼开发,捕鱼总动员,捕鱼机头,捕鱼游戏下载平台,捕鱼游戏充值,捕鱼游戏大厅,捕鱼炮,捕鱼赢奖品,捕鱼达人4,捕鱼达人波克城市,换装,探探下载,推荐游戏,收藏酒,攻城掠地,攻城掠地马超觉醒,攻城略地,放开那三国 游戏,放开那三国2充值,放开那三国2礼包,放开那三国下载,放开那三国二,放开那三国交易,放置,放置三国,放置奇兵英雄,放置类游戏,故事,散人传奇新服,散人传奇送vip,文字小说玄幻,斗三国张辽,斗三国最新区,斗三国礼包,斗地主游戏大厅免费下载,斗战西游,斗牛比赛,斗罗,斗罗同人小说,斗罗大陆1,斗罗大陆2小说,斗罗大陆2漫画,斗罗大陆2绝世唐门漫画全集免费阅读,斗罗大陆三,斗罗大陆之绝世唐门,斗罗大陆之龙王传说,斗罗大陆免费阅读全文,斗罗大陆游戏攻略,斗罗大陆漫画全本下载,斗罗大陆电视剧,斗罗大陆顶点小说,斗罗大陆颠峰斗罗,斗罗大陆龙王,新三国争霸游戏,新三国塔防,新出游戏,新出的丧尸片,新剑侠情缘,新塔防游戏,新开楼盘信息,新开楼盘房价,新房如何装修,新房子开盘,新房开盘,新房房产,新房新楼盘,新房楼盘,新手游,新斗罗,新楼盘,新楼盘价格,新款宝马x1报价,新款宝马x5价格,新款手机,新款轿车报价,新版坦克大战,新能源汽车,新能源汽车大全,新西游记,新诛仙,新诛仙手游攻略,旅游攻略,无充值传奇,无双三国手游官网,无尽争霸手游,无尽尸城官方,无限火力,无限金币的游戏,日剧,时之歌,时代传奇,昆山新楼盘,昆明买房,明日之后,明日方舟,星球大战,星际争霸,星际争霸3,星际争霸虫族之心,星际战甲,星际未来,春装新款女装外套,显卡,普通麻将机免安装,暗黑三,暗黑之魂2,暗黑传奇礼包,暗黑单机版游戏,暗黑圣斗士,暗黑地下城与勇士,暗黑奇迹,暗黑破坏神3好玩吗,暗黑破坏神ol,暗黑血统2攻略,暗黑遗迹,最三国,最后的战争,最女人,最好玩的三国,最好玩的三国手游,最好玩的塔防游戏,最好玩的手机游戏,最好玩的捕鱼游戏,最好的三国手游,最强狂兵免费阅读全文,最强王者,最强神医,最新1.76传奇,最新suv价格,最新suv车型,最新捕鱼棋牌游戏大厅,最新款汽车报价,最新版王者荣耀前瞻,最新的仙侠手游,最新的苹果手机,最新策略手游,最终幻想觉醒,最美天气,朋友圈,望远镜,未来10倍牛股,未来周全国天气预报,末世为王 小说,末世之战,末世之无限兑换,末世之王,末世危城,末世求生,末日之后,末日之战网游,末日决战,末日前线官方,末日危城虐心,末日围城,末日围城破解版,末日孤舰,末日求生游戏,末日求生游戏手机游戏,末日生存大师,末日血战,末日血战兑换码,末日血战官网,末日血战正版,末日血战阵容,末日规则 下载,末日逃生,本田雅阁,杀三国,李丽珍,极品翡翠手镯价格,极品驸马小说免费阅读,果宝三国游戏,枪战游戏,校花梦工厂,核桃手串,格斗游戏,梦仙侠,梦幻之,梦幻剧情,梦幻官方网站,梦幻手游梦幻手游,梦幻西游2职业选择,梦幻西游之雷怒危机,梦幻西游大,梦幻西游官网,梦幻西游宠物进阶,梦幻西游攻略,梦幻西游礼包大全,梦幻西游竖琴价格,梦幻西游网易版官网,梦幻诛仙吧,梦想三国全集,梦游江湖手游,梦醒三国,棋牌捕鱼牛牛娱乐,棋牌游戏,植物大战僵尸,植物大战僵尸无敌,植物大战僵尸无限内购版,植物大战僵尸破解版,楚汉传奇手游,楼盘,楼盘价格,楼盘信息,楼盘房价,模型制作,模拟人生3秘籍,模拟人生4,模拟人生游戏,模拟农场,模拟经营类手游,樱花,次元大作战回归,欢乐捕鱼,欣文学小说,欧米茄手表价格,欧米茄男士手表,欧美一级特黄大片视频,歌曲,歌曲mp3,正版传奇,正版传奇一刀999级,正版海贼王手办,正统三国,正规网络兼职赚钱平台,武侠小说排行榜完本,武帝,武易游戏,武极天下,武神空间,死神vs火影,毁灭,比亚迪优惠,比较好玩的三国游戏,水无濑优夏,水果忍者,永恒塔防,永恒魔法,求生世界,求生之路,江湖行手游,汽车,波克捕鱼官网,波克捕鱼游戏,泽尻绘里香,流量宝,浪琴手表官方旗舰店,海口房价,海岛奇兵破解无限钻石,海战,海战世界国服,海战游戏,海王捕鱼最新版,海贼王上古七大果实,海贼王剧场版,海贼王强者之路,海贼王游戏单机版,海贼王漫画,海贼王漫画下载,海阳天气预报,涨停,混沌剑神小说,混沌弑神诀,清朝穿越小说,清纯美女,游戏,游戏三国之英雄传说,游戏三国游戏,游戏下载平台,游戏充值中心,游戏充值平台,游戏助手,游戏单机游戏,游戏在线游戏,游戏塔防游戏,游戏大厅下载,游戏大厅捕鱼下载,游戏平台下载,游戏热门游戏,游戏牌,游戏王单机手游,游戏王卡牌,游戏王网络游戏,游戏玩游戏,游戏盒子,游戏超级战舰,漂亮美女,漫画,漫画版,火影忍者1,火影忍者什么,火影忍者小樱,火影忍者手游,火影忍者漫画同人,火影忍者真人版,火影忍者羁绊,火龙,火龙王奇迹,炉石传说隐藏任务,点券,烈火雷霆,烈焰战神,热血三国2,热血三国3,热血传奇2,热血冒险岛,热血征途,热血江湖,热血问战,热门手游游戏,烽火三国,烽火戏诸侯,爆笑三国,爆装备的手游,爱你,牛仔裤,特斯拉新款,特色餐饮加盟,狂三国,狂斩三国,狂暴幻想之迷失尸境,狙击精英4,独栋别墅出售,玄天邪尊,玄幻奇幻小说排行榜,玄幻小说族,玄幻小说的巅峰,率土之滨五星,率土之滨武将搭配,率土之滨的乱世,王城争霸,王庚,王王者荣耀前瞻版,王者传奇手游官网,王者军团,王者归来,王者联盟,王者荣耀,王者荣耀之,王者荣耀什么英雄厉害,王者荣耀充值,王者荣耀前瞻版皮肤,王者荣耀即将出的皮肤,王者荣耀哪吒视频,王者荣耀国服东皇,王者荣耀新英雄时间表,王者荣耀最强王者一星,王者荣耀版本,王者荣耀电竞俱乐部,王者荣耀的,玩大天使之剑,玩的游戏,现在手机,现场直播,现房,现棋牌游戏,珍藏茅台,理查德米勒手表,生化危机,生存战,生存游戏,生存游戏推荐,生存类游戏,用什么捕鱼,电焊工培训,电玩游戏下载,电玩游戏机捕鱼,电视剧排行榜,电视直播频道,男人,男发型,男性感内裤,男朋友,男生什么发型好看,男穿越小说全本阅读,疫情,疯狂原始人,疯狂塔防战,白酒茅台价格,百度三国杀,百战天下,皇室战争,皇室战争下载,皓月传奇,皓月传奇礼包,盛世三国,盛大1.76传奇,直播美女直播,看大片,看最新电影,看美女主播,看黄片,真三国,真三国快打,真三国无双,真人美女主播,真实3d捕鱼,真实美女,真放置三国,真无双三国游戏,真正末日,真正的复古传奇,短篇言情小说免费,石家庄房产,砍传奇,破解版手游,碧蓝航线,神兽,神原,神将三国关羽,神舟战神笔记本,神都夜行录,福州房价,福特新车,租房信息,租房车,空气能热泵,穿搭女,穿越,穿越小说免费阅读全文,穿越小说吧免费阅读,穿越火线网页游戏,穿越言情小说,笑傲江湖,第一季,策略型手游,策略手游,策略游戏三国群雄传,策略类三国,简单,类似三国游戏,类似三国策略游戏,类似三国群英传的手机游戏,类似三国群英传的游戏,类似帝王三国手游,类似魔兽rpg的手游,类似魔域的游戏,类地下城与勇士手游,精神分裂症,红包版,红手指,红烧肉的做法,红翡翠手镯,红色警戒,红色警戒1,红警2坦克,红警单机,红警坦克ol,红警坦克大战,红警坦克官网,红警坦克战,红警塔防,红警大战,红警大战之坦克风暴,红警大战吧,红警大战黄金坦克,红警如何空投坦克,红警手机版,红警攻略,红警破解版,红警红警,约会交友软件,约会附近的人,终极斗罗,经典三国志单机游戏,经典歌曲,经典的小说,经营游戏,经营策略游戏,结婚生子游戏,绝世剑神 小说,绝地求生怎么下载,统一三国,缅甸旅游,网店货源,网易三国手游,网游三国之无敌村庄,网游加速器,网站,网络捕鱼平台,网络游戏排行,网络策略游戏,网页捕鱼,美人三国志,美女,美女三国游戏,美女主播在线观看,美女人,美女啊,美女图片,美女图片可爱,美女来了,美女没穿内衣内裤,美女照片,美女秀场直播,美女秀直播,美女脱衣直播,美女诱惑,美眉直播,群英,群雄三国志手游,翡翠冰种,翡翠玉手镯,翡翠玉石手镯,翡翠的等级和价格,翻译,老子是阎王,老梁,老爷吉祥开服表,老版三国,老版三国游戏,老版三国游戏单机,耐玩的安卓手机游戏,聊天群,聊天记录删除了怎么恢复,股票大盘,胡,能赢钱的捕鱼,至尊蓝月激活码,航海王破解版,航海王限定版,航海策略游戏,良心传奇,艾尔之光,艾希,艾泽拉斯,花桥房价,花田,苍之纪元阵容组合,英雄三国,英雄三国杀,英雄三国游戏,英雄对决,英雄无敌,英雄无敌3攻略,英雄无敌3死亡阴影,英雄无敌3死亡阴影安卓,英雄无敌之土匪领主,英雄无敌之战争纪元,英雄无敌公测,英雄无敌变态,英雄无敌布阵,英雄无敌战争纪元新服攻略,英雄英雄联盟,英雄连2,苹果,苹果5s价格,苹果7plus,苹果六,苹果手机,苹果的手机,范冰冰,茅台不老酒,茅台国隆酒,茅台汉酱酒价格,茅台白酒,茅台酒,茅台酒回收价格,茅台醇,茅台镇五星珍藏酒,茅台镇原浆酱香酒价格,茅台镇品鉴酒,茅台镇白酒,茅台镇窖藏原浆酒兼香型,茅台镇窖藏酒,茅台镇系列酒,茅台镇酒,茅台镇酒厂,茅台高尔夫酒价格,荒岛求生,荒岛求生游戏,荒野,荣耀9x,荣耀9xpro,荣耀王者最强王者,菜谱,菜谱家常菜土豆做法,萌三国漫画,蒸馒头,蓝月至尊版下载,蓝月至尊版官方下载,蛊真人,血战,街头霸王,街机三国,街机三国网游,街机捕鱼,街机捕鱼大厅,街机捕鱼平台,街机摇钱树捕鱼,街机电玩城,街机金蟾捕鱼红包,街机金蟾捕鱼联网版,街霸,衣服搭配,衬衫,西方玄幻小说,西游变态版官网,西游手游,西游游戏,视频,视频播放器免费,言小说,言情|免费小说,言情小說,言情小说免费阅读全本,言情小说吧,言情小说在线阅读,詹姆斯夺冠,试玩游戏,诛魔,说电影,谁主三国,谈恋爱,豆丁免费小说,象棋,财税筹划,贪玩蓝月手机版,贪玩蓝月手游,贪玩蓝月至尊版官网,贵州旅游攻略自由行,赚钱手游,赤月传奇3,赵丽颖,赵庭洞穿越小说,赵文卓,超变传奇至尊版,超变攻速版传奇手游,超声波捕鱼,超级三国群英手游,超级红包,超能英雄手游,超高爆率的传奇游戏,足球,足球直播,足球经理,跑步鞋,轩辕传奇,辐射避难所,达人捕鱼2,还女人,这就是战争,进击吧!三国,连天气预报,连衣裙,迷你世界,迷你世界丧尸,迷失尸境,迷失尸境官网,迷失尸境攻略,迷失尸境游戏,迷失尸境激活码,逃生游戏,逆剑狂神,逆剑狂神最新章节免费阅读,逍遥诀,途观l,那些电影,那里有红包领,部落冲突9本部落战阵型,部落战魂,都市仙尊,都市至尊仙医,都市艳妇小说全文阅读,都市言情小说,酷睿笔记本,醉三国手游,重庆新房,重楼,野外生存,野钓钓鲫鱼调漂图解,金庸武侠电视剧,金蟾打鱼捕鱼游戏,钓鱼技巧,钟会三国杀,钻石奇迹,问道,问道塔防,问道外传,问道攻略,问道最新版,问道问道,阅文,阿拉德之怒,阿瓦隆之王,阿瓦隆之王龙之战役,附近人约,附近出租房,附近四十岁单身女人,附近寂寞单身女人,附近约,附近美女单身,降临诸天,随便玩王麻将,雷神怒击,雷霆传奇游戏下载,雷霆霸业,雷鸣三国游戏,霸三国名将,青云,青春校园小说,韩国第一性感美女,音乐,音响,页游,顺义房价,领土战争手游,飘渺西游,飞天茅台53度,飞天茅台53度价格,飞天茅台酒,飞天茅台酒53度价格,飞常准,飞机,飞禽走兽,高德地图,高清动漫图片,高清头像,鬼泣4安卓版,魄斗罗,魔兽rpg,魔兽三国,魔兽世界,魔兽世界任务,魔兽世界充值,魔兽世界冰封王座,魔兽世界国服英雄榜,魔兽世界官,魔兽世界客户端下载,魔兽世界快速升级,魔兽世界战场,魔兽世界战网登陆,魔兽世界鲁克玛,魔兽争霸3,魔兽充值,魔兽剧情,魔兽和魔兽世界,魔兽地图,魔兽塔防,魔兽对战,魔兽归来,魔兽战役,魔兽战网点卡,魔兽攻略,魔兽王座,魔兽的手游,魔兽类单机游戏,魔兽英雄榜,魔兽金币交易平台,魔剑士,魔力捕鱼,魔域,魔域世界,魔域官方下载,魔域官方网,魔域手游特殊怪,魔域攻略,魔域永恒吧,魔域版本,魔域觉醒一区,魔域魔域,魔女猎人,魔尊,魔幻rpg手游,魔法门之英雄无敌战争纪元,魔法门英雄无敌战争纪元官网,麻将和了,麻将必赢,麻将技巧,麻将机,麻将机麻将,麻将的技巧,麻将秘决,麻将过庄,黄埔新房,黄蓉,黑暗之魂3,黑暗传奇,黑暗小说,黑暗帝国,黑暗游戏,龙城,龙城游戏,龙城霸业,龙将三国,龙武剑神,龙湖楼盘,龙珠觉醒,龙珠超宇宙自由对战,龙穴塔防2"
    ad_info = []
    for i in range(plan_result.shape[0]):
        ad_info.append(json.loads(plan_result.loc[i, ['autoExpansion','education', 'customAge', 'keywords',
           'keywordsExtend', 'newInterests', 'sex', 'iosVersion', 'androidVersion',
           'excludeTrans', 'region', 'device', 'age']].to_json()))
    plan_result['audience'] = ad_info
    plan_result.drop(['autoExpansion','education', 'customAge', 'keywords',
           'keywordsExtend', 'newInterests', 'sex', 'iosVersion', 'androidVersion',
           'excludeTrans', 'region', 'device', 'age'], axis=1, inplace=True)
    ad_info = []
    for i in range(plan_result.shape[0]):
        ad_info.append(json.loads(plan_result.loc[i, [ 'transType', 'ocpcLevel',
           'isSkipStageOne', 'payMode', 'optimizeDeepTrans', 'transFrom',
           'ocpcBid', 'deepOcpcBid', 'deepTransType', 'roiRatio', 'useRoi']].to_json()))
    plan_result['ocpc'] = ad_info
    plan_result.drop([ 'transType', 'ocpcLevel',
           'isSkipStageOne', 'payMode', 'optimizeDeepTrans', 'transFrom',
           'ocpcBid', 'deepOcpcBid', 'deepTransType', 'roiRatio', 'useRoi'], axis=1, inplace=True)
    plan_result['schedule'] = plan_result['ocpc'].apply(lambda x: [
                                                                        {
                                                                            "weekDay": 2,
                                                                            "startHour": 5,
                                                                            "endHour": 10
                                                                        },
                                                                        {
                                                                            "weekDay": 3,
                                                                            "startHour": 5,
                                                                            "endHour": 10
                                                                        },
                                                                        {
                                                                            "weekDay": 4,
                                                                            "startHour": 5,
                                                                            "endHour": 10
                                                                        }
                                                                    ])
    
    plan_result['bgtctltype'] = 2  # 加速投放
    plan_result['image_ids'] = plan_result['image_id'].apply(lambda x: [x])
    plan_result.drop('image_id', axis=1, inplace=True)
    plan_result.to_csv('./plan_result.csv', index=0)  # 保存创建日志
    return plan_result

# %%
def get_ad_create(plan_result):
    ad_info = []
    for i in range(plan_result.shape[0]):
        ad_info.append(json.loads(plan_result.iloc[i].to_json()))
#     open_api_url_prefix = "https://ptom-pre.caohua.com/"
    open_api_url_prefix = "https://ptom.caohua.com/"
    uri = "model/generationPlanBatchTask"
    url = open_api_url_prefix + uri
    params = {
        "secretkey": "abc2018!@**@888",
        "mediaId": 45
    }
    rsp = requests.post(url, json=ad_info, params=params)
    rsp_data = rsp.json()
    print('结束....')
    return rsp_data

# %%
if __name__ == '__main__':
#     ad_account_id_group = np.array([10507, 10508, 10509, 10510, 10511, 11368, 11369, 11370, 11371, 11372])   # 计划账号
#     ad_account_id_group = np.array([])
    ad_account_id_group = np.array([11369, 11370, 12228, 12229, 12230, 12231, 12232])
#     ad_account_id_group = np.array([10507])
    plan_num = 1  # 计划数量
    plan_result = get_plan(plan_num, ad_account_id_group)
    plan_result.drop('userPortrait', axis=1, inplace=True)
    print('计划数量', plan_result.shape[0])
    get_ad_create(plan_result)
# Out:
# 匹配的素材ID [42714 47038 47462 47479 47661 48239 48321 48366 48486 48577 48630]
# 计划数量 14
# 结束....
