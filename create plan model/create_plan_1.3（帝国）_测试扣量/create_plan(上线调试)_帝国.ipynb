# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import tensorflow as tf
from numpy import *
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from tensorflow.keras import layers,datasets
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from tensorflow import keras
import gc
# import warnings
# warnings.filterwarnings('ignore')
import lightgbm as lgb
import category_encoders as ce
from sklearn.metrics import f1_score,classification_report,roc_auc_score
from impala.dbapi import connect
from impala.util import as_pandas
import pymysql

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
def get_game_id():
    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL 
    '''
    cur.execute(sql)
    result_df = cur.fetchall()
    cur.close()
    conn.close()
    return result_df

# %%
# 获取近期所有计划('2021年5月7号开始')
def get_plan_info():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = pymysql.connect(host='192.168.0.65', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
                * 
            FROM
                db_ptom.ptom_third_plan p
            WHERE
                game_id IN ({})
                AND media_id = 10
                AND create_time>='2021-05-07'
                AND create_time<= date(NOW())
                            AND plan_id >= (
                                select plan_id from db_ptom.ptom_plan
                                where create_time >= '2021-05-07'
                                and create_time <= '2021-05-08'
                                limit 1
                            )
    '''
    finalSql = sql.format(game_id)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
# 获取image_id,label_ids
def get_image_info():
    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                        passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id,
            a.image_id,
            b.label_ids
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN
            db_data_ptom.ptom_image_info b
        on a.image_id = b.image_id
        WHERE
            a.game_id IN ( SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1112 AND dev_game_id IS NOT NULL ) 
            AND a.media_id = 10 
            AND a.create_time >= '2020-12-01' 
        GROUP BY
            a.chl_user_id,
            a.source_id,
            a.image_id
    '''
    cur.execute(sql)
    result_df = pd.read_sql(sql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
def get_launch_report():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id AS source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount as roi,
            b.pay_role_user_num / b.create_role_num as pay_rate
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN db_stdata.st_lauch_report b ON a.chl_user_id = b.channel_id 
            AND a.source_id = b.source_id 
        WHERE
            a.create_time >= '2020-12-01' 
            AND b.tdate >= '2020-12-01' 
            AND b.tdate_type = 'day' 
            AND b.media_id = 10
            AND b.game_id IN ({})
            AND b.amount >= 500
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')

    return result_df

# %%
# 解析json
def get_plan_json(plan_info):
    plan_info.drop(['inventory_type','budget'], axis=1, inplace=True)
    plan_info.dropna(how='all', inplace=True, axis=1)
    plan_info.dropna(subset=['ad_info'],inplace=True)
    # 解析json
    plan_info['ad_info'] = plan_info['ad_info'].apply(json.loads)
    temp = plan_info['ad_info'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('ad_info', axis=1, inplace=True)
    temp = plan_info['audience'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('audience', axis=1, inplace=True)
    temp = plan_info['action'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('action', axis=1, inplace=True)
    plan_info.dropna(how='all', inplace=True, axis=1)
    plan_info = plan_info[['ad_account_id', 'game_id', 'channel_id', 'source_id',
           'create_time', 'smart_bid_type', 'hide_if_exists', 'budget',
           'delivery_range', 'adjust_cpa', 'inventory_type', 'hide_if_converted',
           'flow_control_mode', 'schedule_time', 'cpa_bid', 'auto_extend_enabled',
           'gender', 'city', 'platform', 'launch_price',
           'retargeting_tags_exclude', 'interest_categories',
           'ac', 'android_osv', 'location_type', 'retargeting_tags_include',
           'retargeting_type', 'ios_osv', 'interest_action_mode', 'age',
           'action_categories', 'action_days', 'action_scene','deep_bid_type','roi_goal']]
    return plan_info

# %%
def get_all_data():
    # 读取历史数据
    plan_info = pd.read_csv('./hist_data/ptom_third_plan.csv')
#     image_info = pd.read_csv('./hist_data/image_info.csv')
#     launch_report = pd.read_csv('./hist_data/launch_report.csv')
    
    plan_info_new = get_plan_info()
    image_info = get_image_info()
    launch_report = get_launch_report()
    
    plan_info = plan_info.append(plan_info_new)
    plan_info = get_plan_json(plan_info)
#     image_info = image_info.append(image_info_new)
#     launch_report = launch_report.append(launch_report_new)
    image_info.dropna(subset=['image_id'],inplace=True)
    image_info['image_id'] = image_info['image_id'].astype(int)
    return plan_info,image_info,launch_report

# %%
plan_info,image_info,launch_report = get_all_data()

# %%
plan_info.shape
# Out:
# (42259, 35)

# %% [markdown]
# ### 构造新计划

# %%
# 获取score_image ()
def get_score_image():
    conn = connect(host='192.168.0.88', port=10000, auth_mechanism='PLAIN', user='hadoop',
                    password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql_engine = 'set hive.execution.engine=tez'
    sql = 'select image_id,label_ids from dws.dws_image_score_d where media_id=10 and score>=550 and dt=CURRENT_DATE group by image_id,label_ids'
    cursor.execute(sql_engine)
    cursor.execute(sql)
    result = as_pandas(cursor)
    result['label_ids'] = result['label_ids'].astype(str)
    result['label_ids'] = result['label_ids'].apply(lambda x: x.strip('-1;') if '-1' in x else x)
    result['label_ids'] = pd.to_numeric(result['label_ids'],errors='coerce')

    # 关闭链接
    cursor.close()
    conn.close()
    
    return result['image_id'].values

# %%
plan_info['create_time'] = pd.to_datetime(plan_info['create_time'])
plan_info_current = plan_info[plan_info['create_time']>=pd.datetime.now() - pd.DateOffset(8)]
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
# 获取近期计划的运营数据
def get_now_plan_roi():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
          b.channel_id,
          b.source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount AS roi,
            b.pay_role_user_num / b.create_role_num AS pay_rate 
        FROM
            db_stdata.st_lauch_report b
        WHERE
            b.tdate >= date( NOW() - INTERVAL 120 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 10 
            AND b.game_id IN ({}) 
            AND b.amount >= 500 
            AND b.pay_role_user_num >= 2 
            AND b.new_role_money >= 90
            AND (b.new_role_money / b.amount)>=0.03
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')
#     result_df = result_df[result_df['roi'] >= 0.03]
    return result_df

# %%
# 获取近期优化计划的创意数据
def get_creative():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.65', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/ 
        SELECT
            b.chl_user_id AS channel_id,
            b.source_id,
            JSON_EXTRACT( a.creative_param, '$.ad_keywords' ) AS ad_keywords,
            JSON_EXTRACT( a.creative_param, '$.title_list' ) AS title_list,
            JSON_EXTRACT( a.creative_param, '$.third_industry_id' ) AS third_industry_id 
        FROM
            db_ptom.ptom_batch_ad_task a
            LEFT JOIN db_ptom.ptom_plan b ON a.plan_name = b.plan_name 
        WHERE
            a.media_id = 10 
            AND b.create_time >= date( NOW() - INTERVAL 720 HOUR )    # 近30天
            AND a.game_id IN ({}) 
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result

# %%
creative_info = get_creative()
creative_info['title_list'] = creative_info['title_list'].fillna('[]')
creative_info['ad_keywords'] = creative_info['ad_keywords'].fillna('[]')
creative_info['title_list'] = creative_info['title_list'].apply(json.loads)
creative_info['ad_keywords'] = creative_info['ad_keywords'].apply(json.loads)

# %%
now_plan_roi = get_now_plan_roi()
now_plan_roi = pd.merge(now_plan_roi,creative_info,on=['channel_id','source_id'],how='left')

# %%
now_plan_roi.head()
# Out:
#    channel_id  source_id      tdate   amount  new_role_money       roi  \
# 0        6231     634667 2021-05-15  8005.87           336.0  0.041969
# 1       21146     646010 2021-05-15  2761.48           121.0  0.043817
# 2       21318     644906 2021-05-15  2358.62           440.0  0.186550
# 3       21316     646142 2021-05-15  2143.68           113.0  0.052713
# 4       21297     641512 2021-05-15  7264.54          1298.0  0.178676
#
#    pay_rate                                        ad_keywords  \
# 0    0.0345                             [游戏, 战争游戏, 策略游戏, 新闻热点]
# 1    0.0235  [英雄联盟, 万国觉醒, 三国游戏, 战略, 体育, 三国, 文明6, 帝国, 魔兽争霸3,...
# 2    0.0625  [帝国, 文明, 美女, 长腿, 小姨子, 女忧, 豪车, 科技, 5G, 科普, 历史, ...
# 3    0.0476  [游戏, 手游, 帝国, SLG, 文明, 铁甲, 列王的纷争, COK, 万国觉醒, 策略...
# 4    0.1000  [三国志, 帝国, 策略手游, 战争策略, 传奇, 万国觉醒, 策略游戏, 红色警戒, 军队...
#
#                                           title_list third_industry_id
# 0  [{'title': '小时候玩的帝国终于出手游了！开局5个农民，建立你的帝国！', 'cr...          19131201
# 1  [{'title': '苦等20年，帝国终于出手游了！满满的儿时回忆，老玩家已感动哭！', ...          19131201
# 2  [{'title': '三大阵营，谁会是你的时代！', 'creative_word_ids...          19131401
# 3  [{'title': '苦等20年，帝国终于出手游了！满满的儿时回忆，老玩家已感动哭！', ...          19131201
# 4  [{'title': '全球SLG玩家的选择：真实兵种自由搭配，成败靠脑不靠肝！', 'cr...          19131201

# %%
now_plan_roi.shape
# Out:
# (47, 10)

# %%
score_image = get_score_image()

# %%
score_image
# Out:
# array([30438, 31184, 31277, 31363, 31408, 31642, 32030, 32171, 32187,
#        32284, 32633, 32719, 33022, 33024, 33025, 33099, 33115, 33134,
#        33285, 33315, 33348, 33429, 33437, 33547, 33551, 33559],
#       dtype=int64)

# %%
image_info.head()
# Out:
#    channel_id  source_id  image_id label_ids
# 1        6231     476667     29773   117,120
# 2        6231     476668     29249       124
# 3        6231     476669     29793       117
# 4        6231     476670     29339       124
# 5        6231     476671     29920       124

# %%
df_create = pd.merge(plan_info_current,image_info,on=['channel_id','source_id'],how='left')
df_create = pd.merge(df_create,now_plan_roi,on=['channel_id','source_id'],how='inner')
df_create['platform'] = df_create['platform'].astype(str)
df_create['platform'] = df_create['platform'].map({"['ANDROID']":1,"['IOS']":2})
df_create['platform'] = df_create['platform'].astype(int)

# %%
df_create.dropna(subset=['image_id'],inplace=True)
df_create['image_id'] = df_create['image_id'].astype(int)

# %%
df_create = df_create[df_create['platform']==1]

# %%
df_create.shape
# Out:
# (39, 45)

# %%
df_create.head()
# Out:
#    ad_account_id  game_id  channel_id  source_id         create_time  \
# 1           7504  1001619       21297     641512 2021-05-13 10:20:38
# 2           6616  1001619       21146     644058 2021-05-14 11:13:37
# 3           6617  1001619       21146     644061 2021-05-14 11:13:39
# 4           6023  1001545        6231     644114 2021-05-14 11:20:36
# 5           6744  1001619       21146     644253 2021-05-14 11:31:36
#
#      smart_bid_type  hide_if_exists   budget delivery_range  adjust_cpa  \
# 1  SMART_BID_CUSTOM               0   3700.0        DEFAULT         0.0
# 2  SMART_BID_CUSTOM               0   2000.0        DEFAULT         0.0
# 3  SMART_BID_CUSTOM               0   2000.0        DEFAULT         0.0
# 4  SMART_BID_CUSTOM               0   3500.0        DEFAULT         0.0
# 5  SMART_BID_CUSTOM               0  10000.0          UNION         0.0
#
#                                       inventory_type hide_if_converted  \
# 1  [INVENTORY_HOTSOON_FEED, INVENTORY_TOMATO_NOVE...               APP
# 2                             [INVENTORY_AWEME_FEED]                AD
# 3                             [INVENTORY_AWEME_FEED]                AD
# 4             [INVENTORY_AWEME_FEED, INVENTORY_FEED]                AD
# 5                             [INVENTORY_UNION_SLOT]                AD
#
#         flow_control_mode                                      schedule_time  \
# 1  FLOW_CONTROL_MODE_FAST  0000000000000000000000000000000000000000000000...
# 2  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 3  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 4  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 5  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
#
#    cpa_bid  auto_extend_enabled       gender  \
# 1   651.19                    0  GENDER_MALE
# 2   589.14                    0  GENDER_MALE
# 3   589.64                    0  GENDER_MALE
# 4   488.88                    0  GENDER_MALE
# 5   666.80                    0         NONE
#
#                                                 city  platform launch_price  \
# 1  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...         1   [0, 11000]
# 2                                                 []         1   [0, 11000]
# 3                                                 []         1   [0, 11000]
# 4  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...         1   [0, 11000]
# 5  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...         1   [0, 11000]
#
#   retargeting_tags_exclude interest_categories          ac android_osv  \
# 1                       []                  []          []         7.0
# 2                       []                  []          []        NONE
# 3                       []                  []          []        NONE
# 4                       []                  []  [WIFI, 4G]         7.0
# 5                       []                  []          []        NONE
#
#   location_type retargeting_tags_include retargeting_type ios_osv  \
# 1          HOME                       []             NONE    NONE
# 2       CURRENT                       []              NaN    NONE
# 3       CURRENT                       []              NaN    NONE
# 4          HOME                       []              NaN    NONE
# 5       CURRENT                       []             NONE    NONE
#
#   interest_action_mode                                                age  \
# 1            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 2            RECOMMEND  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 3            RECOMMEND  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...
# 4            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 5            RECOMMEND                                                 []
#
#   action_categories  action_days action_scene   deep_bid_type  roi_goal  \
# 1               NaN          NaN          NaN  BID_PER_ACTION       NaN
# 2               NaN          NaN          NaN  BID_PER_ACTION       NaN
# 3               NaN          NaN          NaN  BID_PER_ACTION       NaN
# 4               NaN          NaN          NaN  BID_PER_ACTION       NaN
# 5               NaN          NaN          NaN  BID_PER_ACTION       NaN
#
#    image_id                label_ids      tdate   amount  new_role_money  \
# 1     30503                      130 2021-05-15  7264.54          1298.0
# 2     33134                       -1 2021-05-16  8493.42          1224.0
# 3     33134                       -1 2021-05-16  2953.63           270.0
# 4     32633                  114,117 2021-05-15  7476.64           381.0
# 5     33025  129,130,134,138,133,132 2021-05-17  9314.32           461.0
#
#         roi  pay_rate                                        ad_keywords  \
# 1  0.178676    0.1000  [三国志, 帝国, 策略手游, 战争策略, 传奇, 万国觉醒, 策略游戏, 红色警戒, 军队...
# 2  0.144112    0.0909  [英雄联盟, 万国觉醒, 三国游戏, 战略, 体育, 三国, 文明6, 帝国, 魔兽争霸3,...
# 3  0.091413    0.0769  [英雄联盟, 万国觉醒, 三国游戏, 战略, 体育, 三国, 文明6, 帝国, 魔兽争霸3,...
# 4  0.050959    0.0361                             [游戏, 战争游戏, 策略游戏, 新闻热点]
# 5  0.049494    0.0750  [英雄联盟, 万国觉醒, 三国游戏, 战略, 体育, 三国, 文明6, 帝国, 魔兽争霸3,...
#
#                                           title_list third_industry_id
# 1  [{'title': '全球SLG玩家的选择：真实兵种自由搭配，成败靠脑不靠肝！', 'cr...          19131201
# 2  [{'title': '帝国手游今日公测！建筑，开矿，扩张，建立属于自己的帝国！', 'cr...          19131201
# 3  [{'title': '帝国手游今日公测！建筑，开矿，扩张，建立属于自己的帝国！', 'cr...          19131201
# 4  [{'title': '小时候玩的帝国终于出手游了！开局5个农民，建立你的帝国！', 'cr...          19131201
# 5  [{'title': '苦等20年，帝国终于出手游了！满满的儿时回忆，老玩家已感动哭！', ...          19131201

# %%
df_create['game_id'].value_counts()
# Out:
# 1001545    18
# 1001619     7
# 1001635     3
# 1001469     2
# 1001685     2
# 1001667     2
# 1001655     1
# 1001683     1
# 1001680     1
# 1001668     1
# 1001493     1
# Name: game_id, dtype: int64

# %%
def create_plan(df, score_image):
    # 选ad_account_id、image_id每个账号+素材8条
    ad_account_id_group = np.array([7590, 7591, 7592, 7593, 7594])
    image_id_group = np.intersect1d(df['image_id'].unique(), score_image)
    print(image_id_group)
    df = df[df['deep_bid_type'].isin(['BID_PER_ACTION', 'ROI_COEFFICIENT'])]
    df = df[df['image_id'].isin(image_id_group)]
    game_id = 1001673
#     df = df[df['game_id'] == game_id]

    plan = pd.DataFrame()
    for ad_account in ad_account_id_group:
        for image in image_id_group:
            #         print(image)
            temp = pd.DataFrame({'ad_account_id': [ad_account], 'image_id': [image]})
            plan = plan.append(temp)
    #         print(temp)
    plan = pd.DataFrame(np.repeat(plan.values, 10, axis=0), columns=plan.columns)

    # game_image = df[['game_id', 'image_id']].drop_duplicates()
    # plan = pd.merge(plan, game_image, on='image_id', how='left')
    plan['game_id'] = game_id

    # 选platform测试期默认[ANDROID]
    plan['platform'] = df['platform'].iloc[0]
    plan['platform'] = plan['platform'].apply(lambda x: '[ANDROID]' if x == 1 else '[IOS]')

    # 选android_osv
    count_df = pd.DataFrame(data=df['android_osv'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['android_osv'] = plan['platform'].apply(lambda x: 'NONE' if x == '[IOS]' else
    np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0])

    # 选ios_osv
    count_df = pd.DataFrame(data=df['ios_osv'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['ios_osv'] = plan['platform'].apply(lambda x: 'NONE' if x == '[ANDROID]' else
    np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0])

    # 选budget
    plan['budget'] = plan['platform'].apply(lambda x: 3300 if x == '[ANDROID]' else 4000)

    # 选'ad_keywords', 'title_list', 'third_industry_id'  创意
    sample_df = df[['ad_keywords', 'title_list', 'third_industry_id']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'retargeting_type','retargeting_tags_include','retargeting_tags_exclude'  人群包定向
    sample_df = df[['retargeting_type', 'retargeting_tags_include', 'retargeting_tags_exclude']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'interest_action_mode','action_scene','action_days','action_categories' ,'interest_categories' 行为兴趣
    sample_df = df[['interest_action_mode', 'action_scene', 'action_days', 'action_categories', 'interest_categories']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'deep_bid_type','roi_goal','smart_bid_type','adjust_cpa','cpa_bid'出价方式
    sample_df = df[['deep_bid_type', 'roi_goal', 'smart_bid_type', 'adjust_cpa', 'cpa_bid']]
    sample_df = sample_df[sample_df['deep_bid_type'].isin(['ROI_COEFFICIENT', 'BID_PER_ACTION'])]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选
    cols = ['delivery_range', 'city', 'location_type', 'gender', 'age', 'ac', 'launch_price',
            'auto_extend_enabled', 'hide_if_exists', 'hide_if_converted', 'schedule_time', 'flow_control_mode']
    for col in cols:
        count_df = pd.DataFrame(data=df[col].value_counts()).reset_index()
        count_df.columns = ['col', 'counts']
        count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
        plan[col] = plan.apply(lambda x: np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0],
                               axis=1)

    # 选inventory_type 创意投放位置
    count_df = pd.DataFrame(data=df['inventory_type'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']

    for i in range(count_df.shape[0]):
        values = count_df.loc[i, 'col']

        for value in values:
            if value == None:
                values.remove(value)
        a = np.empty(1, dtype=object)
        a[0] = values
        count_df.loc[i, 'col'] = a
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['inventory_type'] = plan.apply(
        lambda x: np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0], axis=1)
    plan['create_time'] = pd.to_datetime(pd.datetime.now())
    plan['create_date'] = pd.to_datetime(pd.datetime.now().date())

    return plan

# %%
plan_create = create_plan(df_create, score_image)
# Out:
# [31184 31642 32633 32719 33025 33099 33134 33285 33315 33437 33547]
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:92: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:93: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
plan_create.shape
# Out:
# (550, 38)

# %%
plan_create['image_id'].value_counts()
# Out:
# 32719    50
# 31642    50
# 32633    50
# 33547    50
# 33437    50
# 33315    50
# 33285    50
# 31184    50
# 33134    50
# 33099    50
# 33025    50
# Name: image_id, dtype: int64

# %%
plan_create.head()
# Out:
#    ad_account_id  image_id  game_id   platform android_osv ios_osv  budget  \
# 0           7590     31184  1001673  [ANDROID]        NONE    NONE    3300
# 1           7590     31184  1001673  [ANDROID]        NONE    NONE    3300
# 2           7590     31184  1001673  [ANDROID]         7.0    NONE    3300
# 3           7590     31184  1001673  [ANDROID]         8.0    NONE    3300
# 4           7590     31184  1001673  [ANDROID]         7.0    NONE    3300
#
#                                          ad_keywords  \
# 0  [游戏, 手游, 对战, 军事手游, 三国志, 三国志策略版, 万国觉醒, 传奇, 深蓝战舰...
# 1  [游戏, 手游, 帝国, SLG, 文明铁甲, 列王的纷争, COK, 万国觉醒, 策略, ...
# 2  [手游, SLG, 策略, 战争策略, 策略手游, 最强王者, 我的使命, 红警, 帝国文明...
# 3                             [游戏, 战争游戏, 策略游戏, 新闻热点]
# 4  [三国志, 帝国, 策略手游, 战争策略, 传奇, 万国觉醒, 策略游戏, 红色警戒, 军队...
#
#                                           title_list third_industry_id  \
# 0  [{'title': '苦等20年，帝国终于出手游了！采集伐木，挖矿，打造你的帝国！', '...          19131201
# 1  [{'title': '开局被踢飞，你能打造出最强帝国么？', 'creative_word...          19131201
# 2  [{'title': '开局流落荒岛，填海造陆，挖矿伐木，白手起家，建立海岛王国！', 'c...          19131201
# 3  [{'title': '小时候玩的帝国终于出手游了！开局5个农民，建立你的帝国！', 'cr...          19131201
# 4  [{'title': '练兵、种植、升级建筑，还要防止领国的入侵，这是你的帝国之战！', '...          19131201
#
#   retargeting_type retargeting_tags_include  \
# 0              NaN                       []
# 1              NaN                       []
# 2             NONE                       []
# 3             NONE                       []
# 4              NaN                       []
#
#             retargeting_tags_exclude interest_action_mode action_scene  \
# 0                                 []            RECOMMEND          NaN
# 1                                 []            RECOMMEND          NaN
# 2                                 []            RECOMMEND          NaN
# 3                                 []            RECOMMEND          NaN
# 4  [317227650, 321333379, 321328670]            RECOMMEND          NaN
#
#    action_days action_categories interest_categories   deep_bid_type  \
# 0          NaN               NaN                  []  BID_PER_ACTION
# 1          NaN               NaN                  []  BID_PER_ACTION
# 2          NaN               NaN                  []  BID_PER_ACTION
# 3          NaN               NaN                  []  BID_PER_ACTION
# 4          NaN               NaN                  []  BID_PER_ACTION
#
#    roi_goal    smart_bid_type  adjust_cpa  cpa_bid delivery_range  \
# 0       NaN  SMART_BID_CUSTOM         0.0   564.57        DEFAULT
# 1       NaN  SMART_BID_CUSTOM         0.0   588.88        DEFAULT
# 2       NaN  SMART_BID_CUSTOM         0.0   625.16        DEFAULT
# 3       NaN  SMART_BID_CUSTOM         0.0   568.88        DEFAULT
# 4       NaN  SMART_BID_CUSTOM         0.0   564.57        DEFAULT
#
#                                                 city location_type  \
# 0  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...       CURRENT
# 1  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...          HOME
# 2                                                 []       CURRENT
# 3                                                 []       CURRENT
# 4  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...          HOME
#
#         gender                                                age          ac  \
# 0  GENDER_MALE  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...  [WIFI, 4G]
# 1  GENDER_MALE  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...          []
# 2  GENDER_MALE                                                 []          []
# 3  GENDER_MALE  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...          []
# 4  GENDER_MALE                                                 []  [WIFI, 4G]
#
#   launch_price  auto_extend_enabled  hide_if_exists hide_if_converted  \
# 0   [0, 11000]                    0               0               APP
# 1   [0, 11000]                    0               0                AD
# 2   [0, 11000]                    0               1                AD
# 3   [0, 11000]                    0               0               APP
# 4   [0, 11000]                    0               0               APP
#
#                                        schedule_time       flow_control_mode  \
# 0  1111111111111111111111111111111111111111110000...  FLOW_CONTROL_MODE_FAST
# 1  1111111111111111111111111111111111111111100000...  FLOW_CONTROL_MODE_FAST
# 2  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 3  0000000000000000000000111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 4  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
#
#                            inventory_type                create_time  \
# 0                  [INVENTORY_AWEME_FEED] 2021-05-20 15:31:05.227622
# 1  [INVENTORY_AWEME_FEED, INVENTORY_FEED] 2021-05-20 15:31:05.227622
# 2                  [INVENTORY_AWEME_FEED] 2021-05-20 15:31:05.227622
# 3                  [INVENTORY_AWEME_FEED] 2021-05-20 15:31:05.227622
# 4                  [INVENTORY_AWEME_FEED] 2021-05-20 15:31:05.227622
#
#   create_date
# 0  2021-05-20
# 1  2021-05-20
# 2  2021-05-20
# 3  2021-05-20
# 4  2021-05-20

# %%
image_info.dropna(subset=['image_id'],inplace=True)
image_info['image_id'] = image_info['image_id'].astype(int)
plan_create = pd.merge(plan_create,image_info[['image_id','label_ids']].drop_duplicates(),on='image_id',how='left')

# %%
plan_info.head()
# Out:
#    ad_account_id  game_id  channel_id  source_id         create_time  \
# 0           6750  1001464       20788     418566 2020-12-28 18:43:18
# 1           6750  1001464       20788     418568 2020-12-28 18:43:16
# 2           6750  1001464       20788     418563 2020-12-28 18:43:17
# 3           6750  1001464       20788     418564 2020-12-28 18:43:17
# 4           6750  1001464       20788     418567 2020-12-28 18:43:16
#
#            smart_bid_type  hide_if_exists  budget delivery_range  adjust_cpa  \
# 0  SMART_BID_CONSERVATIVE               0  2000.0        DEFAULT         1.0
# 1  SMART_BID_CONSERVATIVE               0  2000.0        DEFAULT         1.0
# 2  SMART_BID_CONSERVATIVE               0  2000.0        DEFAULT         1.0
# 3  SMART_BID_CONSERVATIVE               0  2000.0        DEFAULT         1.0
# 4  SMART_BID_CONSERVATIVE               0  2000.0        DEFAULT         1.0
#
#                            inventory_type hide_if_converted  \
# 0  [INVENTORY_AWEME_FEED, INVENTORY_FEED]               APP
# 1  [INVENTORY_AWEME_FEED, INVENTORY_FEED]               APP
# 2  [INVENTORY_AWEME_FEED, INVENTORY_FEED]               APP
# 3  [INVENTORY_AWEME_FEED, INVENTORY_FEED]               APP
# 4  [INVENTORY_AWEME_FEED, INVENTORY_FEED]               APP
#
#         flow_control_mode                                      schedule_time  \
# 0  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 1  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 2  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 3  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 4  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
#
#    cpa_bid  auto_extend_enabled       gender city   platform launch_price  \
# 0  1498.47                    0  GENDER_MALE   []  [ANDROID]   [0, 11000]
# 1  1498.68                    0  GENDER_MALE   []  [ANDROID]   [0, 11000]
# 2  1498.68                    0  GENDER_MALE   []  [ANDROID]   [0, 11000]
# 3  1499.24                    0  GENDER_MALE   []  [ANDROID]   [0, 11000]
# 4  1499.46                    0  GENDER_MALE   []  [ANDROID]   [0, 11000]
#
#   retargeting_tags_exclude interest_categories          ac android_osv  \
# 0                       []                  []  [WIFI, 4G]         8.0
# 1                       []                  []  [WIFI, 4G]         8.0
# 2                       []                  []  [WIFI, 4G]         8.0
# 3                       []                  []  [WIFI, 4G]         8.0
# 4                       []                  []  [WIFI, 4G]         8.0
#
#   location_type retargeting_tags_include retargeting_type ios_osv  \
# 0       CURRENT                       []             NONE    NONE
# 1       CURRENT                       []             NONE    NONE
# 2       CURRENT                       []             NONE    NONE
# 3       CURRENT                       []             NONE    NONE
# 4       CURRENT                       []             NONE    NONE
#
#   interest_action_mode                                                age  \
# 0            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 1            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 2            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 3            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
# 4            RECOMMEND  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...
#
#   action_categories  action_days action_scene     deep_bid_type  roi_goal
# 0               NaN          NaN          NaN  DEEP_BID_DEFAULT       NaN
# 1               NaN          NaN          NaN  DEEP_BID_DEFAULT       NaN
# 2               NaN          NaN          NaN  DEEP_BID_DEFAULT       NaN
# 3               NaN          NaN          NaN  DEEP_BID_DEFAULT       NaN
# 4               NaN          NaN          NaN  DEEP_BID_DEFAULT       NaN

# %%
df = pd.merge(plan_info,image_info,on=['channel_id','source_id'],how='left')
df.dropna(subset=['image_id'],inplace=True)
df = pd.merge(df, launch_report,on=['channel_id','source_id'],how='left')
df.drop(df[df['tdate'].isna()].index,inplace=True)
df = df[df['amount']>=500]

df['platform'] = df['platform'].astype(str)
df['platform'] = df['platform'].map({"['ANDROID']":1,"['IOS']":2})
df['label'] = df.apply(lambda x: 1 if x.new_role_money/x.amount>=0.02 else 0,axis=1)
df['ad_account_id'] = df['ad_account_id'].astype('int')
df['image_id'] = df['image_id'].astype('int')
df.rename(columns={'tdate':'create_date'},inplace=True)
df['create_date'] = pd.to_datetime(df['create_date'])
df['create_time'] = pd.to_datetime(df['create_time'])

# %%
df.shape
# Out:
# (14938, 43)

# %%
df.drop(['budget','cpa_bid','channel_id','source_id','amount','roi','pay_rate',
         'new_role_money'],axis=1,inplace=True)

# %%
plan_create_train = plan_create.drop(['budget', 'cpa_bid','ad_keywords','title_list','third_industry_id'],axis=1)
plan_create_train['platform'] = plan_create_train['platform'].map({'[ANDROID]':1,'[IOS]':2})
df['train_label'] = 1
plan_create_train['train_label'] = 0
plan_create_train['label'] = -1

# %%
df = df.append(plan_create_train)

# %%
df['train_label'].value_counts()
# Out:
# 1    14938
# 0      550
# Name: train_label, dtype: int64

# %%
df['create_date'] = pd.to_datetime(df['create_date'])
df['ad_im_sort_id'] = df.groupby(['ad_account_id','image_id'])['create_time'].rank()
df['ad_game_sort_id'] = df.groupby(['ad_account_id','game_id'])['create_time'].rank()
df['im_ad_sort_id'] = df.groupby(['image_id','ad_account_id'])['create_time'].rank()

# %%
# 对列表内容进行编码降维
def get_mutil_feature(data):
    cols = ['inventory_type','age','city','retargeting_tags_include','retargeting_tags_exclude','ac','interest_categories',
       'action_scene','action_categories']
    for col in cols:
        if col in ['inventory_type','age']:
            data[col] = data[col].apply(lambda x:x if x==x else [])
            data = data.join(data[col].str.join('|').str.get_dummies().add_prefix(col+'_').reset_index(drop=True))
            data.drop(col,axis=1,inplace=True)

        else:
            data[col] = data[col].apply(lambda x:x if x==x else [])
            data[col]=data[col].apply(lambda x:[str(i) for i in x])
            data[col] = data[col].astype(str)
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
    
    gc.collect()
    return data

# %%
df = get_mutil_feature(df)

# %%
df['train_label'].value_counts()
# Out:
# 1    14938
# 0      550
# Name: train_label, dtype: int64

# %%
cat_cols = ['ad_account_id','game_id','schedule_time','delivery_range','flow_control_mode',
            'smart_bid_type','hide_if_converted','gender','location_type','launch_price','retargeting_type',
            'android_osv','ios_osv','interest_action_mode','action_days','image_id','label_ids','deep_bid_type']
from itertools import combinations
from tqdm import tqdm_notebook
cat_cross=[]
for col in tqdm_notebook(combinations(cat_cols,2)):
    df[str(col[0]) + '_'+str(col[1])] = df[col[0]].map(str)+'_'+df[col[1]].map(str)
    cat_cross.append(str(col[0]) + '_'+str(col[1]))

for col in cat_cols+cat_cross:
    df[col] = df[col].astype(str)
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
df['train_label'].value_counts()
# Out:
# 1    14938
# 0      550
# Name: train_label, dtype: int64

# %%
train_data = df[df['train_label']==1]
test_data = df[df['train_label']==0]
train_data.drop(['train_label','create_time','create_date'],axis=1,inplace=True)
test_data.drop(['train_label','create_time','create_date'],axis=1,inplace=True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test_data.shape
# Out:
# (550, 202)

# %%
# train_data, test_data = train_test_split(df, test_size=0.25)
target = train_data['label']
features = train_data.drop(['label'], axis=1)
X_val, x_test, Y_val, y_test = train_test_split(features,target, test_size=0.3)

# %%
params = {
"objective": "binary",
"boosting_type": "gbdt",
"learning_rate": 0.01,
"max_depth":8,
"num_leaves":55,
"max_bin":255,
"min_data_in_leaf":101,
"min_child_samples":15,
"feature_fraction": 0.5,
"bagging_fraction":0.6,
"bagging_freq":20,
"lambda_l1":1e-05,
"lambda_l2":0,
"min_split_gain": 0.0,
"metric": "auc",
'is_unbalance':True    
}

train_data = lgb.Dataset(X_val, label=Y_val)
val_data = lgb.Dataset(x_test, label=y_test, reference=train_data)
model = lgb.train(params, train_data, num_boost_round=8000, early_stopping_rounds=100, valid_sets=[train_data, val_data])
# Out:
# [1]	training's auc: 0.615534	valid_1's auc: 0.526501
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.632893	valid_1's auc: 0.522495
# [3]	training's auc: 0.645427	valid_1's auc: 0.526101
# [4]	training's auc: 0.649576	valid_1's auc: 0.524729
# [5]	training's auc: 0.6584	valid_1's auc: 0.524189
# [6]	training's auc: 0.663491	valid_1's auc: 0.530451
# [7]	training's auc: 0.664864	valid_1's auc: 0.533881
# [8]	training's auc: 0.669123	valid_1's auc: 0.533128
# [9]	training's auc: 0.671298	valid_1's auc: 0.53266
# [10]	training's auc: 0.672483	valid_1's auc: 0.533836
# [11]	training's auc: 0.673024	valid_1's auc: 0.53498
# [12]	training's auc: 0.675671	valid_1's auc: 0.53347
# [13]	training's auc: 0.677354	valid_1's auc: 0.532311
# [14]	training's auc: 0.677351	valid_1's auc: 0.532393
# [15]	training's auc: 0.677777	valid_1's auc: 0.533997
# [16]	training's auc: 0.679642	valid_1's auc: 0.532584
# [17]	training's auc: 0.679861	valid_1's auc: 0.53308
# [18]	training's auc: 0.67939	valid_1's auc: 0.534194
# [19]	training's auc: 0.680307	valid_1's auc: 0.535232
# [20]	training's auc: 0.681252	valid_1's auc: 0.533974
# [21]	training's auc: 0.686227	valid_1's auc: 0.536058
# [22]	training's auc: 0.6888	valid_1's auc: 0.536141
# [23]	training's auc: 0.690352	valid_1's auc: 0.536002
# [24]	training's auc: 0.691748	valid_1's auc: 0.536062
# [25]	training's auc: 0.694429	valid_1's auc: 0.537164
# [26]	training's auc: 0.695679	valid_1's auc: 0.537752
# [27]	training's auc: 0.697751	valid_1's auc: 0.537773
# [28]	training's auc: 0.698805	valid_1's auc: 0.539346
# [29]	training's auc: 0.701173	valid_1's auc: 0.539827
# [30]	training's auc: 0.702869	valid_1's auc: 0.540066
# [31]	training's auc: 0.704591	valid_1's auc: 0.539768
# [32]	training's auc: 0.706039	valid_1's auc: 0.539915
# [33]	training's auc: 0.707497	valid_1's auc: 0.541209
# [34]	training's auc: 0.708683	valid_1's auc: 0.541172
# [35]	training's auc: 0.710591	valid_1's auc: 0.542397
# [36]	training's auc: 0.710792	valid_1's auc: 0.542103
# [37]	training's auc: 0.711424	valid_1's auc: 0.542277
# [38]	training's auc: 0.711743	valid_1's auc: 0.542066
# [39]	training's auc: 0.712171	valid_1's auc: 0.542167
# [40]	training's auc: 0.713325	valid_1's auc: 0.542165
# [41]	training's auc: 0.714397	valid_1's auc: 0.543175
# [42]	training's auc: 0.716781	valid_1's auc: 0.543921
# [43]	training's auc: 0.717681	valid_1's auc: 0.543655
# [44]	training's auc: 0.719066	valid_1's auc: 0.544216
# [45]	training's auc: 0.720652	valid_1's auc: 0.544749
# [46]	training's auc: 0.722351	valid_1's auc: 0.545031
# [47]	training's auc: 0.722756	valid_1's auc: 0.545822
# [48]	training's auc: 0.722877	valid_1's auc: 0.546106
# [49]	training's auc: 0.724202	valid_1's auc: 0.546053
# [50]	training's auc: 0.724964	valid_1's auc: 0.546133
# [51]	training's auc: 0.726449	valid_1's auc: 0.545861
# [52]	training's auc: 0.72697	valid_1's auc: 0.545376
# [53]	training's auc: 0.727406	valid_1's auc: 0.545098
# [54]	training's auc: 0.728287	valid_1's auc: 0.545179
# [55]	training's auc: 0.729453	valid_1's auc: 0.545117
# [56]	training's auc: 0.73002	valid_1's auc: 0.545761
# [57]	training's auc: 0.730088	valid_1's auc: 0.545714
# [58]	training's auc: 0.730143	valid_1's auc: 0.545652
# [59]	training's auc: 0.730595	valid_1's auc: 0.546187
# [60]	training's auc: 0.731052	valid_1's auc: 0.545569
# [61]	training's auc: 0.733031	valid_1's auc: 0.546452
# [62]	training's auc: 0.734531	valid_1's auc: 0.546457
# [63]	training's auc: 0.736136	valid_1's auc: 0.547322
# [64]	training's auc: 0.736668	valid_1's auc: 0.547873
# [65]	training's auc: 0.737057	valid_1's auc: 0.547938
# [66]	training's auc: 0.738301	valid_1's auc: 0.547963
# [67]	training's auc: 0.739274	valid_1's auc: 0.548207
# [68]	training's auc: 0.740002	valid_1's auc: 0.548725
# [69]	training's auc: 0.741679	valid_1's auc: 0.549169
# [70]	training's auc: 0.743019	valid_1's auc: 0.549646
# [71]	training's auc: 0.744416	valid_1's auc: 0.550438
# [72]	training's auc: 0.745872	valid_1's auc: 0.55103
# [73]	training's auc: 0.74663	valid_1's auc: 0.550789
# [74]	training's auc: 0.747292	valid_1's auc: 0.550697
# [75]	training's auc: 0.747651	valid_1's auc: 0.550618
# [76]	training's auc: 0.74851	valid_1's auc: 0.55059
# [77]	training's auc: 0.749463	valid_1's auc: 0.550252
# [78]	training's auc: 0.750497	valid_1's auc: 0.550372
# [79]	training's auc: 0.751361	valid_1's auc: 0.55017
# [80]	training's auc: 0.75213	valid_1's auc: 0.550369
# [81]	training's auc: 0.753002	valid_1's auc: 0.550375
# [82]	training's auc: 0.753531	valid_1's auc: 0.550785
# [83]	training's auc: 0.753998	valid_1's auc: 0.550958
# [84]	training's auc: 0.75469	valid_1's auc: 0.551689
# [85]	training's auc: 0.755352	valid_1's auc: 0.551873
# [86]	training's auc: 0.755782	valid_1's auc: 0.551777
# [87]	training's auc: 0.756343	valid_1's auc: 0.551656
# [88]	training's auc: 0.757276	valid_1's auc: 0.551941
# [89]	training's auc: 0.757634	valid_1's auc: 0.552157
# [90]	training's auc: 0.757801	valid_1's auc: 0.552611
# [91]	training's auc: 0.758285	valid_1's auc: 0.552748
# [92]	training's auc: 0.758247	valid_1's auc: 0.552851
# [93]	training's auc: 0.758584	valid_1's auc: 0.552655
# [94]	training's auc: 0.758555	valid_1's auc: 0.55243
# [95]	training's auc: 0.758758	valid_1's auc: 0.552496
# [96]	training's auc: 0.758994	valid_1's auc: 0.552391
# [97]	training's auc: 0.759313	valid_1's auc: 0.552564
# [98]	training's auc: 0.759531	valid_1's auc: 0.552638
# [99]	training's auc: 0.759695	valid_1's auc: 0.552567
# [100]	training's auc: 0.759875	valid_1's auc: 0.5524
# [101]	training's auc: 0.760439	valid_1's auc: 0.552046
# [102]	training's auc: 0.760938	valid_1's auc: 0.551822
# [103]	training's auc: 0.761205	valid_1's auc: 0.552271
# [104]	training's auc: 0.761433	valid_1's auc: 0.552164
# [105]	training's auc: 0.761957	valid_1's auc: 0.551994
# [106]	training's auc: 0.762264	valid_1's auc: 0.551955
# [107]	training's auc: 0.762789	valid_1's auc: 0.552072
# [108]	training's auc: 0.763016	valid_1's auc: 0.552323
# [109]	training's auc: 0.763674	valid_1's auc: 0.552209
# [110]	training's auc: 0.763869	valid_1's auc: 0.551791
# [111]	training's auc: 0.764206	valid_1's auc: 0.551982
# [112]	training's auc: 0.764353	valid_1's auc: 0.551602
# [113]	training's auc: 0.764873	valid_1's auc: 0.550879
# [114]	training's auc: 0.765033	valid_1's auc: 0.550803
# [115]	training's auc: 0.765589	valid_1's auc: 0.550605
# [116]	training's auc: 0.765845	valid_1's auc: 0.550473
# [117]	training's auc: 0.766109	valid_1's auc: 0.550315
# [118]	training's auc: 0.766803	valid_1's auc: 0.550196
# [119]	training's auc: 0.7671	valid_1's auc: 0.549937
# [120]	training's auc: 0.767135	valid_1's auc: 0.549945
# [121]	training's auc: 0.76767	valid_1's auc: 0.550208
# [122]	training's auc: 0.768211	valid_1's auc: 0.550572
# [123]	training's auc: 0.768907	valid_1's auc: 0.55076
# [124]	training's auc: 0.769271	valid_1's auc: 0.55054
# [125]	training's auc: 0.769292	valid_1's auc: 0.550402
# [126]	training's auc: 0.76938	valid_1's auc: 0.550238
# [127]	training's auc: 0.769456	valid_1's auc: 0.549919
# [128]	training's auc: 0.769757	valid_1's auc: 0.549444
# [129]	training's auc: 0.769757	valid_1's auc: 0.549463
# [130]	training's auc: 0.770371	valid_1's auc: 0.54992
# [131]	training's auc: 0.770461	valid_1's auc: 0.549772
# [132]	training's auc: 0.770711	valid_1's auc: 0.549499
# [133]	training's auc: 0.770532	valid_1's auc: 0.549228
# [134]	training's auc: 0.770481	valid_1's auc: 0.549594
# [135]	training's auc: 0.77058	valid_1's auc: 0.549653
# [136]	training's auc: 0.770812	valid_1's auc: 0.550052
# [137]	training's auc: 0.770998	valid_1's auc: 0.550418
# [138]	training's auc: 0.771266	valid_1's auc: 0.550614
# [139]	training's auc: 0.771703	valid_1's auc: 0.550322
# [140]	training's auc: 0.772079	valid_1's auc: 0.55055
# [141]	training's auc: 0.772387	valid_1's auc: 0.550323
# [142]	training's auc: 0.772627	valid_1's auc: 0.550261
# [143]	training's auc: 0.772964	valid_1's auc: 0.550082
# [144]	training's auc: 0.773387	valid_1's auc: 0.549924
# [145]	training's auc: 0.773776	valid_1's auc: 0.549647
# [146]	training's auc: 0.774155	valid_1's auc: 0.549889
# [147]	training's auc: 0.774263	valid_1's auc: 0.549976
# [148]	training's auc: 0.774419	valid_1's auc: 0.549918
# [149]	training's auc: 0.774448	valid_1's auc: 0.549774
# [150]	training's auc: 0.774679	valid_1's auc: 0.54987
# [151]	training's auc: 0.774886	valid_1's auc: 0.549584
# [152]	training's auc: 0.774772	valid_1's auc: 0.549568
# [153]	training's auc: 0.775281	valid_1's auc: 0.549511
# [154]	training's auc: 0.775456	valid_1's auc: 0.549735
# [155]	training's auc: 0.775714	valid_1's auc: 0.549657
# [156]	training's auc: 0.776035	valid_1's auc: 0.549861
# [157]	training's auc: 0.776082	valid_1's auc: 0.550025
# [158]	training's auc: 0.776518	valid_1's auc: 0.549823
# [159]	training's auc: 0.776868	valid_1's auc: 0.549767
# [160]	training's auc: 0.77712	valid_1's auc: 0.54943
# [161]	training's auc: 0.777671	valid_1's auc: 0.549998
# [162]	training's auc: 0.778192	valid_1's auc: 0.550153
# [163]	training's auc: 0.778261	valid_1's auc: 0.549887
# [164]	training's auc: 0.778619	valid_1's auc: 0.550121
# [165]	training's auc: 0.77885	valid_1's auc: 0.550083
# [166]	training's auc: 0.779365	valid_1's auc: 0.550304
# [167]	training's auc: 0.779613	valid_1's auc: 0.550401
# [168]	training's auc: 0.779908	valid_1's auc: 0.550718
# [169]	training's auc: 0.779992	valid_1's auc: 0.551123
# [170]	training's auc: 0.780219	valid_1's auc: 0.551122
# [171]	training's auc: 0.780188	valid_1's auc: 0.551398
# [172]	training's auc: 0.780349	valid_1's auc: 0.551264
# [173]	training's auc: 0.780559	valid_1's auc: 0.551257
# [174]	training's auc: 0.780494	valid_1's auc: 0.551435
# [175]	training's auc: 0.780528	valid_1's auc: 0.551783
# [176]	training's auc: 0.780565	valid_1's auc: 0.551858
# [177]	training's auc: 0.780602	valid_1's auc: 0.552312
# [178]	training's auc: 0.780502	valid_1's auc: 0.55229
# [179]	training's auc: 0.780694	valid_1's auc: 0.552367
# [180]	training's auc: 0.780775	valid_1's auc: 0.552371
# [181]	training's auc: 0.781095	valid_1's auc: 0.552409
# [182]	training's auc: 0.781692	valid_1's auc: 0.552509
# [183]	training's auc: 0.782413	valid_1's auc: 0.552695
# [184]	training's auc: 0.782835	valid_1's auc: 0.552521
# [185]	training's auc: 0.783202	valid_1's auc: 0.552688
# [186]	training's auc: 0.783387	valid_1's auc: 0.552703
# [187]	training's auc: 0.783847	valid_1's auc: 0.552577
# [188]	training's auc: 0.784051	valid_1's auc: 0.552698
# [189]	training's auc: 0.784297	valid_1's auc: 0.552653
# [190]	training's auc: 0.784485	valid_1's auc: 0.552709
# [191]	training's auc: 0.784994	valid_1's auc: 0.552897
# [192]	training's auc: 0.785175	valid_1's auc: 0.552902
# [193]	training's auc: 0.785263	valid_1's auc: 0.552847
# [194]	training's auc: 0.785634	valid_1's auc: 0.552825
# [195]	training's auc: 0.785901	valid_1's auc: 0.552849
# [196]	training's auc: 0.786114	valid_1's auc: 0.552775
# [197]	training's auc: 0.78642	valid_1's auc: 0.552762
# [198]	training's auc: 0.786716	valid_1's auc: 0.552439
# [199]	training's auc: 0.786918	valid_1's auc: 0.55233
# [200]	training's auc: 0.787155	valid_1's auc: 0.552579
# [201]	training's auc: 0.787526	valid_1's auc: 0.552702
# [202]	training's auc: 0.787802	valid_1's auc: 0.552745
# [203]	training's auc: 0.788086	valid_1's auc: 0.55272
# [204]	training's auc: 0.788351	valid_1's auc: 0.552606
# [205]	training's auc: 0.788564	valid_1's auc: 0.552691
# [206]	training's auc: 0.789128	valid_1's auc: 0.552635
# [207]	training's auc: 0.789456	valid_1's auc: 0.552617
# [208]	training's auc: 0.789834	valid_1's auc: 0.552666
# [209]	training's auc: 0.7902	valid_1's auc: 0.552584
# [210]	training's auc: 0.790369	valid_1's auc: 0.552705
# [211]	training's auc: 0.790644	valid_1's auc: 0.552433
# [212]	training's auc: 0.790868	valid_1's auc: 0.552626
# [213]	training's auc: 0.791123	valid_1's auc: 0.55267
# [214]	training's auc: 0.791618	valid_1's auc: 0.55267
# [215]	training's auc: 0.791733	valid_1's auc: 0.552599
# [216]	training's auc: 0.791983	valid_1's auc: 0.55243
# [217]	training's auc: 0.792327	valid_1's auc: 0.552528
# [218]	training's auc: 0.792836	valid_1's auc: 0.552701
# [219]	training's auc: 0.792931	valid_1's auc: 0.552698
# [220]	training's auc: 0.793406	valid_1's auc: 0.553137
# [221]	training's auc: 0.793692	valid_1's auc: 0.553197
# [222]	training's auc: 0.793855	valid_1's auc: 0.552904
# [223]	training's auc: 0.794373	valid_1's auc: 0.552918
# [224]	training's auc: 0.795061	valid_1's auc: 0.552958
# [225]	training's auc: 0.795524	valid_1's auc: 0.552998
# [226]	training's auc: 0.795836	valid_1's auc: 0.553021
# [227]	training's auc: 0.796021	valid_1's auc: 0.553119
# [228]	training's auc: 0.7964	valid_1's auc: 0.553156
# [229]	training's auc: 0.796597	valid_1's auc: 0.553262
# [230]	training's auc: 0.796716	valid_1's auc: 0.553151
# [231]	training's auc: 0.797154	valid_1's auc: 0.552848
# [232]	training's auc: 0.797644	valid_1's auc: 0.552927
# [233]	training's auc: 0.797984	valid_1's auc: 0.552919
# [234]	training's auc: 0.798403	valid_1's auc: 0.552581
# [235]	training's auc: 0.798688	valid_1's auc: 0.552605
# [236]	training's auc: 0.798841	valid_1's auc: 0.552503
# [237]	training's auc: 0.799155	valid_1's auc: 0.55261
# [238]	training's auc: 0.799344	valid_1's auc: 0.552454
# [239]	training's auc: 0.79981	valid_1's auc: 0.552843
# [240]	training's auc: 0.800374	valid_1's auc: 0.552893
# [241]	training's auc: 0.800712	valid_1's auc: 0.553019
# [242]	training's auc: 0.801109	valid_1's auc: 0.552762
# [243]	training's auc: 0.801241	valid_1's auc: 0.552622
# [244]	training's auc: 0.801859	valid_1's auc: 0.552804
# [245]	training's auc: 0.802403	valid_1's auc: 0.552677
# [246]	training's auc: 0.802683	valid_1's auc: 0.552758
# [247]	training's auc: 0.802811	valid_1's auc: 0.552634
# [248]	training's auc: 0.803015	valid_1's auc: 0.552689
# [249]	training's auc: 0.803383	valid_1's auc: 0.552618
# [250]	training's auc: 0.80397	valid_1's auc: 0.552264
# [251]	training's auc: 0.804195	valid_1's auc: 0.552446
# [252]	training's auc: 0.804473	valid_1's auc: 0.552453
# [253]	training's auc: 0.804895	valid_1's auc: 0.552526
# [254]	training's auc: 0.805018	valid_1's auc: 0.552637
# [255]	training's auc: 0.805366	valid_1's auc: 0.552497
# [256]	training's auc: 0.805677	valid_1's auc: 0.55246
# [257]	training's auc: 0.805877	valid_1's auc: 0.552478
# [258]	training's auc: 0.80617	valid_1's auc: 0.552555
# [259]	training's auc: 0.806511	valid_1's auc: 0.552565
# [260]	training's auc: 0.806971	valid_1's auc: 0.552499
# [261]	training's auc: 0.807354	valid_1's auc: 0.552703
# [262]	training's auc: 0.807533	valid_1's auc: 0.552583
# [263]	training's auc: 0.807814	valid_1's auc: 0.552743
# [264]	training's auc: 0.807938	valid_1's auc: 0.552829
# [265]	training's auc: 0.808323	valid_1's auc: 0.552808
# [266]	training's auc: 0.808384	valid_1's auc: 0.552883
# [267]	training's auc: 0.808596	valid_1's auc: 0.55289
# [268]	training's auc: 0.808559	valid_1's auc: 0.553022
# [269]	training's auc: 0.808856	valid_1's auc: 0.553325
# [270]	training's auc: 0.808842	valid_1's auc: 0.553297
# [271]	training's auc: 0.809085	valid_1's auc: 0.553507
# [272]	training's auc: 0.809457	valid_1's auc: 0.553558
# [273]	training's auc: 0.809579	valid_1's auc: 0.5537
# [274]	training's auc: 0.809876	valid_1's auc: 0.553996
# [275]	training's auc: 0.810504	valid_1's auc: 0.554174
# [276]	training's auc: 0.810525	valid_1's auc: 0.554172
# [277]	training's auc: 0.810928	valid_1's auc: 0.554282
# [278]	training's auc: 0.811309	valid_1's auc: 0.554368
# [279]	training's auc: 0.811488	valid_1's auc: 0.554524
# [280]	training's auc: 0.811668	valid_1's auc: 0.554358
# [281]	training's auc: 0.812189	valid_1's auc: 0.554607
# [282]	training's auc: 0.812647	valid_1's auc: 0.554553
# [283]	training's auc: 0.813097	valid_1's auc: 0.554494
# [284]	training's auc: 0.81356	valid_1's auc: 0.554763
# [285]	training's auc: 0.814035	valid_1's auc: 0.554573
# [286]	training's auc: 0.814487	valid_1's auc: 0.554664
# [287]	training's auc: 0.814698	valid_1's auc: 0.554903
# [288]	training's auc: 0.815181	valid_1's auc: 0.555006
# [289]	training's auc: 0.815613	valid_1's auc: 0.555182
# [290]	training's auc: 0.815726	valid_1's auc: 0.555105
# [291]	training's auc: 0.816009	valid_1's auc: 0.555125
# [292]	training's auc: 0.816329	valid_1's auc: 0.555111
# [293]	training's auc: 0.81679	valid_1's auc: 0.555222
# [294]	training's auc: 0.817004	valid_1's auc: 0.555145
# [295]	training's auc: 0.817295	valid_1's auc: 0.55509
# [296]	training's auc: 0.817282	valid_1's auc: 0.555134
# [297]	training's auc: 0.817752	valid_1's auc: 0.555162
# [298]	training's auc: 0.818154	valid_1's auc: 0.555211
# [299]	training's auc: 0.818456	valid_1's auc: 0.55535
# [300]	training's auc: 0.818687	valid_1's auc: 0.55544
# [301]	training's auc: 0.8188	valid_1's auc: 0.555661
# [302]	training's auc: 0.818836	valid_1's auc: 0.555779
# [303]	training's auc: 0.819022	valid_1's auc: 0.555776
# [304]	training's auc: 0.819163	valid_1's auc: 0.555753
# [305]	training's auc: 0.81915	valid_1's auc: 0.555721
# [306]	training's auc: 0.819162	valid_1's auc: 0.555639
# [307]	training's auc: 0.819508	valid_1's auc: 0.555466
# [308]	training's auc: 0.819593	valid_1's auc: 0.555524
# [309]	training's auc: 0.819634	valid_1's auc: 0.555765
# [310]	training's auc: 0.819659	valid_1's auc: 0.555753
# [311]	training's auc: 0.819725	valid_1's auc: 0.555659
# [312]	training's auc: 0.819752	valid_1's auc: 0.555583
# [313]	training's auc: 0.819847	valid_1's auc: 0.55561
# [314]	training's auc: 0.819786	valid_1's auc: 0.555753
# [315]	training's auc: 0.819867	valid_1's auc: 0.55566
# [316]	training's auc: 0.819886	valid_1's auc: 0.555655
# [317]	training's auc: 0.81988	valid_1's auc: 0.555728
# [318]	training's auc: 0.819807	valid_1's auc: 0.555864
# [319]	training's auc: 0.8198	valid_1's auc: 0.555718
# [320]	training's auc: 0.819839	valid_1's auc: 0.555871
# [321]	training's auc: 0.819804	valid_1's auc: 0.55616
# [322]	training's auc: 0.819834	valid_1's auc: 0.556373
# [323]	training's auc: 0.819966	valid_1's auc: 0.55657
# [324]	training's auc: 0.820045	valid_1's auc: 0.556749
# [325]	training's auc: 0.820106	valid_1's auc: 0.556918
# [326]	training's auc: 0.820105	valid_1's auc: 0.556928
# [327]	training's auc: 0.820188	valid_1's auc: 0.557228
# [328]	training's auc: 0.820117	valid_1's auc: 0.557379
# [329]	training's auc: 0.820203	valid_1's auc: 0.557356
# [330]	training's auc: 0.820134	valid_1's auc: 0.557588
# [331]	training's auc: 0.820057	valid_1's auc: 0.55777
# [332]	training's auc: 0.820078	valid_1's auc: 0.557978
# [333]	training's auc: 0.820043	valid_1's auc: 0.557934
# [334]	training's auc: 0.82015	valid_1's auc: 0.557979
# [335]	training's auc: 0.820135	valid_1's auc: 0.558098
# [336]	training's auc: 0.820172	valid_1's auc: 0.557988
# [337]	training's auc: 0.820089	valid_1's auc: 0.5581
# [338]	training's auc: 0.820026	valid_1's auc: 0.558319
# [339]	training's auc: 0.819942	valid_1's auc: 0.558306
# [340]	training's auc: 0.819904	valid_1's auc: 0.558249
# [341]	training's auc: 0.820096	valid_1's auc: 0.558325
# [342]	training's auc: 0.820166	valid_1's auc: 0.55826
# [343]	training's auc: 0.820258	valid_1's auc: 0.558218
# [344]	training's auc: 0.820422	valid_1's auc: 0.558222
# [345]	training's auc: 0.820561	valid_1's auc: 0.558273
# [346]	training's auc: 0.820657	valid_1's auc: 0.558179
# [347]	training's auc: 0.820711	valid_1's auc: 0.55821
# [348]	training's auc: 0.820755	valid_1's auc: 0.558254
# [349]	training's auc: 0.820824	valid_1's auc: 0.558328
# [350]	training's auc: 0.82101	valid_1's auc: 0.558367
# [351]	training's auc: 0.821141	valid_1's auc: 0.558446
# [352]	training's auc: 0.821194	valid_1's auc: 0.55847
# [353]	training's auc: 0.821284	valid_1's auc: 0.558463
# [354]	training's auc: 0.82141	valid_1's auc: 0.558516
# [355]	training's auc: 0.821528	valid_1's auc: 0.558304
# [356]	training's auc: 0.821533	valid_1's auc: 0.558253
# [357]	training's auc: 0.821696	valid_1's auc: 0.558269
# [358]	training's auc: 0.821745	valid_1's auc: 0.558337
# [359]	training's auc: 0.82182	valid_1's auc: 0.558281
# [360]	training's auc: 0.821914	valid_1's auc: 0.558325
# [361]	training's auc: 0.822232	valid_1's auc: 0.558281
# [362]	training's auc: 0.822545	valid_1's auc: 0.558288
# [363]	training's auc: 0.822785	valid_1's auc: 0.558055
# [364]	training's auc: 0.823256	valid_1's auc: 0.557951
# [365]	training's auc: 0.823401	valid_1's auc: 0.557886
# [366]	training's auc: 0.82353	valid_1's auc: 0.557766
# [367]	training's auc: 0.823639	valid_1's auc: 0.557493
# [368]	training's auc: 0.823976	valid_1's auc: 0.55755
# [369]	training's auc: 0.824129	valid_1's auc: 0.557494
# [370]	training's auc: 0.824415	valid_1's auc: 0.557341
# [371]	training's auc: 0.824537	valid_1's auc: 0.557304
# [372]	training's auc: 0.824711	valid_1's auc: 0.557379
# [373]	training's auc: 0.824895	valid_1's auc: 0.55728
# [374]	training's auc: 0.825173	valid_1's auc: 0.55723
# [375]	training's auc: 0.825368	valid_1's auc: 0.557158
# [376]	training's auc: 0.82547	valid_1's auc: 0.556949
# [377]	training's auc: 0.825688	valid_1's auc: 0.556742
# [378]	training's auc: 0.825803	valid_1's auc: 0.556562
# [379]	training's auc: 0.826001	valid_1's auc: 0.556465
# [380]	training's auc: 0.826095	valid_1's auc: 0.556237
# [381]	training's auc: 0.826696	valid_1's auc: 0.556145
# [382]	training's auc: 0.826957	valid_1's auc: 0.556069
# [383]	training's auc: 0.827307	valid_1's auc: 0.556099
# [384]	training's auc: 0.827893	valid_1's auc: 0.555881
# [385]	training's auc: 0.828429	valid_1's auc: 0.556006
# [386]	training's auc: 0.828732	valid_1's auc: 0.556104
# [387]	training's auc: 0.829004	valid_1's auc: 0.556237
# [388]	training's auc: 0.829461	valid_1's auc: 0.555924
# [389]	training's auc: 0.83	valid_1's auc: 0.555801
# [390]	training's auc: 0.830451	valid_1's auc: 0.555725
# [391]	training's auc: 0.830899	valid_1's auc: 0.555899
# [392]	training's auc: 0.831266	valid_1's auc: 0.555817
# [393]	training's auc: 0.831622	valid_1's auc: 0.555864
# [394]	training's auc: 0.83202	valid_1's auc: 0.555668
# [395]	training's auc: 0.832349	valid_1's auc: 0.555687
# [396]	training's auc: 0.832757	valid_1's auc: 0.55556
# [397]	training's auc: 0.833169	valid_1's auc: 0.555473
# [398]	training's auc: 0.83353	valid_1's auc: 0.555774
# [399]	training's auc: 0.833788	valid_1's auc: 0.556014
# [400]	training's auc: 0.834102	valid_1's auc: 0.55594
# [401]	training's auc: 0.834292	valid_1's auc: 0.556135
# [402]	training's auc: 0.834401	valid_1's auc: 0.556117
# [403]	training's auc: 0.834499	valid_1's auc: 0.556188
# [404]	training's auc: 0.834657	valid_1's auc: 0.55614
# [405]	training's auc: 0.834944	valid_1's auc: 0.556168
# [406]	training's auc: 0.835112	valid_1's auc: 0.556052
# [407]	training's auc: 0.835284	valid_1's auc: 0.556093
# [408]	training's auc: 0.835379	valid_1's auc: 0.556068
# [409]	training's auc: 0.835477	valid_1's auc: 0.556079
# [410]	training's auc: 0.835655	valid_1's auc: 0.55615
# [411]	training's auc: 0.835686	valid_1's auc: 0.556332
# [412]	training's auc: 0.83584	valid_1's auc: 0.556481
# [413]	training's auc: 0.835958	valid_1's auc: 0.556482
# [414]	training's auc: 0.835959	valid_1's auc: 0.55648
# [415]	training's auc: 0.836091	valid_1's auc: 0.556621
# [416]	training's auc: 0.836104	valid_1's auc: 0.55679
# [417]	training's auc: 0.83616	valid_1's auc: 0.556916
# [418]	training's auc: 0.83642	valid_1's auc: 0.556845
# [419]	training's auc: 0.836512	valid_1's auc: 0.556794
# [420]	training's auc: 0.836613	valid_1's auc: 0.55692
# [421]	training's auc: 0.836761	valid_1's auc: 0.556973
# [422]	training's auc: 0.836941	valid_1's auc: 0.557046
# [423]	training's auc: 0.837077	valid_1's auc: 0.55728
# [424]	training's auc: 0.837209	valid_1's auc: 0.55728
# [425]	training's auc: 0.837375	valid_1's auc: 0.55752
# [426]	training's auc: 0.837456	valid_1's auc: 0.557296
# [427]	training's auc: 0.83748	valid_1's auc: 0.55719
# [428]	training's auc: 0.837534	valid_1's auc: 0.557137
# [429]	training's auc: 0.8375	valid_1's auc: 0.557383
# [430]	training's auc: 0.837573	valid_1's auc: 0.557286
# [431]	training's auc: 0.837579	valid_1's auc: 0.557392
# [432]	training's auc: 0.837583	valid_1's auc: 0.557365
# [433]	training's auc: 0.837721	valid_1's auc: 0.557387
# [434]	training's auc: 0.837834	valid_1's auc: 0.557309
# [435]	training's auc: 0.837838	valid_1's auc: 0.557164
# [436]	training's auc: 0.837853	valid_1's auc: 0.557172
# [437]	training's auc: 0.837879	valid_1's auc: 0.556968
# [438]	training's auc: 0.837957	valid_1's auc: 0.557088
# [439]	training's auc: 0.83792	valid_1's auc: 0.557363
# [440]	training's auc: 0.837856	valid_1's auc: 0.557121
# [441]	training's auc: 0.838271	valid_1's auc: 0.55716
# [442]	training's auc: 0.838521	valid_1's auc: 0.557125
# [443]	training's auc: 0.83875	valid_1's auc: 0.556983
# [444]	training's auc: 0.839111	valid_1's auc: 0.556766
# [445]	training's auc: 0.839283	valid_1's auc: 0.556586
# [446]	training's auc: 0.839522	valid_1's auc: 0.556704
# [447]	training's auc: 0.839694	valid_1's auc: 0.556656
# [448]	training's auc: 0.839891	valid_1's auc: 0.55689
# [449]	training's auc: 0.840075	valid_1's auc: 0.556873
# [450]	training's auc: 0.840169	valid_1's auc: 0.556953
# [451]	training's auc: 0.840374	valid_1's auc: 0.55657
# [452]	training's auc: 0.840502	valid_1's auc: 0.556505
# [453]	training's auc: 0.840644	valid_1's auc: 0.556546
# [454]	training's auc: 0.840785	valid_1's auc: 0.556629
# Early stopping, best iteration is:
# [354]	training's auc: 0.82141	valid_1's auc: 0.558516

# %%
features_test = test_data.drop(['label'], axis=1)
y_predict = model.predict(features_test)

plan_create['prob'] = y_predict
threshold = pd.Series(y_predict).sort_values(ascending=False).reset_index(drop=True)[int(y_predict.shape[0] * 0.3)]

plan_result = plan_create[plan_create['prob'] >= threshold]
plan_result['rank_ad_im'] = plan_result.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False, method='first')
plan_result = plan_result[plan_result['rank_ad_im'] <= 1]

plan_create['rank_ad_im'] = plan_create.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False, method='first')
plan_result_pr = plan_create[plan_create['rank_ad_im'] <= 1]
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ad_num = plan_result['ad_account_id'].value_counts()
for ad in np.setdiff1d(plan_create['ad_account_id'].values, ad_num[ad_num > 2].index):
    add_plan = plan_result_pr[plan_result_pr['ad_account_id'] == ad].sort_values('prob', ascending=False)[0:2]
    plan_result = plan_result.append(add_plan)

# %%
plan_result

# %%
# if plan_result.shape[0] > 12:
#     plan_result = plan_result.sample(12)

plan_result = plan_result.drop(['create_time', 'create_date', 'prob', 'rank_ad_im', 'label_ids'], axis=1)
plan_result['convertIndex'] = plan_result['deep_bid_type'].apply(lambda x: 13 if x == 'BID_PER_ACTION' else 14)

plan_result['budget'] = plan_result.apply(lambda x: x.budget if x.budget >= x.cpa_bid else x.cpa_bid, axis=1)
plan_result['budget'] = plan_result['budget'].apply(np.ceil)
plan_result['operation'] = 'disable'
plan_result['web_url'] = 'https://www.chengzijianzhan.com/tetris/page/6960565870964621319/'

plan_result.to_csv('./plan_result.csv', index=0)  # 保存创建日志

# rsp_data = get_ad_create(plan_result)
# print(rsp_data)

# %%
plan_result.shape
# Out:
# (35, 39)

# %%
plan_create.shape
# Out:
# (550, 41)

# %%
plan_result.head()
# Out:
#    game_id  image_id   platform android_osv ios_osv  budget  \
# 0  1001545     32633  [ANDROID]         7.0    NONE  3300.0
# 3  1001545     31845  [ANDROID]         8.0    NONE  3300.0
# 4  1001545     32171  [ANDROID]         8.0    NONE  3300.0
# 5  1001545     32997  [ANDROID]         7.0    NONE  3300.0
# 6  1001545     33115  [ANDROID]         7.0    NONE  3300.0
#
#       retargeting_type retargeting_tags_include retargeting_tags_exclude  \
# 0  RETARGETING_EXCLUDE                       []   [320989434, 321082199]
# 3                 NONE                       []                       []
# 4                 NONE                       []                       []
# 5                 NONE                       []                       []
# 6                 NONE                       []                       []
#
#   interest_action_mode action_scene  action_days action_categories  \
# 0            RECOMMEND          NaN          NaN               NaN
# 3            RECOMMEND          NaN          NaN               NaN
# 4            RECOMMEND          NaN          NaN               NaN
# 5               CUSTOM        [APP]          7.0              [16]
# 6            RECOMMEND          NaN          NaN               NaN
#
#   interest_categories   deep_bid_type  roi_goal    smart_bid_type  adjust_cpa  \
# 0                  []  BID_PER_ACTION       NaN  SMART_BID_CUSTOM         0.0
# 3                  []  BID_PER_ACTION       NaN  SMART_BID_CUSTOM         0.0
# 4                  []  BID_PER_ACTION       NaN  SMART_BID_CUSTOM         0.0
# 5                [16]  BID_PER_ACTION       NaN  SMART_BID_CUSTOM         0.0
# 6                  []  BID_PER_ACTION       NaN  SMART_BID_CUSTOM         0.0
#
#    cpa_bid delivery_range                                               city  \
# 0   614.97        DEFAULT  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...
# 3   604.87        DEFAULT  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...
# 4   523.06        DEFAULT  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...
# 5   513.97        DEFAULT  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...
# 6   594.87        DEFAULT  [64, 421000, 11, 12, 13, 14, 15, 422800, 42050...
#
#   location_type       gender  \
# 0          HOME  GENDER_MALE
# 3          HOME  GENDER_MALE
# 4       CURRENT  GENDER_MALE
# 5          HOME         NONE
# 6          HOME  GENDER_MALE
#
#                                                  age          ac launch_price  \
# 0  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...  [WIFI, 4G]   [0, 11000]
# 3  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...  [WIFI, 4G]   [0, 11000]
# 4  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...  [WIFI, 4G]   [0, 11000]
# 5  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...  [WIFI, 4G]   [0, 11000]
# 6  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...  [WIFI, 4G]   [0, 11000]
#
#    auto_extend_enabled  hide_if_exists hide_if_converted  \
# 0                    0               0                AD
# 3                    0               0               APP
# 4                    0               0               APP
# 5                    0               0               APP
# 6                    0               0               APP
#
#                                        schedule_time       flow_control_mode  \
# 0  1111111111111111111111111111111111111111111000...  FLOW_CONTROL_MODE_FAST
# 3  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 4  1111111111111111111111111111111111111110000000...  FLOW_CONTROL_MODE_FAST
# 5  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 6  1111111111111111111111111111111111111111111100...  FLOW_CONTROL_MODE_FAST
#
#                            inventory_type  \
# 0                  [INVENTORY_AWEME_FEED]
# 3  [INVENTORY_AWEME_FEED, INVENTORY_FEED]
# 4  [INVENTORY_AWEME_FEED, INVENTORY_FEED]
# 5  [INVENTORY_AWEME_FEED, INVENTORY_FEED]
# 6                  [INVENTORY_AWEME_FEED]
#
#                                          ad_keywords  \
# 0  [手游, SLG, 策略, 战争策略, 策略手游, 最强王者, 我的使命, 红警, 帝国文明...
# 3  [游戏, 手游, 对战, 军事手游, 三国志, 三国志策略版, 万国觉醒, 传奇, 深蓝战舰...
# 4  [手游, 原神, ace, 全面战争, 军团, 帝国, 红色警戒, 烧脑, 世界, 时代, ...
# 5  [游戏, 手游, 帝国, 文明, SLG, 战争, 建造, 策略, 中世纪, COK, 帝国...
# 6                   [帝国, 战争, 策略, 手游, 全新手游, 正版授权, IP]
#
#                                           title_list third_industry_id  \
# 0  [{'title': '开局流落荒岛，填海造陆，挖矿伐木，白手起家，建立海岛王国！', 'c...          19131201
# 3  [{'title': '8090后已集体沦陷，帝国玩家苦等20年，终于等到这款良心策略手游'...          19131201
# 4  [{'title': '1:1还原经典端游，开局5个农民，3天建造帝国？', 'creati...          19131201
# 5  [{'title': '狩猎捕鱼，伐木挖矿，掠夺资源，升级主城，看农民如何制霸帝国！', '...          19131201
# 6  [{'title': '小时候玩的帝国终于出手游了！开局5个农民，建立你的帝国！', 'cr...          19131201
#
#    ad_account_id  convertIndex operation
# 0           6867            13   disable
# 3           6867            13   disable
# 4           6867            13   disable
# 5           6867            13   disable
# 6           6867            13   disable

# %%
plan_result['ad_account_id'].value_counts()
# Out:
# 6868    7
# 6867    7
# 6988    7
# 6987    7
# Name: ad_account_id, dtype: int64

# %%
sns.distplot(y_predict)
plt.show()
