# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import tensorflow as tf
from numpy import *
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from tensorflow.keras import layers,datasets
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from tensorflow import keras
import gc
# import warnings
# warnings.filterwarnings('ignore')
import lightgbm as lgb
import category_encoders as ce
from sklearn.metrics import f1_score,classification_report,roc_auc_score
from impala.dbapi import connect
from impala.util import as_pandas
import pymysql

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
def get_game_id():
    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1056 AND dev_game_id IS NOT NULL 
    '''
    cur.execute(sql)
    result_df = cur.fetchall()
    cur.close()
    conn.close()
    return result_df

# %%
# 获取近期所有计划('2021年4月23号开始')
def get_plan_info():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)
    conn = pymysql.connect(host='192.168.0.65', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t', db='db_ptom')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
    /*手动查询*/
        SELECT
                * 
            FROM
                db_ptom.ptom_third_plan p
            WHERE
                game_id IN ({})
                AND media_id = 10
                AND create_time>='2021-04-23'
                AND create_time<= date(NOW())
                            AND plan_id >= (
                                select plan_id from db_ptom.ptom_plan
                                where create_time >= '2021-04-23'
                                and create_time <= '2021-04-24'
                                limit 1
                            )
    '''
    finalSql = sql.format(game_id)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
# 获取image_id,label_ids
def get_image_info():
    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                        passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id,
            a.image_id,
            b.label_ids
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN
            db_data_ptom.ptom_image_info b
        on a.image_id = b.image_id
        WHERE
            a.game_id IN ( SELECT dev_game_id AS game_id FROM db_data.t_game_config WHERE game_id = 1056 AND dev_game_id IS NOT NULL ) 
            AND a.media_id = 10 
            AND a.create_time >= '2021-03-14' 
        GROUP BY
            a.chl_user_id,
            a.source_id,
            a.image_id
    '''
    cur.execute(sql)
    result_df = pd.read_sql(sql, conn)
    cur.close()
    conn.close()
    return result_df

# %%
def get_launch_report():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/
        SELECT
            a.chl_user_id AS channel_id,
            a.source_id AS source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount as roi,
            b.pay_role_user_num / b.create_role_num as pay_rate
        FROM
            db_data_ptom.ptom_plan a
            LEFT JOIN db_stdata.st_lauch_report b ON a.chl_user_id = b.channel_id 
            AND a.source_id = b.source_id 
        WHERE
            a.create_time >= '2021-04-23' 
            AND b.tdate >= '2021-04-23' 
            AND b.tdate_type = 'day' 
            AND b.media_id = 10
            AND b.game_id IN ({})
            AND b.amount >= 500
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')

    return result_df

# %%
# 解析json
def get_plan_json(plan_info):
    plan_info.drop(['inventory_type','budget'], axis=1, inplace=True)
    plan_info.dropna(how='all', inplace=True, axis=1)
    plan_info.dropna(subset=['ad_info'],inplace=True)
    # 解析json
    plan_info['ad_info'] = plan_info['ad_info'].apply(json.loads)
    temp = plan_info['ad_info'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('ad_info', axis=1, inplace=True)
    temp = plan_info['audience'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('audience', axis=1, inplace=True)
    temp = plan_info['action'].apply(pd.Series)
    plan_info = pd.concat([plan_info,temp], axis=1)
    plan_info.drop('action', axis=1, inplace=True)
    plan_info.dropna(how='all', inplace=True, axis=1)
    plan_info = plan_info[['ad_account_id', 'game_id', 'channel_id', 'source_id',
           'create_time', 'smart_bid_type', 'hide_if_exists', 'budget',
           'delivery_range', 'adjust_cpa', 'inventory_type', 'hide_if_converted',
           'flow_control_mode', 'schedule_time', 'cpa_bid', 'auto_extend_enabled',
           'gender', 'city', 'platform', 'launch_price',
           'retargeting_tags_exclude', 'interest_categories',
           'ac', 'android_osv', 'location_type', 'retargeting_tags_include',
           'retargeting_type', 'ios_osv', 'interest_action_mode', 'age',
           'action_categories', 'action_days', 'action_scene','deep_bid_type','roi_goal']]
    return plan_info

# %%
def get_all_data():
    # 读取历史数据
    plan_info = pd.read_csv('./hist_data/ptom_third_plan.csv')
    image_info = pd.read_csv('./hist_data/image_info.csv')
    launch_report = pd.read_csv('./hist_data/launch_report.csv')
    
    plan_info_new = get_plan_info()
    image_info_new = get_image_info()
    launch_report_new = get_launch_report()
    
    plan_info = plan_info.append(plan_info_new)
    plan_info = get_plan_json(plan_info)
    image_info = image_info.append(image_info_new)
    launch_report = launch_report.append(launch_report_new)
    image_info.dropna(subset=['image_id'],inplace=True)
    image_info['image_id'] = image_info['image_id'].astype(int)
    return plan_info,image_info,launch_report

# %%
plan_info,image_info,launch_report = get_all_data()

# %%
plan_info.shape
# Out:
# (102825, 35)

# %% [markdown]
# ### 构造新计划

# %%
# 获取score_image (分数大于550的image_id)
def get_score_image():
    conn = connect(host='192.168.0.89', port=10000, auth_mechanism='PLAIN', user='hadoop',
                    password='Ycjh8FxiaoMtShZRd3-97%3hCEL0CK4ns1w', database='default')
    cursor = conn.cursor()
    sql_engine = 'set hive.execution.engine=tez'
    sql = 'select image_id,label_ids from dws.dws_image_score_d where media_id=10 and score>=580 and dt=CURRENT_DATE group by image_id,label_ids'
    cursor.execute(sql_engine)
    cursor.execute(sql)
    result = as_pandas(cursor)
    result['label_ids'] = result['label_ids'].astype(str)
    result['label_ids'] = result['label_ids'].apply(lambda x: x.strip('-1;') if '-1' in x else x)
    result['label_ids'] = pd.to_numeric(result['label_ids'],errors='coerce')
#     result = result[result['label_ids'].isin([27])]
#     print(result)
    # 关闭链接
    cursor.close()
    conn.close()
    
    return result['image_id'].values

# %%
plan_info['create_time'] = pd.to_datetime(plan_info['create_time'])
plan_info_current = plan_info[plan_info['create_time']>=pd.datetime.now() - pd.DateOffset(8)]
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
# 获取近期计划的运营数据
def get_now_plan_roi():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.79', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        SELECT
            a.ad_account_id,
            b.channel_id,
            b.source_id,
            b.tdate,
            b.amount,
            b.new_role_money,
            b.new_role_money / b.amount AS roi,
            b.pay_role_user_num / b.create_role_num AS pay_rate 
        FROM
            db_data_ptom.ptom_plan a 
        left join
            db_stdata.st_lauch_report b
        on a.chl_user_id=b.channel_id and a.source_id=b.source_id
        WHERE
            b.tdate >= date( NOW() - INTERVAL 120 HOUR ) 
            AND b.tdate_type = 'day' 
            AND b.media_id = 10 
            AND b.game_id IN ({}) 
            AND b.amount >= 500 
            AND b.pay_role_user_num >= 2 
            AND b.new_role_money >= 90
            AND (b.new_role_money / b.amount)>=0.028
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result_df = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    result_df['tdate'] = pd.to_datetime(result_df['tdate'])
    result_df = result_df.sort_values('tdate')
    result_df = result_df.drop_duplicates(['channel_id', 'source_id'], keep='first')
#     result_df = result_df[result_df['roi'] >= 0.03]
    return result_df

# %%
# 获取近期优化计划的创意数据
def get_creative():
    game_id = get_game_id()
    game_id = list(map(lambda x: x['game_id'], game_id))
    game_id = [str(i) for i in game_id]
    game_id = ','.join(game_id)

    conn = pymysql.connect(host='192.168.0.65', port=3306, user='readonly',
                           passwd='Kc&r+z1ql9x8za4kzfk761weq8ozGv3ZpI;RMe,#+s%c>t')
    cur = conn.cursor(cursor=pymysql.cursors.DictCursor)
    sql = '''
        /*手动查询*/ 
        SELECT
            b.chl_user_id AS channel_id,
            b.source_id,
            JSON_EXTRACT( a.creative_param, '$.ad_keywords' ) AS ad_keywords,
            JSON_EXTRACT( a.creative_param, '$.title_list' ) AS title_list,
            JSON_EXTRACT( a.creative_param, '$.third_industry_id' ) AS third_industry_id 
        FROM
            db_ptom.ptom_batch_ad_task a
            LEFT JOIN db_ptom.ptom_plan b ON a.plan_name = b.plan_name 
        WHERE
            a.media_id = 10 
            AND b.create_time >= date( NOW() - INTERVAL 720 HOUR )    # 近30天
            AND a.game_id IN ({}) 
    '''
    finalSql = sql.format(game_id)
    cur.execute(finalSql)
    result = pd.read_sql(finalSql, conn)
    cur.close()
    conn.close()
    return result

# %%
creative_info = get_creative()
creative_info['title_list'] = creative_info['title_list'].fillna('[]')
creative_info['ad_keywords'] = creative_info['ad_keywords'].fillna('[]')
creative_info['title_list'] = creative_info['title_list'].apply(json.loads)
creative_info['ad_keywords'] = creative_info['ad_keywords'].apply(json.loads)

# %%
now_plan_roi = get_now_plan_roi()
now_plan_roi = pd.merge(now_plan_roi,creative_info,on=['channel_id','source_id'],how='left')

# %%
now_plan_roi.shape
# Out:
# (65, 11)

# %%
score_image = get_score_image()

# %%
score_image
# Out:
# array([27672, 31010, 32217, 33382, 33901, 34013, 34101, 34186, 34335,
#        34624, 34822, 34933, 35012, 35018, 35166, 35210, 35334, 35340,
#        35380, 35381, 35659, 35814, 35883, 35916, 36090, 36093, 36219,
#        36269, 36327, 36393, 36435, 36485], dtype=int64)

# %%
df_create = pd.merge(plan_info_current,image_info,on=['channel_id','source_id'],how='left')
df_create = pd.merge(df_create,now_plan_roi,on=['channel_id','source_id'],how='inner')
df_create['platform'] = df_create['platform'].astype(str)
df_create['platform'] = df_create['platform'].map({"['ANDROID']":1,"['IOS']":2})
df_create['platform'] = df_create['platform'].astype(int)

# %%
df_create.dropna(subset=['image_id'],inplace=True)
df_create['image_id'] = df_create['image_id'].astype(int)

# %%
df_create = df_create[df_create['platform']==1]

# %%
df_create.shape
# Out:
# (46, 46)

# %%
score_image
# Out:
# array([27672, 31010, 32217, 33382, 33901, 34013, 34101, 34186, 34335,
#        34624, 34822, 34933, 35012, 35018, 35166, 35210, 35334, 35340,
#        35380, 35381, 35659, 35814, 35883, 35916, 36090, 36093, 36219,
#        36269, 36327, 36393, 36435, 36485], dtype=int64)

# %%
df_create.shape
# Out:
# (46, 46)

# %%
def create_plan(df, score_image):
    # 选ad_account_id、image_id每个账号+素材8条
    game_id = 1001703
    # df = df[df['game_id'] == game_id]
    df = df[df['game_id'].isin([1001379, 1001703])]
    ad_account_id_group = np.array([7771, 7772, 7773, 7856])
    image_id_group = np.intersect1d(df['image_id'].unique(), score_image)
    image_id_group = list(filter(lambda x: x >= 32861, image_id_group))

    # print(image_id_group)
    df = df[df['deep_bid_type'].isin(['BID_PER_ACTION', 'ROI_COEFFICIENT'])]
    df = df[df['image_id'].isin(image_id_group)]
    print('df的大小', df.shape)
    plan = pd.DataFrame()
    for ad_account in ad_account_id_group:
        for image in image_id_group:
            #         print(image)
            temp = pd.DataFrame({'ad_account_id': [ad_account], 'image_id': [image]})
            plan = plan.append(temp)
    #         print(temp)
    plan = pd.DataFrame(np.repeat(plan.values, 10, axis=0), columns=plan.columns)

    # game_image = df[['game_id', 'image_id']].drop_duplicates()
    # plan = pd.merge(plan, game_image, on='image_id', how='left')
    plan['game_id'] = game_id

    # 选platform测试期默认[ANDROID]
    # plan['platform'] = df['platform'].iloc[0]
    plan['platform'] = 1
    plan['platform'] = plan['platform'].apply(lambda x: '[ANDROID]' if x == 1 else '[IOS]')

    # 选android_osv
    count_df = pd.DataFrame(data=df['android_osv'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['android_osv'] = plan['platform'].apply(lambda x: 'NONE' if x == '[IOS]' else
    np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0])

    # 选ios_osv
    count_df = pd.DataFrame(data=df['ios_osv'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['ios_osv'] = plan['platform'].apply(lambda x: 'NONE' if x == '[ANDROID]' else
    np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0])

    # 选budget
    plan['budget'] = plan['platform'].apply(lambda x: 3300 if x == '[ANDROID]' else 4000)

    # 选'ad_keywords', 'title_list', 'third_industry_id'  创意
    sample_df = df[['ad_keywords', 'title_list', 'third_industry_id']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'retargeting_type','retargeting_tags_include','retargeting_tags_exclude'  人群包定向
    sample_df = df[['retargeting_type', 'retargeting_tags_include', 'retargeting_tags_exclude']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'interest_action_mode','action_scene','action_days','action_categories' ,'interest_categories' 行为兴趣
    sample_df = df[['interest_action_mode', 'action_scene', 'action_days', 'action_categories', 'interest_categories']]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选'deep_bid_type','roi_goal','smart_bid_type','adjust_cpa','cpa_bid'出价方式
    sample_df = df[['deep_bid_type', 'roi_goal', 'smart_bid_type', 'adjust_cpa', 'cpa_bid']]
    sample_df = sample_df[sample_df['deep_bid_type'].isin(['ROI_COEFFICIENT', 'BID_PER_ACTION'])]
    sample_df = sample_df.sample(n=plan.shape[0], replace=True).reset_index(drop=True)
    plan = pd.concat([plan, sample_df], axis=1)

    # 选
    cols = ['delivery_range', 'city', 'location_type', 'gender', 'age', 'ac', 'launch_price',
            'auto_extend_enabled', 'hide_if_exists', 'hide_if_converted', 'schedule_time', 'flow_control_mode']
    for col in cols:
        count_df = pd.DataFrame(data=df[col].value_counts()).reset_index()
        count_df.columns = ['col', 'counts']
        count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
        plan[col] = plan.apply(lambda x: np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0],
                               axis=1)

    # 选inventory_type 创意投放位置
    count_df = pd.DataFrame(data=df['inventory_type'].value_counts()).reset_index()
    count_df.columns = ['col', 'counts']
    count_df['col'] = count_df['col'].apply(lambda x: list(filter(None, x)))
    # for i in range(count_df.shape[0]):
    #     values = count_df.loc[i, 'col']
    #
    #     for value in values:
    #         if value == None:
    #             values.remove(value)
    #     a = np.empty(1, dtype=object)
    #     a[0] = values
    #     count_df.loc[i, 'col'] = a
    count_df['pct'] = count_df['counts'] / count_df['counts'].sum()
    plan['inventory_type'] = plan.apply(
        lambda x: np.random.choice(count_df['col'].values, 1, p=count_df['pct'].values)[0], axis=1)
    plan['create_time'] = pd.to_datetime(pd.datetime.now())
    plan['create_date'] = pd.to_datetime(pd.datetime.now().date())

    return plan

# %%
plan_create = create_plan(df_create, score_image)
# Out:
# [32887, 33066, 33114, 33200, 33308, 33311, 33348, 33506, 33507, 33551, 33588, 33615, 33622, 33686, 33696, 33712, 33727, 33731, 33773, 33835]
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:93: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:94: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
plan_create.shape
# Out:
# (1400, 38)

# %%
image_info.dropna(subset=['image_id'],inplace=True)
image_info['image_id'] = image_info['image_id'].astype(int)
plan_create = pd.merge(plan_create,image_info[['image_id','label_ids']].drop_duplicates(),on='image_id',how='left')

# %%
df = pd.merge(plan_info,image_info,on=['channel_id','source_id'],how='left')
df.dropna(subset=['image_id'],inplace=True)
df = pd.merge(df, launch_report,on=['channel_id','source_id'],how='left')
df.drop(df[df['tdate'].isna()].index,inplace=True)
df = df[df['amount']>=500]

df['platform'] = df['platform'].astype(str)
df['platform'] = df['platform'].map({"['ANDROID']":1,"['IOS']":2})
df['label'] = df.apply(lambda x: 1 if x.new_role_money/x.amount>=0.02 else 0,axis=1)
df['ad_account_id'] = df['ad_account_id'].astype('int')
df['image_id'] = df['image_id'].astype('int')
df.rename(columns={'tdate':'create_date'},inplace=True)
df['create_date'] = pd.to_datetime(df['create_date'])
df['create_time'] = pd.to_datetime(df['create_time'])

# %%
df.head()
# Out:
#    ad_account_id  game_id  channel_id  source_id         create_time  \
# 0           4003  1000840        7162     259913 2020-01-19 16:18:31
# 3           4003  1000840        7162     259916 2020-01-20 14:35:23
# 4           4003  1000840        7162     259918 2020-01-29 18:01:59
# 5           4003  1000840        7162     259917 2020-01-29 18:02:00
# 6           4003  1000840        7162     259919 2020-01-30 14:32:38
#
#            smart_bid_type  hide_if_exists   budget delivery_range  adjust_cpa  \
# 0  SMART_BID_CONSERVATIVE               0   5000.0          UNION         0.0
# 3  SMART_BID_CONSERVATIVE               0   8000.0          UNION         0.0
# 4  SMART_BID_CONSERVATIVE               0  10000.0        DEFAULT         0.0
# 5  SMART_BID_CONSERVATIVE               0  10000.0        DEFAULT         0.0
# 6  SMART_BID_CONSERVATIVE               0  10000.0        DEFAULT         0.0
#
#                                       inventory_type hide_if_converted  \
# 0                             [INVENTORY_UNION_SLOT]                AD
# 3                             [INVENTORY_UNION_SLOT]                AD
# 4  [INVENTORY_FEED, INVENTORY_HOTSOON_FEED, INVEN...                AD
# 5  [INVENTORY_FEED, INVENTORY_HOTSOON_FEED, INVEN...                AD
# 6  [INVENTORY_FEED, INVENTORY_HOTSOON_FEED, INVEN...                AD
#
#         flow_control_mode                                      schedule_time  \
# 0  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 3  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
# 4  FLOW_CONTROL_MODE_FAST  1110000000000000000011111111111111111111111111...
# 5  FLOW_CONTROL_MODE_FAST  1110000000000000000000000000000000000111111111...
# 6  FLOW_CONTROL_MODE_FAST  1111111111111111111111111111111111111111111111...
#
#    cpa_bid  auto_extend_enabled       gender  \
# 0  1135.73                    0  GENDER_MALE
# 3  1180.24                    0  GENDER_MALE
# 4  1377.89                    0  GENDER_MALE
# 5  1431.96                    0  GENDER_MALE
# 6  1484.64                    0  GENDER_MALE
#
#                                                 city  platform launch_price  \
# 0                                                 []         1           []
# 3                                                 []         1           []
# 4  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...         1           []
# 5  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...         1           []
# 6  [11, 12, 13, 14, 15, 21, 22, 23, 31, 32, 33, 3...         1           []
#
#   retargeting_tags_exclude interest_categories  ac android_osv location_type  \
# 0                       []                  []  []        NONE       CURRENT
# 3                       []                  []  []        NONE       CURRENT
# 4                       []                  []  []        NONE       CURRENT
# 5                       []                  []  []        NONE       CURRENT
# 6                       []                  []  []        NONE       CURRENT
#
#   retargeting_tags_include retargeting_type ios_osv interest_action_mode  \
# 0                       []             NONE    NONE            UNLIMITED
# 3                       []             NONE    NONE            UNLIMITED
# 4                       []             NONE    NONE            UNLIMITED
# 5                       []             NONE    NONE            UNLIMITED
# 6                       []             NONE    NONE            UNLIMITED
#
#                                                  age action_categories  \
# 0  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...               NaN
# 3  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...               NaN
# 4  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...               NaN
# 5  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...               NaN
# 6  [AGE_BETWEEN_24_30, AGE_BETWEEN_31_40, AGE_BET...               NaN
#
#    action_days action_scene deep_bid_type  roi_goal  image_id label_ids  \
# 0          NaN          NaN           NaN       NaN     19788       NaN
# 3          NaN          NaN           NaN       NaN     19791       NaN
# 4          NaN          NaN           NaN       NaN     19636        19
# 5          NaN          NaN           NaN       NaN     19854       NaN
# 6          NaN          NaN           NaN       NaN     19636        19
#
#   create_date   amount  new_role_money       roi  pay_rate  label
# 0  2020-01-21   803.21             0.0  0.000000    0.0000      0
# 3  2020-01-20  1599.31             0.0  0.000000    0.0000      0
# 4  2020-01-29  6997.97           268.0  0.038297    0.0133      1
# 5  2020-01-29  3950.75             0.0  0.000000    0.0000      0
# 6  2020-01-30  6354.46           132.0  0.020773    0.0231      1

# %%
df.drop(['budget','cpa_bid','channel_id','source_id','amount','roi','pay_rate',
         'new_role_money'],axis=1,inplace=True)

# %%
plan_create_train = plan_create.drop(['budget', 'cpa_bid','ad_keywords','title_list','third_industry_id'],axis=1)
plan_create_train['platform'] = plan_create_train['platform'].map({'[ANDROID]':1,'[IOS]':2})
df['train_label'] = 1
plan_create_train['train_label'] = 0
plan_create_train['label'] = -1

# %%
df.shape
# Out:
# (42740, 36)

# %%
plan_create_train.shape
# Out:
# (1400, 36)

# %%
df = df.append(plan_create_train)

# %%
df['create_date'] = pd.to_datetime(df['create_date'])
df['ad_im_sort_id'] = df.groupby(['ad_account_id','image_id'])['create_time'].rank()
df['ad_game_sort_id'] = df.groupby(['ad_account_id','game_id'])['create_time'].rank()
df['im_ad_sort_id'] = df.groupby(['image_id','ad_account_id'])['create_time'].rank()

# %%
# 对列表内容进行编码降维
def get_mutil_feature(data):
    cols = ['inventory_type','age','city','retargeting_tags_include','retargeting_tags_exclude','ac','interest_categories',
       'action_scene','action_categories']
    for col in cols:
        if col in ['inventory_type','age']:
            data[col] = data[col].apply(lambda x:x if x==x else [])
            data = data.join(data[col].str.join('|').str.get_dummies().add_prefix(col+'_').reset_index(drop=True))
            data.drop(col,axis=1,inplace=True)

        else:
            data[col] = data[col].apply(lambda x:x if x==x else [])
            data[col]=data[col].apply(lambda x:[str(i) for i in x])
            data[col] = data[col].astype(str)
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
    
    gc.collect()
    return data

# %%
df = get_mutil_feature(df)

# %%
cat_cols = ['ad_account_id','game_id','schedule_time','delivery_range','flow_control_mode',
            'smart_bid_type','hide_if_converted','gender','location_type','launch_price','retargeting_type',
            'android_osv','ios_osv','interest_action_mode','action_days','image_id','label_ids','deep_bid_type']
from itertools import combinations
from tqdm import tqdm_notebook
cat_cross=[]
for col in tqdm_notebook(combinations(cat_cols,2)):
    df[str(col[0]) + '_'+str(col[1])] = df[col[0]].map(str)+'_'+df[col[1]].map(str)
    cat_cross.append(str(col[0]) + '_'+str(col[1]))

for col in cat_cols+cat_cross:
    df[col] = df[col].astype(str)
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
train_data = df[df['train_label']==1]
test_data = df[df['train_label']==0]
train_data.drop(['train_label','create_time','create_date'],axis=1,inplace=True)
test_data.drop(['train_label','create_time','create_date'],axis=1,inplace=True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# train_data, test_data = train_test_split(df, test_size=0.25)
target = train_data['label']
features = train_data.drop(['label'], axis=1)
X_val, x_test, Y_val, y_test = train_test_split(features,target, test_size=0.3)

# %%
params = {
"objective": "binary",
"boosting_type": "gbdt",
"learning_rate": 0.01,
"max_depth":8,
"num_leaves":55,
"max_bin":255,
"min_data_in_leaf":101,
"min_child_samples":15,
"feature_fraction": 0.5,
"bagging_fraction":0.6,
"bagging_freq":20,
"lambda_l1":1e-05,
"lambda_l2":0,
"min_split_gain": 0.0,
"metric": "auc",
'is_unbalance':True    
}

train_data = lgb.Dataset(X_val, label=Y_val)
val_data = lgb.Dataset(x_test, label=y_test, reference=train_data)
model = lgb.train(params, train_data, num_boost_round=8000, early_stopping_rounds=100, valid_sets=[train_data, val_data])
# Out:
# [1]	training's auc: 0.613995	valid_1's auc: 0.582916
# Training until validation scores don't improve for 100 rounds
# [2]	training's auc: 0.627921	valid_1's auc: 0.590816
# [3]	training's auc: 0.637973	valid_1's auc: 0.594354
# [4]	training's auc: 0.645213	valid_1's auc: 0.594419
# [5]	training's auc: 0.649392	valid_1's auc: 0.596954
# [6]	training's auc: 0.65379	valid_1's auc: 0.598287
# [7]	training's auc: 0.655186	valid_1's auc: 0.597672
# [8]	training's auc: 0.657548	valid_1's auc: 0.598758
# [9]	training's auc: 0.659807	valid_1's auc: 0.600518
# [10]	training's auc: 0.660573	valid_1's auc: 0.599141
# [11]	training's auc: 0.664445	valid_1's auc: 0.600179
# [12]	training's auc: 0.665406	valid_1's auc: 0.600466
# [13]	training's auc: 0.667495	valid_1's auc: 0.600853
# [14]	training's auc: 0.670625	valid_1's auc: 0.601037
# [15]	training's auc: 0.671802	valid_1's auc: 0.60095
# [16]	training's auc: 0.67219	valid_1's auc: 0.600504
# [17]	training's auc: 0.672101	valid_1's auc: 0.600636
# [18]	training's auc: 0.673473	valid_1's auc: 0.600951
# [19]	training's auc: 0.67536	valid_1's auc: 0.600665
# [20]	training's auc: 0.67611	valid_1's auc: 0.60068
# [21]	training's auc: 0.678176	valid_1's auc: 0.600835
# [22]	training's auc: 0.680883	valid_1's auc: 0.601676
# [23]	training's auc: 0.682828	valid_1's auc: 0.601518
# [24]	training's auc: 0.68391	valid_1's auc: 0.601386
# [25]	training's auc: 0.68498	valid_1's auc: 0.601714
# [26]	training's auc: 0.686538	valid_1's auc: 0.602355
# [27]	training's auc: 0.688555	valid_1's auc: 0.601804
# [28]	training's auc: 0.690404	valid_1's auc: 0.60187
# [29]	training's auc: 0.692128	valid_1's auc: 0.602516
# [30]	training's auc: 0.693142	valid_1's auc: 0.602223
# [31]	training's auc: 0.694637	valid_1's auc: 0.601855
# [32]	training's auc: 0.695654	valid_1's auc: 0.601693
# [33]	training's auc: 0.696155	valid_1's auc: 0.601314
# [34]	training's auc: 0.697447	valid_1's auc: 0.600983
# [35]	training's auc: 0.69863	valid_1's auc: 0.600436
# [36]	training's auc: 0.699268	valid_1's auc: 0.600139
# [37]	training's auc: 0.700002	valid_1's auc: 0.599872
# [38]	training's auc: 0.701242	valid_1's auc: 0.599852
# [39]	training's auc: 0.701785	valid_1's auc: 0.600067
# [40]	training's auc: 0.702194	valid_1's auc: 0.599635
# [41]	training's auc: 0.703489	valid_1's auc: 0.600542
# [42]	training's auc: 0.705077	valid_1's auc: 0.600762
# [43]	training's auc: 0.706008	valid_1's auc: 0.600805
# [44]	training's auc: 0.707485	valid_1's auc: 0.600923
# [45]	training's auc: 0.707948	valid_1's auc: 0.601084
# [46]	training's auc: 0.708077	valid_1's auc: 0.601238
# [47]	training's auc: 0.709352	valid_1's auc: 0.601176
# [48]	training's auc: 0.709733	valid_1's auc: 0.601371
# [49]	training's auc: 0.710542	valid_1's auc: 0.601631
# [50]	training's auc: 0.711102	valid_1's auc: 0.601875
# [51]	training's auc: 0.711618	valid_1's auc: 0.602064
# [52]	training's auc: 0.712104	valid_1's auc: 0.602522
# [53]	training's auc: 0.712241	valid_1's auc: 0.602369
# [54]	training's auc: 0.712768	valid_1's auc: 0.602615
# [55]	training's auc: 0.713195	valid_1's auc: 0.602393
# [56]	training's auc: 0.714036	valid_1's auc: 0.602624
# [57]	training's auc: 0.714789	valid_1's auc: 0.602546
# [58]	training's auc: 0.71542	valid_1's auc: 0.602335
# [59]	training's auc: 0.715622	valid_1's auc: 0.602154
# [60]	training's auc: 0.715886	valid_1's auc: 0.602031
# [61]	training's auc: 0.716557	valid_1's auc: 0.602149
# [62]	training's auc: 0.717164	valid_1's auc: 0.602065
# [63]	training's auc: 0.717529	valid_1's auc: 0.602216
# [64]	training's auc: 0.718293	valid_1's auc: 0.602441
# [65]	training's auc: 0.718757	valid_1's auc: 0.602207
# [66]	training's auc: 0.719241	valid_1's auc: 0.602556
# [67]	training's auc: 0.719613	valid_1's auc: 0.602379
# [68]	training's auc: 0.720397	valid_1's auc: 0.602527
# [69]	training's auc: 0.720928	valid_1's auc: 0.602678
# [70]	training's auc: 0.72133	valid_1's auc: 0.602859
# [71]	training's auc: 0.72152	valid_1's auc: 0.602645
# [72]	training's auc: 0.72195	valid_1's auc: 0.602761
# [73]	training's auc: 0.722132	valid_1's auc: 0.602599
# [74]	training's auc: 0.722746	valid_1's auc: 0.602394
# [75]	training's auc: 0.723217	valid_1's auc: 0.602252
# [76]	training's auc: 0.72367	valid_1's auc: 0.602134
# [77]	training's auc: 0.723988	valid_1's auc: 0.602249
# [78]	training's auc: 0.724166	valid_1's auc: 0.602192
# [79]	training's auc: 0.724624	valid_1's auc: 0.601886
# [80]	training's auc: 0.724733	valid_1's auc: 0.602022
# [81]	training's auc: 0.725499	valid_1's auc: 0.602023
# [82]	training's auc: 0.726309	valid_1's auc: 0.602316
# [83]	training's auc: 0.726955	valid_1's auc: 0.602584
# [84]	training's auc: 0.727585	valid_1's auc: 0.602538
# [85]	training's auc: 0.728488	valid_1's auc: 0.602873
# [86]	training's auc: 0.729131	valid_1's auc: 0.602791
# [87]	training's auc: 0.729721	valid_1's auc: 0.60265
# [88]	training's auc: 0.73011	valid_1's auc: 0.602659
# [89]	training's auc: 0.730794	valid_1's auc: 0.602841
# [90]	training's auc: 0.731097	valid_1's auc: 0.602822
# [91]	training's auc: 0.731745	valid_1's auc: 0.602987
# [92]	training's auc: 0.732314	valid_1's auc: 0.602828
# [93]	training's auc: 0.732796	valid_1's auc: 0.602956
# [94]	training's auc: 0.733013	valid_1's auc: 0.603072
# [95]	training's auc: 0.733238	valid_1's auc: 0.603247
# [96]	training's auc: 0.733846	valid_1's auc: 0.603253
# [97]	training's auc: 0.734379	valid_1's auc: 0.603367
# [98]	training's auc: 0.734661	valid_1's auc: 0.603474
# [99]	training's auc: 0.734762	valid_1's auc: 0.603592
# [100]	training's auc: 0.73479	valid_1's auc: 0.60367
# [101]	training's auc: 0.734966	valid_1's auc: 0.603711
# [102]	training's auc: 0.735014	valid_1's auc: 0.603565
# [103]	training's auc: 0.735124	valid_1's auc: 0.603632
# [104]	training's auc: 0.735266	valid_1's auc: 0.60356
# [105]	training's auc: 0.735368	valid_1's auc: 0.603507
# [106]	training's auc: 0.735533	valid_1's auc: 0.6035
# [107]	training's auc: 0.735716	valid_1's auc: 0.603465
# [108]	training's auc: 0.735762	valid_1's auc: 0.603423
# [109]	training's auc: 0.735835	valid_1's auc: 0.603416
# [110]	training's auc: 0.735936	valid_1's auc: 0.603318
# [111]	training's auc: 0.736082	valid_1's auc: 0.603367
# [112]	training's auc: 0.736134	valid_1's auc: 0.603274
# [113]	training's auc: 0.736126	valid_1's auc: 0.603172
# [114]	training's auc: 0.736228	valid_1's auc: 0.603083
# [115]	training's auc: 0.736343	valid_1's auc: 0.602966
# [116]	training's auc: 0.736423	valid_1's auc: 0.603097
# [117]	training's auc: 0.736383	valid_1's auc: 0.603166
# [118]	training's auc: 0.736549	valid_1's auc: 0.603082
# [119]	training's auc: 0.736699	valid_1's auc: 0.603258
# [120]	training's auc: 0.73694	valid_1's auc: 0.603439
# [121]	training's auc: 0.737173	valid_1's auc: 0.603387
# [122]	training's auc: 0.73751	valid_1's auc: 0.603379
# [123]	training's auc: 0.737665	valid_1's auc: 0.60338
# [124]	training's auc: 0.738196	valid_1's auc: 0.603608
# [125]	training's auc: 0.738488	valid_1's auc: 0.603685
# [126]	training's auc: 0.738625	valid_1's auc: 0.603818
# [127]	training's auc: 0.739081	valid_1's auc: 0.60378
# [128]	training's auc: 0.739183	valid_1's auc: 0.603788
# [129]	training's auc: 0.739422	valid_1's auc: 0.603869
# [130]	training's auc: 0.739663	valid_1's auc: 0.603683
# [131]	training's auc: 0.740005	valid_1's auc: 0.603682
# [132]	training's auc: 0.740115	valid_1's auc: 0.603822
# [133]	training's auc: 0.740268	valid_1's auc: 0.603841
# [134]	training's auc: 0.740351	valid_1's auc: 0.604075
# [135]	training's auc: 0.740393	valid_1's auc: 0.604079
# [136]	training's auc: 0.740511	valid_1's auc: 0.604214
# [137]	training's auc: 0.740582	valid_1's auc: 0.60423
# [138]	training's auc: 0.74069	valid_1's auc: 0.604319
# [139]	training's auc: 0.740735	valid_1's auc: 0.60445
# [140]	training's auc: 0.740885	valid_1's auc: 0.604265
# [141]	training's auc: 0.741268	valid_1's auc: 0.604282
# [142]	training's auc: 0.741686	valid_1's auc: 0.604248
# [143]	training's auc: 0.742129	valid_1's auc: 0.604259
# [144]	training's auc: 0.742429	valid_1's auc: 0.604124
# [145]	training's auc: 0.742913	valid_1's auc: 0.604152
# [146]	training's auc: 0.743146	valid_1's auc: 0.604187
# [147]	training's auc: 0.743685	valid_1's auc: 0.604132
# [148]	training's auc: 0.743865	valid_1's auc: 0.603967
# [149]	training's auc: 0.744211	valid_1's auc: 0.604075
# [150]	training's auc: 0.744669	valid_1's auc: 0.604057
# [151]	training's auc: 0.744994	valid_1's auc: 0.603851
# [152]	training's auc: 0.74527	valid_1's auc: 0.603791
# [153]	training's auc: 0.745641	valid_1's auc: 0.60367
# [154]	training's auc: 0.746183	valid_1's auc: 0.603491
# [155]	training's auc: 0.746542	valid_1's auc: 0.603411
# [156]	training's auc: 0.746967	valid_1's auc: 0.603485
# [157]	training's auc: 0.747381	valid_1's auc: 0.603452
# [158]	training's auc: 0.747626	valid_1's auc: 0.603475
# [159]	training's auc: 0.747975	valid_1's auc: 0.603399
# [160]	training's auc: 0.748293	valid_1's auc: 0.603392
# [161]	training's auc: 0.748545	valid_1's auc: 0.603446
# [162]	training's auc: 0.748731	valid_1's auc: 0.603586
# [163]	training's auc: 0.748909	valid_1's auc: 0.603644
# [164]	training's auc: 0.749217	valid_1's auc: 0.603843
# [165]	training's auc: 0.749291	valid_1's auc: 0.603829
# [166]	training's auc: 0.749448	valid_1's auc: 0.603919
# [167]	training's auc: 0.749531	valid_1's auc: 0.603975
# [168]	training's auc: 0.749721	valid_1's auc: 0.604051
# [169]	training's auc: 0.749749	valid_1's auc: 0.604115
# [170]	training's auc: 0.749821	valid_1's auc: 0.604096
# [171]	training's auc: 0.749943	valid_1's auc: 0.604099
# [172]	training's auc: 0.749938	valid_1's auc: 0.604211
# [173]	training's auc: 0.749977	valid_1's auc: 0.604336
# [174]	training's auc: 0.750139	valid_1's auc: 0.604433
# [175]	training's auc: 0.750192	valid_1's auc: 0.604365
# [176]	training's auc: 0.750419	valid_1's auc: 0.604231
# [177]	training's auc: 0.750495	valid_1's auc: 0.604341
# [178]	training's auc: 0.75059	valid_1's auc: 0.604365
# [179]	training's auc: 0.750788	valid_1's auc: 0.604454
# [180]	training's auc: 0.750838	valid_1's auc: 0.604539
# [181]	training's auc: 0.751343	valid_1's auc: 0.604463
# [182]	training's auc: 0.75145	valid_1's auc: 0.604398
# [183]	training's auc: 0.751829	valid_1's auc: 0.604309
# [184]	training's auc: 0.752108	valid_1's auc: 0.604238
# [185]	training's auc: 0.752389	valid_1's auc: 0.604302
# [186]	training's auc: 0.752648	valid_1's auc: 0.604438
# [187]	training's auc: 0.753197	valid_1's auc: 0.604482
# [188]	training's auc: 0.75349	valid_1's auc: 0.604499
# [189]	training's auc: 0.753669	valid_1's auc: 0.604429
# [190]	training's auc: 0.754037	valid_1's auc: 0.604252
# [191]	training's auc: 0.75459	valid_1's auc: 0.604238
# [192]	training's auc: 0.754876	valid_1's auc: 0.604348
# [193]	training's auc: 0.755014	valid_1's auc: 0.604303
# [194]	training's auc: 0.755217	valid_1's auc: 0.604224
# [195]	training's auc: 0.755553	valid_1's auc: 0.604124
# [196]	training's auc: 0.755611	valid_1's auc: 0.604113
# [197]	training's auc: 0.755892	valid_1's auc: 0.604197
# [198]	training's auc: 0.756122	valid_1's auc: 0.604162
# [199]	training's auc: 0.756197	valid_1's auc: 0.604129
# [200]	training's auc: 0.75627	valid_1's auc: 0.604075
# [201]	training's auc: 0.756609	valid_1's auc: 0.604089
# [202]	training's auc: 0.757052	valid_1's auc: 0.603998
# [203]	training's auc: 0.757209	valid_1's auc: 0.603892
# [204]	training's auc: 0.757572	valid_1's auc: 0.603856
# [205]	training's auc: 0.757985	valid_1's auc: 0.603875
# [206]	training's auc: 0.75813	valid_1's auc: 0.603734
# [207]	training's auc: 0.758456	valid_1's auc: 0.60382
# [208]	training's auc: 0.758682	valid_1's auc: 0.603787
# [209]	training's auc: 0.758894	valid_1's auc: 0.603637
# [210]	training's auc: 0.759068	valid_1's auc: 0.603566
# [211]	training's auc: 0.759412	valid_1's auc: 0.603544
# [212]	training's auc: 0.759685	valid_1's auc: 0.603424
# [213]	training's auc: 0.75993	valid_1's auc: 0.603208
# [214]	training's auc: 0.76021	valid_1's auc: 0.603245
# [215]	training's auc: 0.760636	valid_1's auc: 0.603229
# [216]	training's auc: 0.760706	valid_1's auc: 0.603245
# [217]	training's auc: 0.760934	valid_1's auc: 0.603246
# [218]	training's auc: 0.761175	valid_1's auc: 0.603324
# [219]	training's auc: 0.761552	valid_1's auc: 0.603326
# [220]	training's auc: 0.761606	valid_1's auc: 0.603333
# [221]	training's auc: 0.761741	valid_1's auc: 0.603419
# [222]	training's auc: 0.762045	valid_1's auc: 0.603519
# [223]	training's auc: 0.76212	valid_1's auc: 0.603621
# [224]	training's auc: 0.762414	valid_1's auc: 0.603522
# [225]	training's auc: 0.762483	valid_1's auc: 0.603582
# [226]	training's auc: 0.762554	valid_1's auc: 0.603667
# [227]	training's auc: 0.762599	valid_1's auc: 0.603731
# [228]	training's auc: 0.762888	valid_1's auc: 0.603802
# [229]	training's auc: 0.763212	valid_1's auc: 0.603777
# [230]	training's auc: 0.763401	valid_1's auc: 0.603957
# [231]	training's auc: 0.763458	valid_1's auc: 0.604027
# [232]	training's auc: 0.763528	valid_1's auc: 0.604098
# [233]	training's auc: 0.763595	valid_1's auc: 0.604262
# [234]	training's auc: 0.764014	valid_1's auc: 0.604412
# [235]	training's auc: 0.764007	valid_1's auc: 0.60435
# [236]	training's auc: 0.764246	valid_1's auc: 0.60427
# [237]	training's auc: 0.764299	valid_1's auc: 0.604258
# [238]	training's auc: 0.764568	valid_1's auc: 0.604444
# [239]	training's auc: 0.764784	valid_1's auc: 0.604554
# [240]	training's auc: 0.764809	valid_1's auc: 0.604622
# [241]	training's auc: 0.764873	valid_1's auc: 0.604571
# [242]	training's auc: 0.764896	valid_1's auc: 0.604558
# [243]	training's auc: 0.764993	valid_1's auc: 0.604656
# [244]	training's auc: 0.765088	valid_1's auc: 0.604598
# [245]	training's auc: 0.765169	valid_1's auc: 0.604573
# [246]	training's auc: 0.76539	valid_1's auc: 0.604505
# [247]	training's auc: 0.765514	valid_1's auc: 0.604427
# [248]	training's auc: 0.765584	valid_1's auc: 0.604466
# [249]	training's auc: 0.765765	valid_1's auc: 0.604509
# [250]	training's auc: 0.765809	valid_1's auc: 0.604487
# [251]	training's auc: 0.766139	valid_1's auc: 0.604317
# [252]	training's auc: 0.766224	valid_1's auc: 0.604256
# [253]	training's auc: 0.76645	valid_1's auc: 0.604204
# [254]	training's auc: 0.766491	valid_1's auc: 0.604244
# [255]	training's auc: 0.76654	valid_1's auc: 0.604137
# [256]	training's auc: 0.766746	valid_1's auc: 0.603975
# [257]	training's auc: 0.766834	valid_1's auc: 0.603873
# [258]	training's auc: 0.766933	valid_1's auc: 0.603696
# [259]	training's auc: 0.767151	valid_1's auc: 0.603679
# [260]	training's auc: 0.767162	valid_1's auc: 0.603738
# [261]	training's auc: 0.767465	valid_1's auc: 0.603715
# [262]	training's auc: 0.768053	valid_1's auc: 0.603672
# [263]	training's auc: 0.76846	valid_1's auc: 0.603551
# [264]	training's auc: 0.76891	valid_1's auc: 0.603411
# [265]	training's auc: 0.769296	valid_1's auc: 0.603284
# [266]	training's auc: 0.769496	valid_1's auc: 0.603252
# [267]	training's auc: 0.769836	valid_1's auc: 0.603176
# [268]	training's auc: 0.770029	valid_1's auc: 0.603126
# [269]	training's auc: 0.770323	valid_1's auc: 0.602952
# [270]	training's auc: 0.770654	valid_1's auc: 0.602815
# [271]	training's auc: 0.770756	valid_1's auc: 0.602815
# [272]	training's auc: 0.771146	valid_1's auc: 0.602814
# [273]	training's auc: 0.771514	valid_1's auc: 0.602753
# [274]	training's auc: 0.771966	valid_1's auc: 0.602615
# [275]	training's auc: 0.77206	valid_1's auc: 0.602571
# [276]	training's auc: 0.772415	valid_1's auc: 0.602424
# [277]	training's auc: 0.77278	valid_1's auc: 0.602116
# [278]	training's auc: 0.7729	valid_1's auc: 0.602058
# [279]	training's auc: 0.773102	valid_1's auc: 0.602099
# [280]	training's auc: 0.773552	valid_1's auc: 0.601966
# [281]	training's auc: 0.774124	valid_1's auc: 0.601977
# [282]	training's auc: 0.774643	valid_1's auc: 0.601939
# [283]	training's auc: 0.775004	valid_1's auc: 0.601909
# [284]	training's auc: 0.77528	valid_1's auc: 0.601896
# [285]	training's auc: 0.775753	valid_1's auc: 0.601961
# [286]	training's auc: 0.775955	valid_1's auc: 0.601944
# [287]	training's auc: 0.77625	valid_1's auc: 0.601978
# [288]	training's auc: 0.77648	valid_1's auc: 0.601931
# [289]	training's auc: 0.777028	valid_1's auc: 0.602008
# [290]	training's auc: 0.777459	valid_1's auc: 0.601994
# [291]	training's auc: 0.777535	valid_1's auc: 0.602015
# [292]	training's auc: 0.777816	valid_1's auc: 0.601919
# [293]	training's auc: 0.778109	valid_1's auc: 0.601884
# [294]	training's auc: 0.778245	valid_1's auc: 0.601851
# [295]	training's auc: 0.77863	valid_1's auc: 0.601904
# [296]	training's auc: 0.77895	valid_1's auc: 0.601831
# [297]	training's auc: 0.77919	valid_1's auc: 0.601846
# [298]	training's auc: 0.779444	valid_1's auc: 0.601928
# [299]	training's auc: 0.779943	valid_1's auc: 0.602078
# [300]	training's auc: 0.780166	valid_1's auc: 0.602026
# [301]	training's auc: 0.78034	valid_1's auc: 0.602044
# [302]	training's auc: 0.780749	valid_1's auc: 0.601999
# [303]	training's auc: 0.781132	valid_1's auc: 0.601973
# [304]	training's auc: 0.781443	valid_1's auc: 0.601972
# [305]	training's auc: 0.781502	valid_1's auc: 0.60194
# [306]	training's auc: 0.781768	valid_1's auc: 0.601905
# [307]	training's auc: 0.782047	valid_1's auc: 0.602013
# [308]	training's auc: 0.782321	valid_1's auc: 0.602109
# [309]	training's auc: 0.78254	valid_1's auc: 0.601847
# [310]	training's auc: 0.782753	valid_1's auc: 0.601772
# [311]	training's auc: 0.782907	valid_1's auc: 0.601683
# [312]	training's auc: 0.782934	valid_1's auc: 0.601614
# [313]	training's auc: 0.783101	valid_1's auc: 0.601619
# [314]	training's auc: 0.78334	valid_1's auc: 0.601629
# [315]	training's auc: 0.783468	valid_1's auc: 0.601536
# [316]	training's auc: 0.783584	valid_1's auc: 0.601451
# [317]	training's auc: 0.783733	valid_1's auc: 0.601454
# [318]	training's auc: 0.783752	valid_1's auc: 0.601409
# [319]	training's auc: 0.783872	valid_1's auc: 0.601456
# [320]	training's auc: 0.784138	valid_1's auc: 0.601446
# [321]	training's auc: 0.784447	valid_1's auc: 0.601419
# [322]	training's auc: 0.784532	valid_1's auc: 0.601304
# [323]	training's auc: 0.784609	valid_1's auc: 0.601259
# [324]	training's auc: 0.784669	valid_1's auc: 0.601121
# [325]	training's auc: 0.784801	valid_1's auc: 0.601028
# [326]	training's auc: 0.785085	valid_1's auc: 0.600985
# [327]	training's auc: 0.785096	valid_1's auc: 0.600941
# [328]	training's auc: 0.785233	valid_1's auc: 0.600955
# [329]	training's auc: 0.785277	valid_1's auc: 0.600909
# [330]	training's auc: 0.78545	valid_1's auc: 0.600925
# [331]	training's auc: 0.785472	valid_1's auc: 0.600892
# [332]	training's auc: 0.785646	valid_1's auc: 0.600765
# [333]	training's auc: 0.785686	valid_1's auc: 0.60076
# [334]	training's auc: 0.785791	valid_1's auc: 0.600679
# [335]	training's auc: 0.785832	valid_1's auc: 0.600632
# [336]	training's auc: 0.785945	valid_1's auc: 0.600556
# [337]	training's auc: 0.786045	valid_1's auc: 0.600576
# [338]	training's auc: 0.786112	valid_1's auc: 0.600506
# [339]	training's auc: 0.786166	valid_1's auc: 0.600397
# [340]	training's auc: 0.786195	valid_1's auc: 0.600398
# [341]	training's auc: 0.786292	valid_1's auc: 0.600455
# [342]	training's auc: 0.786441	valid_1's auc: 0.600584
# [343]	training's auc: 0.786597	valid_1's auc: 0.600658
# Early stopping, best iteration is:
# [243]	training's auc: 0.764993	valid_1's auc: 0.604656

# %%
features_test = test_data.drop(['label'], axis=1)
y_predict = model.predict(features_test)

plan_create['prob'] = y_predict
threshold = pd.Series(y_predict).sort_values(ascending=False).reset_index(drop=True)[int(y_predict.shape[0] * 0.3)]

plan_result = plan_create[plan_create['prob'] >= threshold]
plan_result['rank_ad_im'] = plan_result.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False, method='first')
plan_result = plan_result[plan_result['rank_ad_im'] <= 1]

plan_create['rank_ad_im'] = plan_create.groupby(['ad_account_id', 'image_id'])['prob'].rank(ascending=False, method='first')
plan_result_pr = plan_create[plan_create['rank_ad_im'] <= 1]
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ad_num = plan_result['ad_account_id'].value_counts()
for ad in np.setdiff1d(plan_create['ad_account_id'].values, ad_num[ad_num > 2].index):
    add_plan = plan_result_pr[plan_result_pr['ad_account_id'] == ad].sort_values('prob', ascending=False)[0:2]
    plan_result = plan_result.append(add_plan)

# %%
plan_result.shape
# Out:
# (108, 41)

# %%
plan_result['weight'] = plan_result.groupby(['ad_account_id'])['game_id'].transform('count')
if plan_result.shape[0] > 12:
    plan_result = plan_result.sample(12,weights=plan_result['weight'])

# %%
# if plan_result.shape[0] > 12:
#     plan_result = plan_result.sample(12)

plan_result = plan_result.drop(['create_time', 'create_date', 'prob', 'rank_ad_im', 'label_ids','weight'], axis=1)
plan_result['convertIndex'] = plan_result['deep_bid_type'].apply(lambda x: 13 if x == 'BID_PER_ACTION' else 14)

plan_result['budget'] = plan_result.apply(lambda x: x.budget if x.budget >= x.cpa_bid else x.cpa_bid, axis=1)
plan_result['budget'] = plan_result['budget'].apply(np.ceil)
plan_result['operation'] = 'disable'
plan_result['web_url'] = 'https://www.chengzijianzhan.com/tetris/page/6960565870964621319/'

plan_result.to_csv('./plan_result.csv', index=0)  # 保存创建日志

# %%
plan_result['ad_account_id'].value_counts()
# Out:
# 7326    3
# 7325    3
# 7324    3
# 7323    3
# 6990    2
# 6989    2
# 6987    2
# Name: ad_account_id, dtype: int64

# %%
sns.distplot(y_predict)
plt.show()

# %%
plan_create.head()
# Out:
#    ad_account_id  image_id  game_id   platform android_osv ios_osv  budget  \
# 0           6987     33308  1001540  [ANDROID]        NONE    NONE    3300
# 1           6987     33308  1001540  [ANDROID]        NONE    NONE    3300
# 2           6987     33308  1001540  [ANDROID]        NONE    NONE    3300
# 3           6987     33308  1001540  [ANDROID]        NONE    NONE    3300
# 4           6987     33308  1001540  [ANDROID]        NONE    NONE    3300
#
#                                          ad_keywords  \
# 0  [僵尸, 美女, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, 生存, ...
# 1  [僵尸, 美女, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, 生存, ...
# 2  [僵尸, 美女, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, 生存, ...
# 3  [丧尸, 美女, 僵尸, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, ...
# 4  [僵尸, 美女, 卡牌, 策略, 放置, 回合, 手游, LOL, 塔防, 三国, 生存, ...
#
#                                           title_list third_industry_id  \
# 0  [{'title': '这游戏谁设计的，蹲厕所玩了两小时，腿都麻了！', 'creative...          19131501
# 1  [{'title': '这游戏谁设计的，蹲厕所玩了两小时，腿都麻了！', 'creative...          19131501
# 2  [{'title': '这游戏谁设计的，蹲厕所玩了两小时，腿都麻了！', 'creative...          19131501
# 3  [{'title': '无限关卡游戏，休闲不伤脑，能过50关是人才', 'creative_...          19131501
# 4  [{'title': '这游戏谁设计的，蹲厕所玩了两小时，腿都麻了！', 'creative...          19131501
#
#       retargeting_type retargeting_tags_include retargeting_tags_exclude  \
# 0  RETARGETING_EXCLUDE                       []   [311668496, 301305405]
# 1  RETARGETING_EXCLUDE                       []   [311668496, 301305405]
# 2                  NaN                       []                       []
# 3  RETARGETING_EXCLUDE                       []   [311668496, 301305405]
# 4                  NaN                       []                       []
#
#   interest_action_mode action_scene  action_days action_categories  \
# 0            RECOMMEND          NaN          NaN               NaN
# 1            UNLIMITED          NaN          NaN               NaN
# 2            UNLIMITED          NaN          NaN               NaN
# 3            RECOMMEND          NaN          NaN               NaN
# 4            RECOMMEND          NaN          NaN               NaN
#
#   interest_categories    deep_bid_type  roi_goal    smart_bid_type  \
# 0                  []  ROI_COEFFICIENT      0.03  SMART_BID_CUSTOM
# 1                  []  ROI_COEFFICIENT      0.03  SMART_BID_CUSTOM
# 2                  []  ROI_COEFFICIENT      0.03  SMART_BID_CUSTOM
# 3                  []  ROI_COEFFICIENT      0.03  SMART_BID_CUSTOM
# 4                  []  ROI_COEFFICIENT      0.03  SMART_BID_CUSTOM
#
#    adjust_cpa  cpa_bid delivery_range city location_type       gender  \
# 0         0.0   2866.0        DEFAULT   []       CURRENT  GENDER_MALE
# 1         0.0   2866.0        DEFAULT   []       CURRENT  GENDER_MALE
# 2         0.0   2866.0        DEFAULT   []       CURRENT  GENDER_MALE
# 3         0.0   2866.0        DEFAULT   []       CURRENT  GENDER_MALE
# 4         0.0   2866.0        DEFAULT   []       CURRENT  GENDER_MALE
#
#                                                  age  ac launch_price  \
# 0                                                 []  []   [0, 11000]
# 1                                                 []  []   [0, 11000]
# 2  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...  []   [0, 11000]
# 3  [AGE_BETWEEN_18_23, AGE_BETWEEN_24_30, AGE_BET...  []   [0, 11000]
# 4                                                 []  []   [0, 11000]
#
#    auto_extend_enabled  hide_if_exists hide_if_converted  \
# 0                    0               0                AD
# 1                    0               0                AD
# 2                    0               0                AD
# 3                    0               0                AD
# 4                    0               0                AD
#
#                                        schedule_time       flow_control_mode  \
# 0  0000000000000000000000000001111111111111111111...  FLOW_CONTROL_MODE_FAST
# 1  0000000000000000000000000001111111111111111111...  FLOW_CONTROL_MODE_FAST
# 2  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 3  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
# 4  1111111111111111111111111111111111111111111111...  FLOW_CONTROL_MODE_FAST
#
#                                       inventory_type  \
# 0  [INVENTORY_UNION_SLOT, INVENTORY_AWEME_FEED, I...
# 1  [INVENTORY_HOTSOON_FEED, INVENTORY_TOMATO_NOVE...
# 2  [INVENTORY_HOTSOON_FEED, INVENTORY_TOMATO_NOVE...
# 3  [INVENTORY_HOTSOON_FEED, INVENTORY_TOMATO_NOVE...
# 4  [INVENTORY_HOTSOON_FEED, INVENTORY_TOMATO_NOVE...
#
#                  create_time create_date label_ids      prob  rank_ad_im
# 0 2021-05-21 09:46:10.699622  2021-05-21        20  0.402629         7.0
# 1 2021-05-21 09:46:10.699622  2021-05-21        20  0.428328         5.0
# 2 2021-05-21 09:46:10.699622  2021-05-21        20  0.391564         8.0
# 3 2021-05-21 09:46:10.699622  2021-05-21        20  0.375702         9.0
# 4 2021-05-21 09:46:10.699622  2021-05-21        20  0.363626        10.0
