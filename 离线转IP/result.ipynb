# %%
import pandas as pd

# %%
result = pd.read_table('./result_file.txt')

# %%
result
# Out:
#                               IP地址|错误数据
# 0          116.7.176.29|中国|0|广东省|珠海市|电信
# 1          116.7.176.29|中国|0|广东省|珠海市|电信
# 2          116.7.176.29|中国|0|广东省|珠海市|电信
# 3          116.7.176.29|中国|0|广东省|珠海市|电信
# 4          218.76.38.73|中国|0|湖南省|长沙市|电信
# ...                                 ...
# 164921   223.104.27.193|中国|0|甘肃省|兰州市|移动
# 164922     183.193.61.27|中国|0|上海|上海市|移动
# 164923  114.220.190.104|中国|0|江苏省|苏州市|电信
# 164924     106.56.43.128|中国|0|云南省|红河|电信
# 164925  114.235.176.162|中国|0|江苏省|徐州市|电信
#
# [164926 rows x 1 columns]

# %%
df = pd.read_csv('./export_user.csv')

# %%
df.head()
# Out:
#      玩家Id      服务器   角色名称  等级                 创建时间   充值         账号  \
# 0  100001  1服.口齿留香    佛跳墙  18  2020-08-05 10:17:54  655  106879370
# 1  100002  1服.口齿留香  名字六个字  13  2020-08-05 09:49:29  230  118932045
# 2  100003  1服.口齿留香     臭猪  12  2020-08-05 09:48:28    0  114264663
# 3  100004  1服.口齿留香  第二双马尾   5  2020-08-05 09:32:20    0   88884962
# 4  100005  1服.口齿留香  优雅的果冻   7  2020-08-05 09:34:59    6  112635705
#
#            IP地址                型号  \
# 0  116.7.176.29      vivo vivo X9
# 1  116.7.176.29   HUAWEI HLK-AL10
# 2  116.7.176.29  samsung SM-N9760
# 3  116.7.176.29  HUAWEI HRY-AL00a
# 4  218.76.38.73   HUAWEI JEF-AN00
#
#                                                   系统
# 0  Android OS 7.1.2 / API-25 (N2G47H/eng.compil.2...
# 1  Android OS 10 / API-29 (HONORHLK-AL10/10.0.1.1...
# 2  Android OS 5.1.1 / API-22 (LMY49I/V9.5.3.0.LAC...
# 3  Android OS 10 / API-29 (HONORHRY-AL00a/10.0.0....
# 4  Android OS 10 / API-29 (HUAWEIJEF-AN00/10.1.1....

# %%
df['ip'] = result

# %%
# Out:
#      玩家Id      服务器   角色名称  等级                 创建时间   充值         账号  \
# 0  100001  1服.口齿留香    佛跳墙  18  2020-08-05 10:17:54  655  106879370
# 1  100002  1服.口齿留香  名字六个字  13  2020-08-05 09:49:29  230  118932045
# 2  100003  1服.口齿留香     臭猪  12  2020-08-05 09:48:28    0  114264663
# 3  100004  1服.口齿留香  第二双马尾   5  2020-08-05 09:32:20    0   88884962
# 4  100005  1服.口齿留香  优雅的果冻   7  2020-08-05 09:34:59    6  112635705
#
#            IP地址                型号  \
# 0  116.7.176.29      vivo vivo X9
# 1  116.7.176.29   HUAWEI HLK-AL10
# 2  116.7.176.29  samsung SM-N9760
# 3  116.7.176.29  HUAWEI HRY-AL00a
# 4  218.76.38.73   HUAWEI JEF-AN00
#
#                                                   系统  \
# 0  Android OS 7.1.2 / API-25 (N2G47H/eng.compil.2...
# 1  Android OS 10 / API-29 (HONORHLK-AL10/10.0.1.1...
# 2  Android OS 5.1.1 / API-22 (LMY49I/V9.5.3.0.LAC...
# 3  Android OS 10 / API-29 (HONORHRY-AL00a/10.0.0....
# 4  Android OS 10 / API-29 (HUAWEIJEF-AN00/10.1.1....
#
# ...

# %%
df['ip'] = df['ip'].str.split('|')

# %%
df['pro'] = df['ip'].str[3]
df['city'] = df['ip'].str[4]

# %%
df.head()
# Out:
#      玩家Id      服务器   角色名称  等级                 创建时间   充值         账号  \
# 0  100001  1服.口齿留香    佛跳墙  18  2020-08-05 10:17:54  655  106879370
# 1  100002  1服.口齿留香  名字六个字  13  2020-08-05 09:49:29  230  118932045
# 2  100003  1服.口齿留香     臭猪  12  2020-08-05 09:48:28    0  114264663
# 3  100004  1服.口齿留香  第二双马尾   5  2020-08-05 09:32:20    0   88884962
# 4  100005  1服.口齿留香  优雅的果冻   7  2020-08-05 09:34:59    6  112635705
#
#            IP地址                型号  \
# 0  116.7.176.29      vivo vivo X9
# 1  116.7.176.29   HUAWEI HLK-AL10
# 2  116.7.176.29  samsung SM-N9760
# 3  116.7.176.29  HUAWEI HRY-AL00a
# 4  218.76.38.73   HUAWEI JEF-AN00
#
#                                                   系统  \
# 0  Android OS 7.1.2 / API-25 (N2G47H/eng.compil.2...
# 1  Android OS 10 / API-29 (HONORHLK-AL10/10.0.1.1...
# 2  Android OS 5.1.1 / API-22 (LMY49I/V9.5.3.0.LAC...
# 3  Android OS 10 / API-29 (HONORHRY-AL00a/10.0.0....
# 4  Android OS 10 / API-29 (HUAWEIJEF-AN00/10.1.1....
#
# ...

# %%
df.to_csv('./df.csv')
